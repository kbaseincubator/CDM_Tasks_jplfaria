# %% [markdown]
# # Build Metabolic Model (Advanced)
#
# To build a metabolic model we need the following inputs:
#  - template (genome scale)
#  - template (core)
#  - atp metabolism medias - ModelSEEDpy provides an array of atp metabolism medias
#  - genome
#  - genome growth medium

# %%
import modelseedpy
from modelseedpy.core.mstemplate import MSTemplateBuilder

# %% [markdown]
# ### Load Templates

# %%
import json
with open('./Core-V5.2.json') as fh:
    template_core = MSTemplateBuilder.from_dict(json.load(fh)).build()
with open('./GramNegModelTemplateV6.json') as fh:
    template_gramneg = MSTemplateBuilder.from_dict(json.load(fh)).build()

# %%
template_core
# Out:
#         <table>
#             <tr>
#                 <td><strong>ID</strong></td>
#                 <td>CoreTemplateBacteria</td>
#             </tr><tr>
#                 <td><strong>Memory address</strong></td>
#                 <td>0x07fd278173730</td>
#             </tr><tr>
#                 <td><strong>Number of metabolites</strong></td>
#                 <td>197</td>
#             </tr><tr>
#                 <td><strong>Number of species</strong></td>
#                 <td>232</td>
#             </tr><tr>
#                 <td><strong>Number of reactions</strong></td>
#                 <td>252</td>
#             </tr><tr>
#                 <td><strong>Number of biomasses</strong></td>
#                 <td>0</td>
#             </tr><tr>
#                 <td><strong>Number of roles</strong></td>
#                 <td>706</td>
#             </tr><tr>
#                 <td><strong>Number of complexes</strong></td>
#                 <td>468</td>
#             </tr>
#           </table>

# %%
template_gramneg
# Out:
#         <table>
#             <tr>
#                 <td><strong>ID</strong></td>
#                 <td>GramNegative.modeltemplate</td>
#             </tr><tr>
#                 <td><strong>Memory address</strong></td>
#                 <td>0x07fd10d9736d0</td>
#             </tr><tr>
#                 <td><strong>Number of metabolites</strong></td>
#                 <td>6573</td>
#             </tr><tr>
#                 <td><strong>Number of species</strong></td>
#                 <td>7116</td>
#             </tr><tr>
#                 <td><strong>Number of reactions</strong></td>
#                 <td>8584</td>
#             </tr><tr>
#                 <td><strong>Number of biomasses</strong></td>
#                 <td>1</td>
#             </tr><tr>
#                 <td><strong>Number of roles</strong></td>
#                 <td>20548</td>
#             </tr><tr>
#                 <td><strong>Number of complexes</strong></td>
#                 <td>3296</td>
#             </tr>
#           </table>

# %% [markdown]
# ### Load Genome and Annotate with RAST

# %%
genome = modelseedpy.MSGenome.from_fasta('/opt/python/ModelSEEDpy/examples/Model Reconstruction/GCF_000005845.2_ASM584v2_protein.faa')

# %%
rast = modelseedpy.RastClient()
out = rast.annotate_genome(genome)

# %%
for feature in genome.features:
    print(feature.ontology_terms)
# Out:
# {'RAST': ['Thr operon leader peptide']}
# {'RAST': ['Aspartokinase (EC 2.7.2.4)', 'Homoserine dehydrogenase (EC 1.1.1.3)']}
# {'RAST': ['Homoserine kinase (EC 2.7.1.39)']}
# {'RAST': ['Threonine synthase (EC 4.2.3.1)']}
# {'RAST': ['Uncharacterized protein YaaX']}
# {'RAST': ['UPF0246 protein YaaA']}
# {'RAST': ['Putative alanine/glycine transport protein']}
# {'RAST': ['Transaldolase (EC 2.2.1.2)']}
# {'RAST': ['Molybdopterin adenylyltransferase (EC 2.7.7.75)']}
# {'RAST': ['Succinate-acetate/proton symporter SatP']}
# {'RAST': ['UPF0174 protein YaaW']}
# {'RAST': ['UPF0412 protein YaaI']}
# {'RAST': ['Chaperone protein DnaK']}
# {'RAST': ['Chaperone protein DnaJ']}
# {'RAST': ['Transposase InsL for insertion sequence element IS186']}
# {}
# {'RAST': ['Na+/H+ antiporter NhaA type']}
# {'RAST': ['Transcriptional activator NhaR']}
# {'RAST': ['IS1 protein InsB']}
# {'RAST': ['IS1 protein InsA']}
# {'RAST': ['SSU ribosomal protein S20p']}
# {'RAST': ['Uncharacterized protein YaaY']}
# {'RAST': ['FMN adenylyltransferase (EC 2.7.7.2)', 'Riboflavin kinase (EC 2.7.1.26)']}
# {'RAST': ['Isoleucyl-tRNA synthetase (EC 6.1.1.5)']}
# {'RAST': ['Lipoprotein signal peptidase (EC 3.4.23.36)']}
# {'RAST': ['FKBP-type peptidyl-prolyl cis-trans isomerase SlpA (EC 5.2.1.8)']}
# {'RAST': ['4-hydroxy-3-methylbut-2-enyl diphosphate reductase (EC 1.17.7.4)']}
# {'RAST': ['Non-specific ribonucleoside hydrolase RihC']}
# {'RAST': ['4-hydroxy-tetrahydrodipicolinate reductase (EC 1.17.1.8)']}
# {'RAST': ['Carbamoyl-phosphate synthase small chain (EC 6.3.5.5)']}
# {'RAST': ['Carbamoyl-phosphate synthase large chain (EC 6.3.5.5)']}
# {'RAST': ['Transcriptional activatory protein CaiF']}
# {'RAST': ['Carnitine operon protein CaiE']}
# {'RAST': ['Carnitinyl-CoA dehydratase (EC 4.2.1.149)']}
# {'RAST': ['Crotonobetaine--CoA ligase', ' Carnitine--CoA ligase']}
# {'RAST': ['Crotonobetainyl-CoA:carnitine CoA-transferase (EC 2.8.3.21)']}
# {'RAST': ['Crotonobetainyl-CoA dehydrogenase (EC 1.3.99.-)']}
# {'RAST': ['L-carnitine/gamma-butyrobetaine antiporter']}
# {'RAST': ['Electron transfer flavoprotein, beta subunit ecFixA']}
# {'RAST': ['Electron transfer flavoprotein, alpha subunit ecFixB']}
# {'RAST': ['Electron transfer flavoprotein-quinone oxidoreductase ecFixC']}
# {'RAST': ['Ferredoxin-like protein ecFixX']}
# {'RAST': ['Putative metabolite transport protein YaaU']}
# {'RAST': ['Glutathione-regulated potassium-efflux system ancillary protein KefF']}
# {'RAST': ['Glutathione-regulated potassium-efflux system protein KefC']}
# {'RAST': ['Dihydrofolate reductase (EC 1.5.1.3)']}
# {'RAST': ["Bis(5'-nucleosyl)-tetraphosphatase, symmetrical (EC 3.6.1.41)"]}
# {'RAST': ['ApaG protein']}
# {'RAST': ['SSU rRNA (adenine(1518)-N(6)/adenine(1519)-N(6))-dimethyltransferase (EC 2.1.1.182)']}
# {'RAST': ['4-hydroxythreonine-4-phosphate dehydrogenase (EC 1.1.1.262)']}
# {'RAST': ['Periplasmic chaperone and peptidyl-prolyl cis-trans isomerase of outer membrane proteins SurA (EC 5.2.1.8)']}
# {'RAST': ['LPS-assembly protein LptD', ' Organic solvent tolerance protein precursor']}
# {'RAST': ['DnaJ-like protein DjlA']}
# {'RAST': ['LSU rRNA pseudouridine(746) synthase (EC 5.4.99.29)', ' tRNA pseudouridine(32) synthase (EC 5.4.99.28)']}
# {'RAST': ['RNA polymerase associated protein RapA']}
# {'RAST': ['DNA polymerase II (EC 2.7.7.7)']}
# {'RAST': ['L-ribulose-5-phosphate 4-epimerase (EC 5.1.3.4)']}
# {'RAST': ['L-arabinose isomerase (EC 5.3.1.4)']}
# {'RAST': ['Ribulokinase (EC 2.7.1.16)']}
# {'RAST': ['Arabinose operon regulatory protein AraC']}
# {'RAST': ['DedA family inner membrane protein YabI']}
# {'RAST': ['Thiamin ABC transporter, ATPase component']}
# {'RAST': ['Thiamin ABC transporter, transmembrane component']}
# {'RAST': ['Thiamin ABC transporter, substrate-binding component']}
# {'RAST': ['SgrR, sugar-phosphate stress, transcriptional activator of SgrS small RNA']}
# {'RAST': ['3-isopropylmalate dehydratase small subunit (EC 4.2.1.33)']}
# {'RAST': ['3-isopropylmalate dehydratase large subunit (EC 4.2.1.33)']}
# {'RAST': ['3-isopropylmalate dehydrogenase (EC 1.1.1.85)']}
# {'RAST': ['2-isopropylmalate synthase (EC 2.3.3.13)']}
# {'RAST': ['Leu operon leader peptide']}
# {'RAST': ['LysR family transcriptional activator LeuO']}
# {'RAST': ['Acetolactate synthase small subunit (EC 2.2.1.6)']}
# {'RAST': ['Fructose repressor FruR, LacI family']}
# {'RAST': ['Transcriptional regulator MraZ']}
# {'RAST': ['16S rRNA (cytosine(1402)-N(4))-methyltransferase (EC 2.1.1.199)']}
# {'RAST': ['Cell division protein FtsL']}
# {'RAST': ['Cell division protein FtsI [Peptidoglycan synthetase] (EC 2.4.1.129)']}
# {'RAST': ['UDP-N-acetylmuramoyl-dipeptide--2,6-diaminopimelate ligase (EC 6.3.2.13)']}
# {'RAST': ['UDP-N-acetylmuramoyl-tripeptide--D-alanyl-D-alanine ligase (EC 6.3.2.10)']}
# {'RAST': ['Phospho-N-acetylmuramoyl-pentapeptide-transferase (EC 2.7.8.13)']}
# {'RAST': ['UDP-N-acetylmuramoyl-L-alanine--D-glutamate ligase (EC 6.3.2.9)']}
# {'RAST': ['Peptidoglycan glycosyltransferase FtsW (EC 2.4.1.129)']}
# {'RAST': ['UDP-N-acetylglucosamine--N-acetylmuramyl-(pentapeptide) pyrophosphoryl-undecaprenol N-acetylglucosamine transferase (EC 2.4.1.227)']}
# {'RAST': ['UDP-N-acetylmuramate--L-alanine ligase (EC 6.3.2.8)']}
# {'RAST': ['D-alanine--D-alanine ligase (EC 6.3.2.4)']}
# {'RAST': ['Cell division protein FtsQ']}
# {'RAST': ['Cell division protein FtsA']}
# {'RAST': ['Cell division protein FtsZ']}
# {'RAST': ['UDP-3-O-[3-hydroxymyristoyl] N-acetylglucosamine deacetylase (EC 3.5.1.108)']}
# {'RAST': ['Secretion monitor SecM']}
# {'RAST': ['Protein translocase subunit SecA']}
# {'RAST': ['Mutator MutT protein (7,8-dihydro-8-oxoguanine-triphosphatase) (EC 3.6.1.-)']}
# {'RAST': ['DNA gyrase inhibitor YacG']}
# {'RAST': ['Cell division protein ZapD']}
# {'RAST': ['Dephospho-CoA kinase (EC 2.7.1.24)']}
# {'RAST': ['GMP reductase (EC 1.7.1.7)']}
# {'RAST': ['Type IV fimbrial assembly protein PilC']}
# {'RAST': ['Type IV fimbrial assembly, ATPase PilB']}
# {'RAST': ['Type IV pilin PilA']}
# {'RAST': ['Quinolinate phosphoribosyltransferase [decarboxylating] (EC 2.4.2.19)']}
# {'RAST': ['1,6-anhydro-N-acetylmuramyl-L-alanine amidase']}
# {'RAST': ['AmpE protein']}
# {'RAST': ['Aromatic amino acid transport protein AroP']}
# {'RAST': ['Transcriptional repressor for pyruvate dehydrogenase complex']}
# {'RAST': ['Pyruvate dehydrogenase E1 component (EC 1.2.4.1)']}
# {'RAST': ['Dihydrolipoamide acetyltransferase component of pyruvate dehydrogenase complex (EC 2.3.1.12)']}
# {'RAST': ['Dihydrolipoamide dehydrogenase of pyruvate dehydrogenase complex (EC 1.8.1.4)', ' Dihydrolipoamide dehydrogenase (EC 1.8.1.4)']}
# {'RAST': ['Uncharacterized protein YacH']}
# {'RAST': ['Aconitate hydratase 2 (EC 4.2.1.3)', ' 2-methylisocitrate dehydratase (EC 4.2.1.99)']}
# {'RAST': ['UPF0231 protein YacL']}
# {'RAST': ['S-adenosylmethionine decarboxylase proenzyme (EC 4.1.1.50), prokaryotic class 1A']}
# {'RAST': ['Spermidine synthase (EC 2.5.1.16)']}
# {'RAST': ['Predicted chaperone lipoprotein YacC, potentially involved in protein secretion']}
# {'RAST': ['Blue copper oxidase CueO precursor']}
# {'RAST': ['Glucose dehydrogenase, PQQ-dependent (EC 1.1.5.2)']}
# {'RAST': ['Hypoxanthine-guanine phosphoribosyltransferase (EC 2.4.2.8)']}
# {'RAST': ['Carbonic anhydrase, beta class (EC 4.2.1.1)']}
# {'RAST': ['Uncharacterized efflux ABC transporter, ATP-binding protein YadG']}
# {'RAST': ['Uncharacterized efflux ABC transporter, permease protein YadH']}
# {'RAST': ['Putative PTS system IIA component YadI']}
# {'RAST': ['Uncharacterized protein YadE']}
# {'RAST': ['Aspartate 1-decarboxylase (EC 4.1.1.11)']}
# {'RAST': ['Uncharacterized protein YadD']}
# {'RAST': ['Pantoate--beta-alanine ligase (EC 6.3.2.1)']}
# {'RAST': ['3-methyl-2-oxobutanoate hydroxymethyltransferase (EC 2.1.2.11)']}
# {'RAST': ['Uncharacterized fimbrial-like protein YadC']}
# {'RAST': ['Uncharacterized fimbrial-like protein YadK']}
# {'RAST': ['Uncharacterized fimbrial-like protein YadL']}
# {'RAST': ['Uncharacterized fimbrial-like protein YadM']}
# {'RAST': ['Outer membrane usher protein HtrE']}
# {'RAST': ['Fimbria adhesin EcpD']}
# {'RAST': ['Uncharacterized fimbrial-like protein YadN']}
# {'RAST': ['2-amino-4-hydroxy-6-hydroxymethyldihydropteridine pyrophosphokinase (EC 2.7.6.3)']}
# {'RAST': ['Poly(A) polymerase (EC 2.7.7.19)']}
# {'RAST': ['Glutamyl-Q tRNA(Asp) synthetase']}
# {'RAST': ['RNA polymerase-binding transcription factor DksA']}
# {'RAST': ['Sugar fermentation stimulation protein SfsA']}
# {'RAST': ["2'-5' RNA ligase"]}
# {'RAST': ['ATP-dependent helicase HrpB']}
# {'RAST': ['Multimodular transpeptidase-transglycosylase (EC 2.4.1.129) (EC 3.4.-.-)']}
# {'RAST': ['Ferric hydroxamate outer membrane receptor FhuA']}
# {'RAST': ['Ferric hydroxamate ABC transporter (TC 3.A.1.14.3), ATP-binding protein FhuC']}
# {'RAST': ['Ferric hydroxamate ABC transporter (TC 3.A.1.14.3), periplasmic substrate binding protein FhuD']}
# {'RAST': ['Ferric hydroxamate ABC transporter (TC 3.A.1.14.3), permease component FhuB']}
# {'RAST': ['Glutamate-1-semialdehyde 2,1-aminomutase (EC 5.4.3.8)']}
# {'RAST': ['Voltage-gated H(+)/2Cl(-) exchange transporter ClcA']}
# {'RAST': ['Iron-sulfur cluster insertion protein ErpA']}
# {'RAST': ['UPF0126 inner membrane protein YadS']}
# {'RAST': ['Vitamin B12 ABC transporter, substrate-binding protein BtuF']}
# {'RAST': ["5'-methylthioadenosine nucleosidase (EC 3.2.2.16)", ' S-adenosylhomocysteine nucleosidase (EC 3.2.2.9)']}
# {'RAST': ['Deoxyguanosinetriphosphate triphosphohydrolase (EC 3.1.5.1), subgroup 1']}
# {'RAST': ['HtrA protease/chaperone protein']}
# {'RAST': ['Sugar diacid utilization regulator SdaR']}
# {'RAST': ['UPF0325 protein YaeH']}
# {'RAST': ['Phosphodiesterase YaeI']}
# {'RAST': ['2,3,4,5-tetrahydropyridine-2,6-dicarboxylate N-succinyltransferase (EC 2.3.1.117)']}
# {'RAST': ['[Protein-PII] uridylyltransferase (EC 2.7.7.59)', '[Protein-PII]-UMP uridylyl-removing enzyme']}
# {'RAST': ['Methionine aminopeptidase (EC 3.4.11.18)']}
# {'RAST': ['SSU ribosomal protein S2p (SAe)']}
# {'RAST': ['Translation elongation factor Ts']}
# {'RAST': ['Uridylate kinase (EC 2.7.4.22)']}
# {'RAST': ['Ribosome recycling factor']}
# {'RAST': ['1-deoxy-D-xylulose 5-phosphate reductoisomerase (EC 1.1.1.267)']}
# {'RAST': ['Undecaprenyl diphosphate synthase (EC 2.5.1.31)']}
# {'RAST': ['Phosphatidate cytidylyltransferase (EC 2.7.7.41)']}
# {'RAST': ['Intramembrane protease RasP/YluC, implicated in cell division based on FtsL cleavage']}
# {'RAST': ['Outer membrane protein assembly factor YaeT']}
# {'RAST': ['Periplasmic chaperone of outer membrane proteins Skp', ' Outer membrane protein H precursor']}
# {'RAST': ['UDP-3-O-[3-hydroxymyristoyl] glucosamine N-acyltransferase (EC 2.3.1.191)']}
# {'RAST': ['3-hydroxyacyl-[acyl-carrier-protein] dehydratase, FabZ form (EC 4.2.1.59)']}
# {'RAST': ['Acyl-[acyl-carrier-protein]--UDP-N-acetylglucosamine O-acyltransferase (EC 2.3.1.129)']}
# {'RAST': ['Lipid-A-disaccharide synthase (EC 2.4.1.182)']}
# {'RAST': ['Ribonuclease HII (EC 3.1.26.4)']}
# {'RAST': ['DNA polymerase III alpha subunit (EC 2.7.7.7)']}
# {'RAST': ['Acetyl-coenzyme A carboxyl transferase alpha chain (EC 6.4.1.2)']}
# {'RAST': ['Lysine decarboxylase 2, constitutive (EC 4.1.1.18)']}
# {'RAST': ['Uncharacterized protein YaeR with similarity to glyoxylase family']}
# {'RAST': ['tRNA(Ile)-lysidine synthetase (EC 6.3.4.19)']}
# {'RAST': ['Rho-specific inhibitor of transcription termination (YaeO)']}
# {'RAST': ['YaeQ protein']}
# {'RAST': ['Peptidyl-tRNA hydrolase ArfB (EC 3.1.1.29)']}
# {'RAST': ['Copper homeostasis protein CutF precursor', 'Lipoprotein NlpE involeved in surface adhesion']}
# {'RAST': ['Uncharacterized lipoprotein yaeF precursor']}
# {'RAST': ['Prolyl-tRNA synthetase (EC 6.1.1.15), bacterial type']}
# {'RAST': ['tRNA (adenine(37)-N6)-methyltransferase']}
# {'RAST': ['Protein RcsF']}
# {'RAST': ['Methionine ABC transporter substrate-binding protein']}
# {'RAST': ['Methionine ABC transporter permease protein']}
# {'RAST': ['Methionine ABC transporter ATP-binding protein']}
# {'RAST': ['D-glycero-beta-D-manno-heptose-1,7-bisphosphate 7-phosphatase (EC 3.1.3.82)']}
# {'RAST': ['Methylglyoxal reductase, dihydroxyacetone producing', ' 2,5-didehydrogluconate reductase (2-dehydro-L-gulonate-forming) (EC 1.1.1.346)']}
# {'RAST': ['Transcriptional regulator YafC, LysR family']}
# {'RAST': ['UPF0294 protein YafD']}
# {'RAST': ['SAM-dependent methyltransferase YafE (UbiE paralog)']}
# {'RAST': ['Membrane-bound lytic murein transglycosylase D']}
# {'RAST': ['Hydroxyacylglutathione hydrolase (EC 3.1.2.6)']}
# {'RAST': ['FIG005121: SAM-dependent methyltransferase (EC 2.1.1.-)']}
# {'RAST': ['Ribonuclease HI (EC 3.1.26.4)']}
# {'RAST': ['DNA polymerase III epsilon subunit (EC 2.7.7.7)']}
# {'RAST': ['Uncharacterized lipoprotein YafT']}
# {'RAST': ['Aliphatic amidase AmiE (EC 3.5.1.4)']}
# {'RAST': ['Inhibitor of vertebrate c-type lysozyme, periplasmic => Ivy']}
# {'RAST': ['Acyl-coenzyme A dehydrogenase FadE (EC 1.3.8.-)']}
# {'RAST': ['D-sedoheptulose 7-phosphate isomerase (EC 5.3.1.28)']}
# {'RAST': ['Putative glutamine amidotransferase YafJ']}
# {'RAST': ['Putative L,D-transpeptidase YafK']}
# {'RAST': ['mRNA interferase YafQ']}
# {'RAST': ['Antitoxin DinJ (binds YafQ toxin)']}
# {'RAST': ['Probable endopeptidase YafL']}
# {'RAST': ['Transposase and inactivated derivatives']}
# {'RAST': ['DNA polymerase IV (EC 2.7.7.7)']}
# {'RAST': ['Antitoxin YafN']}
# {'RAST': ['Toxin YafO']}
# {'RAST': ['Uncharacterized acetyltransferase YafP (EC 2.3.1.-)']}
# {'RAST': ['Cytosol nonspecific dipeptidase (EC 3.4.13.18)']}
# {'RAST': ['Xanthine-guanine phosphoribosyltransferase (EC 2.4.2.22)']}
# {'RAST': ['Fermentation/respiration switch protein']}
# {'RAST': ['Outer membrane porin PhoE']}
# {'RAST': ['Glutamate 5-kinase (EC 2.7.2.11)', 'RNA-binding C-terminal domain PUA']}
# {'RAST': ['Gamma-glutamyl phosphate reductase (EC 1.2.1.41)']}
# {'RAST': ['Toxin YkfI']}
# {'RAST': ['Antitoxin YafW (binds toxin YkfI)']}
# {'RAST': ['UPF0758 protein YkfG']}
# {'RAST': ['Antirestriction protein klcA']}
# {'RAST': ['UPF0401 protein YkfF']}
# {'RAST': ['Uncharacterized protein YkfB']}
# {'RAST': ['Uncharacterized lipoprotein YafY']}
# {'RAST': ['UPF0380 proteins YafZ and homologs']}
# {'RAST': ['Uncharacterized protein YkfA']}
# {'RAST': ['Transcriptional regulator PerR, LysR family']}
# {'RAST': ['Transposase InsI for insertion sequence element IS30']}
# {'RAST': ['Transposase InsH for insertion sequence element IS5']}
# {'RAST': ['S-methylmethionine permease']}
# {'RAST': ['Homocysteine S-methyltransferase (EC 2.1.1.10)']}
# {'RAST': ['Ferric cations import ATP-binding protein fbpC (EC 3.6.3.30)']}
# {'RAST': ['IS1 protein InsB']}
# {'RAST': ['IS1 protein InsA']}
# {'RAST': ['Uncharacterized transposase YagA']}
# {'RAST': ['Uncharacterized lyase YjhH']}
# {'RAST': ['Uncharacterized dehydratase YagF']}
# {'RAST': ['Proposed xyloside/Na+ symporter YagG']}
# {'RAST': ['Xylan 1,4-beta-xylosidase (EC 3.2.1.37)']}
# {'RAST': ['Uncharacterized transcriptional regulator YagI, IclR family']}
# {'RAST': ['Ornithine carbamoyltransferase (EC 2.1.3.3)']}
# {'RAST': ['IS1 protein InsB']}
# {'RAST': ['IS1 protein InsA']}
# {'RAST': ['Uncharacterized protein YagK']}
# {'RAST': ['Uncharacterized resolvase YagL']}
# {'RAST': ['Uncharacterized protein YagM']}
# {}
# {'RAST': ['Prophage CP4-6 integrase']}
# {'RAST': ['Uncharacterized protein YagQ']}
# {'RAST': ['Periplasmic aromatic aldehyde oxidoreductase, molybdenum binding subunit YagR']}
# {'RAST': ['Periplasmic aromatic aldehyde oxidoreductase, FAD binding subunit YagS']}
# {'RAST': ['Periplasmic aromatic aldehyde oxidoreductase, iron-sulfur subunit YagT']}
# {'RAST': ['DUF1440 domain-containing membrane protein']}
# {'RAST': ['Ferredoxin']}
# {'RAST': ['CFA/I fimbrial chaperone']}
# {'RAST': ['CFA/I fimbrial minor adhesin']}
# {'RAST': ['CFA/I fimbrial subunit C usher protein']}
# {'RAST': ['CFA/I fimbrial auxiliary subunit']}
# {'RAST': ['CFA/I fimbrial major subunit']}
# {'RAST': ['Transcriptional regulator EcpR']}
# {'RAST': ['Uncharacterized protein YkgL']}
# {'RAST': ['LSU ribosomal protein L31p', ' LSU ribosomal protein L31p, zinc-independent']}
# {'RAST': ['Transposase InsE for insertion sequence IS3E']}
# {'RAST': ['Transposase InsF for insertion sequence IS3', ' Mobile element protein']}
# {'RAST': ['Inner membrane protein RclC associated with response to reactive chlorine species']}
# {'RAST': ['Uncharacterized protein RclB associated with response to reactive chlorine species']}
# {'RAST': ['Putative Dihydrolipoamide dehydrogenase (EC 1.8.1.4)', 'Mercuric ion reductase (EC 1.16.1.1)', 'PF00070 family, FAD-dependent NAD(P)-disulphide oxidoreductase']}
# {'RAST': ['Reactive-chlorine-species-specific transcriptional activator RclR, AraC family']}
# {'RAST': ['Predicted L-lactate dehydrogenase, Fe-S oxidoreductase subunit YkgE']}
# {'RAST': ['Predicted L-lactate dehydrogenase, Iron-sulfur cluster-binding subunit YkgF']}
# {'RAST': ['Predicted L-lactate dehydrogenase, hypothetical protein subunit YkgG']}
# {'RAST': ['Uncharacterized protein YkgH']}
# {'RAST': ['Choline dehydrogenase (EC 1.1.99.1)']}
# {'RAST': ['Betaine aldehyde dehydrogenase (EC 1.2.1.8)']}
# {'RAST': ['Transcriptional regulator BetI, TetR family']}
# {'RAST': ['High-affinity choline uptake protein BetT']}
# {'RAST': ['c-di-GMP phosphodiesterase (EC 3.1.4.52) => PdeL']}
# {'RAST': ['LysR family transcriptional regulator YahB']}
# {'RAST': ['Uncharacterized protein YahC']}
# {'RAST': ['Putative ankyrin repeat protein YahD']}
# {'RAST': ['Uncharacterized protein YahE']}
# {'RAST': ['Uncharacterized protein YahF, possible CoA ligase']}
# {'RAST': ['Uncharacterized protein YahG']}
# {'RAST': ['Carbamate kinase-like protein YahI']}
# {'RAST': ['Putative deaminase YahJ']}
# {'RAST': ['Cinnamyl alcohol dehydrogenase/reductase (EC 1.1.1.195)', ' Alcohol dehydrogenase (EC 1.1.1.1)']}
# {'RAST': ['Uncharacterized protein YahL']}
# {}
# {'RAST': ['Uncharacterized membrane protein YahN']}
# {}
# {'RAST': ['Propionate catabolism operon regulatory protein PrpR']}
# {'RAST': ['Methylisocitrate lyase (EC 4.1.3.30)']}
# {'RAST': ['2-methylcitrate synthase (EC 2.3.3.5)']}
# {'RAST': ['2-methylcitrate dehydratase (EC 4.2.1.79)']}
# {'RAST': ['Propionate--CoA ligase (EC 6.2.1.17)']}
# {'RAST': ['Cytosine permease']}
# {'RAST': ['Cytosine deaminase (EC 3.5.4.1)']}
# {'RAST': ['Cyn operon transcriptional activator']}
# {'RAST': ['Carbonic anhydrase, beta class (EC 4.2.1.1)']}
# {'RAST': ['Cyanate hydratase (EC 4.2.1.104)']}
# {'RAST': ['Cyanate transport protein CynX']}
# {'RAST': ['Galactoside O-acetyltransferase (EC 2.3.1.18)']}
# {'RAST': ['Lactose permease']}
# {'RAST': ['beta-galactosidase (EC 3.2.1.23)']}
# {'RAST': ['Transcriptional repressor of the lac operon']}
# {'RAST': ['Mhp operon transcriptional activator']}
# {'RAST': ['3-(3-hydroxyphenyl)propanoate hydroxylase (EC 1.14.13.127)']}
# {'RAST': ['3-carboxyethylcatechol 2,3-dioxygenase (EC 1.13.11.16)']}
# {'RAST': ['2-hydroxy-6-oxonona-2,4-dienedioate hydrolase (EC 3.7.1.14)']}
# {'RAST': ['2-keto-4-pentenoate hydratase (EC 4.2.1.80)']}
# {'RAST': ['Acetaldehyde dehydrogenase, acetylating, (EC 1.2.1.10) in gene cluster for degradation of phenols, cresols, catechol']}
# {'RAST': ['4-hydroxy-2-oxovalerate aldolase (EC 4.1.3.39)']}
# {'RAST': ['3-(3-hydroxyphenyl)propionate transporter, MFS-type']}
# {'RAST': ['Nucleoprotein/polynucleotide-associated enzyme']}
# {'RAST': ['S-formylglutathione hydrolase (EC 3.1.2.12)']}
# {'RAST': ['S-(hydroxymethyl)glutathione dehydrogenase (EC 1.1.1.284)']}
# {'RAST': ['FrmR: Negative transcriptional regulator of formaldehyde detoxification operon']}
# {'RAST': ['hypothetical protein']}
# {'RAST': ['Transposase InsC for insertion element IS2']}
# {'RAST': ['Transposase InsD for insertion element IS2']}
# {'RAST': ['Uncharacterized glycosyltransferase YaiP']}
# {'RAST': ['Uncharacterized deacetylase YaiS']}
# {'RAST': ['Taurine ABC transporter, substrate-binding protein TauA']}
# {'RAST': ['Taurine ABC transporter, ATP-binding protein TauB']}
# {'RAST': ['Taurine ABC transporter, permease protein TauC']}
# {'RAST': ['Alpha-ketoglutarate-dependent taurine dioxygenase (EC 1.14.11.17)']}
# {'RAST': ['Porphobilinogen synthase (EC 4.2.1.24)']}
# {'RAST': ['Transposase InsF for insertion sequence IS3', ' Mobile element protein']}
# {'RAST': ['Transposase InsE for insertion sequence IS3E']}
# {'RAST': ['Uncharacterized protein YaiV']}
# {'RAST': ['D-alanyl-D-alanine-carboxypeptidase/endopeptidase AmpH']}
# {'RAST': ['SbmA protein']}
# {'RAST': ['Uncharacterized outer membrane protein YaiW']}
# {'RAST': ['Inner membrane protein YaiY']}
# {'RAST': ['Uncharacterized protein YaiZ']}
# {'RAST': ['D-alanine--D-alanine ligase (EC 6.3.2.4)']}
# {'RAST': ['Anti-adapter protein IraP']}
# {'RAST': ['Alkaline phosphatase (EC 3.1.3.1)']}
# {'RAST': ['Phosphate starvation-inducible protein PsiF']}
# {'RAST': ['Diguanylate cyclase (EC 2.7.7.65) => DgcC']}
# {'RAST': ['Pyrroline-5-carboxylate reductase (EC 1.5.1.2)']}
# {'RAST': ['Protein YaiI']}
# {'RAST': ['Shikimate kinase III (EC 2.7.1.71)']}
# {'RAST': ['Protein YaiA']}
# {'RAST': ['AroM protein']}
# {'RAST': ['Pyrimidine/purine nucleoside phosphorylase PpnP']}
# {'RAST': ['DNA recombination-dependent growth factor RdgC']}
# {'RAST': ['Cryptic sugar kinase Mak']}
# {'RAST': ['Protein AraJ precursor']}
# {'RAST': ['Exonuclease SbcC']}
# {'RAST': ['Exonuclease SbcD']}
# {'RAST': ['Phosphate regulon transcriptional regulatory protein PhoB (SphR)']}
# {'RAST': ['Phosphate regulon sensor protein PhoR (SphS) (EC 2.7.13.3)']}
# {'RAST': ['Na(+)-dependent branched-chain amino acid transporter']}
# {'RAST': ['Proline-specific permease ProY']}
# {'RAST': ['Maltodextrin glucosidase (EC 3.2.1.20)']}
# {'RAST': ['Acyl carrier protein phosphodiesterase (EC 3.1.4.14)']}
# {'RAST': ['S-adenosylmethionine:tRNA ribosyltransferase-isomerase (EC 2.4.99.17)']}
# {'RAST': ['Queuine tRNA-ribosyltransferase (EC 2.4.2.29)']}
# {'RAST': ['Protein translocase subunit YajC']}
# {'RAST': ['Protein translocase subunit SecD']}
# {'RAST': ['Protein translocase subunit SecF']}
# {'RAST': ['Uncharacterized protein YajD']}
# {'RAST': ['Nucleoside-specific channel-forming protein Tsx precursor']}
# {'RAST': ['Hypothetical lipoprotein yajI']}
# {'RAST': ['Ribonucleotide reductase transcriptional regulator NrdR']}
# {'RAST': ['Diaminohydroxyphosphoribosylaminopyrimidine deaminase (EC 3.5.4.26)', '5-amino-6-(5-phosphoribosylamino)uracil reductase (EC 1.1.1.193)']}
# {'RAST': ['6,7-dimethyl-8-ribityllumazine synthase (EC 2.5.1.78)']}
# {'RAST': ['Transcription termination protein NusB']}
# {'RAST': ['Thiamine-monophosphate kinase (EC 2.7.4.16)']}
# {'RAST': ['Phosphatidylglycerophosphatase A (EC 3.1.3.27)']}
# {'RAST': ['NADPH dependent aldo-keto reductase => YajO']}
# {'RAST': ['1-deoxy-D-xylulose 5-phosphate synthase (EC 2.2.1.7)']}
# {'RAST': ['(2E,6E)-farnesyl diphosphate synthase (EC 2.5.1.10)', ' Dimethylallyltransferase (EC 2.5.1.1)']}
# {'RAST': ['Exodeoxyribonuclease VII small subunit (EC 3.1.11.6)']}
# {'RAST': ['tRNA 4-thiouridine synthase (EC 2.8.1.4)', 'Rhodanese-like domain required for thiamine synthesis']}
# {'RAST': ['DJ-1/YajL/PfpI superfamily, includes chaperone protein YajL (former ThiJ), parkinsonism-associated protein DJ-1, peptidases PfpI, Hsp31']}
# {'RAST': ['2-dehydropantoate 2-reductase (EC 1.1.1.169)']}
# {'RAST': ['UPF0234 protein Yitk']}
# {'RAST': ['Inner membrane transport protein YajR']}
# {'RAST': ['Heme O synthase, protoheme IX farnesyltransferase, COX10-CtaB']}
# {'RAST': ['Cytochrome O ubiquinol oxidase subunit IV (EC 1.10.3.-)']}
# {'RAST': ['Cytochrome O ubiquinol oxidase subunit III (EC 1.10.3.-)']}
# {'RAST': ['Cytochrome O ubiquinol oxidase subunit I (EC 1.10.3.-)']}
# {'RAST': ['Cytochrome O ubiquinol oxidase subunit II (EC 1.10.3.-)']}
# {'RAST': ['AmpG permease']}
# {'RAST': ['Hypothetical lipoprotein YajG precursor']}
# {'RAST': ['Cell division protein BolA']}
# {'RAST': ['Cell division trigger factor (EC 5.2.1.8)']}
# {'RAST': ['ATP-dependent Clp protease proteolytic subunit ClpP (EC 3.4.21.92)']}
# {'RAST': ['ATP-dependent Clp protease ATP-binding subunit ClpX']}
# {'RAST': ['ATP-dependent protease La (EC 3.4.21.53) Type I']}
# {'RAST': ['DNA-binding protein HU-beta']}
# {'RAST': ['Peptidyl-prolyl cis-trans isomerase PpiD (EC 5.2.1.8)']}
# {'RAST': ['hypothetical protein']}
# {'RAST': ['4-hydroxybenzoyl-CoA thioesterase family active site']}
# {'RAST': ['7-cyano-7-deazaguanine synthase (EC 6.3.4.20)']}
# {'RAST': ['Uncharacterized substrate-biding protein YbaE']}
# {'RAST': ['HMP-PP hydrolase (pyridoxal phosphatase) Cof, detected in genetic screen for thiamin metabolic genes']}
# {'RAST': ['DNA-binding transcriptional activator DecR, AsnC family']}
# {'RAST': ['Efflux ABC transporter, permease/ATP-binding protein MdlA']}
# {'RAST': ['Efflux ABC transporter, permease/ATP-binding protein MdlB']}
# {'RAST': ['Nitrogen regulatory protein P-II, GlnK']}
# {'RAST': ['Ammonium transporter']}
# {'RAST': ['Acyl-CoA thioesterase II (EC 3.1.2.-)']}
# {'RAST': ['Uncharacterized lipoprotein YbaY']}
# {'RAST': ['DNA base-flipping protein']}
# {'RAST': ['Protein of unknown function DUF1428']}
# {'RAST': ['c-di-GMP phosphodiesterase (EC 3.1.4.52) => PdeB']}
# {'RAST': ['Inner membrane protein YlaC']}
# {'RAST': ['Maltose O-acetyltransferase (EC 2.3.1.79)']}
# {'RAST': ['Haemolysin expression modulating protein']}
# {'RAST': ['Hha toxicity modulator TomB']}
# {'RAST': ['Multidrug efflux system AcrAB-TolC, inner-membrane proton/drug antiporter AcrB (RND type)']}
# {'RAST': ['Multidrug efflux system AcrAB-TolC, membrane fusion component AcrA']}
# {'RAST': ['Transcriptional regulator of acrAB operon, AcrR']}
# {'RAST': ['Mechanosensitive channel MscK']}
# {'RAST': ['Uncharacterized protein YbaM']}
# {'RAST': ['Primosomal replication protein N prime prime']}
# {'RAST': ['Inner membrane protein YbaN']}
# {'RAST': ['Adenine phosphoribosyltransferase (EC 2.4.2.7)']}
# {'RAST': ['DNA polymerase III subunits gamma and tau (EC 2.7.7.7)']}
# {'RAST': ['Nucleoid-associated protein YaaK']}
# {'RAST': ['Recombination protein RecR']}
# {'RAST': ['Chaperone protein HtpG']}
# {'RAST': ['Adenylate kinase (EC 2.7.4.3)']}
# {'RAST': ['Ferrochelatase, protoheme ferro-lyase (EC 4.99.1.1)']}
# {'RAST': ['Acetyl esterase (EC 3.1.1.-)']}
# {'RAST': ['Inosine-guanosine kinase (EC 2.7.1.73)']}
# {'RAST': ['Inner membrane protein YbaL, KefB/KefC family']}
# {'RAST': ['Fosmidomycin resistance protein']}
# {'RAST': ['UDP-sugar hydrolase (EC 3.6.1.45)', "5'-nucleotidase (EC 3.1.3.5)"]}
# {'RAST': ['Cys-tRNA(Pro) deacylase YbaK']}
# {'RAST': ['Uncharacterized protein YbaP']}
# {'RAST': ['Antitoxin HigA']}
# {'RAST': ['Lead, cadmium, zinc and mercury transporting ATPase (EC 3.6.3.3) (EC 3.6.3.5)', 'Copper-translocating P-type ATPase (EC 3.6.3.4)']}
# {'RAST': ['Glutaminase (EC 3.5.1.2)']}
# {'RAST': ['Inner membrane transport protein YbaT']}
# {'RAST': ['Copper resistance transcriptional regulator CueR (MerR family)']}
# {'RAST': ['Putative activity regulator of membrane protease YbbK']}
# {'RAST': ['Protein QmcA (possibly involved in integral membrane quality control)']}
# {'RAST': ['Probable iron export ATP-binding protein FetA']}
# {'RAST': ['Probable iron export permease protein FetB']}
# {'RAST': ['FIG000875: Thioredoxin domain-containing protein EC-YbbN']}
# {'RAST': ['Putative NAD(P)-dependent oxidoreductase EC-YbbO']}
# {'RAST': ['Multifunctional acyl-CoA thioesterase I, protease I, lysophospholipase L1']}
# {'RAST': ['Uncharacterized metabolite ABC transporter in Enterobacteriaceae, ATP-binding protein EC-YbbA']}
# {'RAST': ['Uncharacterized metabolite ABC transporter in Enterobacteriaceae, permease protein EC-YbbP']}
# {'RAST': ['Protein RhsD']}
# {'RAST': ['Uncharacterized protein YbbC']}
# {'RAST': ['Selenophosphate-dependent tRNA 2-selenouridine synthase']}
# {'RAST': ['Transcriptional regulator AllS, LysR family']}
# {'RAST': ['Ureidoglycolate lyase (EC 4.3.2.3)']}
# {}
# {'RAST': ['Glyoxylate carboligase (EC 4.1.1.47)']}
# {'RAST': ['Hydroxypyruvate isomerase (EC 5.3.1.22)']}
# {'RAST': ['2-hydroxy-3-oxopropionate reductase (EC 1.1.1.60)']}
# {'RAST': ['Allantoin permease']}
# {'RAST': ['Allantoinase (EC 3.5.2.5)']}
# {'RAST': ['Putative purine permease YbbY']}
# {'RAST': ['Glycerate kinase (EC 2.7.1.31)']}
# {'RAST': ['Ureidoglycine aminohydrolase']}
# {'RAST': ['Allantoate amidohydrolase (EC 3.5.3.9)']}
# {'RAST': ['Ureidoglycolate dehydrogenase (EC 1.1.1.154)']}
# {'RAST': ['Membrane protein FdrA']}
# {'RAST': ['Uncharacterized protein YlbF']}
# {'RAST': ['Carbamate kinase (EC 2.7.2.2)']}
# {'RAST': ['N5-carboxyaminoimidazole ribonucleotide synthase (EC 6.3.4.18)']}
# {'RAST': ['N5-carboxyaminoimidazole ribonucleotide mutase (EC 5.4.99.18)']}
# {'RAST': ['UDP-2,3-diacylglucosamine diphosphatase (EC 3.6.1.54)']}
# {'RAST': ['Peptidyl-prolyl cis-trans isomerase PpiB (EC 5.2.1.8)']}
# {'RAST': ['Cysteinyl-tRNA synthetase (EC 6.1.1.16)']}
# {'RAST': ['Inner membrane protein YbcI']}
# {'RAST': ['Uncharacterized S4 RNA-binding-domain protein YbcJ']}
# {'RAST': ['Methenyltetrahydrofolate cyclohydrolase (EC 3.5.4.9)', 'Methylenetetrahydrofolate dehydrogenase (NADP+) (EC 1.5.1.5)']}
# {'RAST': ['Uncharacterized fimbrial-like protein SfmA']}
# {'RAST': ['Probable fimbrial chaperone SfmC']}
# {'RAST': ['Outer membrane usher protein SfmD']}
# {'RAST': ['Uncharacterized fimbrial-like protein SfmH']}
# {'RAST': ['Uncharacterized fimbrial-like protein SfmF']}
# {'RAST': ['Transcriptional regulator of fimbriae expression FimZ (LuxR/UhpA family)']}
# {'RAST': ['Phage integrase']}
# {'RAST': ['Transposase InsE for insertion sequence IS3E']}
# {'RAST': ['Transposase InsF for insertion sequence IS3', ' Mobile element protein']}
# {'RAST': ['Small multidrug resistance (SMR) efflux transporter => EmrE, broad substrate specificity']}
# {'RAST': ['Uncharacterized protein YbcK']}
# {'RAST': ['UPF0098 protein ybcL precursor']}
# {'RAST': ['Uncharacterized transcriptional regulator YbcM, AraC family']}
# {'RAST': ['Uncharacterized protein YbcN']}
# {'RAST': ['Phage protein NinE']}
# {'RAST': ['Uncharacterized protein YbcO']}
# {'RAST': ['Holliday junction resolvase', 'Crossover junction endodeoxyribonuclease rusA (EC 3.1.22.-)']}
# {'RAST': ['Phage antitermination protein Q']}
# {'RAST': ['Transposase InsH for insertion sequence element IS5']}
# {'RAST': ['Phage holin/antiholin component S']}
# {'RAST': ['Phage lysozyme R (EC 3.2.1.17)']}
# {'RAST': ['Phage endopeptidase Rz']}
# {'RAST': ['Phage-encoded virulence determinant Bor']}
# {'RAST': ['Phage protein YbcV']}
# {'RAST': ['Phage protein YbcW']}
# {'RAST': ['Phage head, terminase subunit Nu1']}
# {'RAST': ['Acid phosphatase transcriptional regulator AppY, AraC family']}
# {'RAST': ['Protease VII (Omptin) precursor (EC 3.4.23.49)', ' Outer membrane protease OmpT']}
# {'RAST': ['Porin thermoregulatory protein envY']}
# {'RAST': ['Uncharacterized protein YbcH']}
# {'RAST': ['Bacteriophage N4 adsorption protein A']}
# {'RAST': ['Bacteriophage N4 adsorption protein B']}
# {'RAST': ['Copper sensory histidine kinase CusS']}
# {'RAST': ['Copper-sensing two-component system response regulator CusR']}
# {'RAST': ['Copper/silver efflux RND transporter, outer membrane protein CusC']}
# {'RAST': ['Copper/silver efflux RND transporter, periplasmic protein CusF']}
# {'RAST': ['Copper/silver efflux RND transporter, membrane fusion protein CusB']}
# {'RAST': ['Copper/silver efflux RND transporter, transmembrane protein CusA']}
# {'RAST': ['Phenylalanine-specific permease']}
# {'RAST': ['Miniconductance mechanosensitive channel YbdG']}
# {'RAST': ['Oxygen-insensitive NAD(P)H nitroreductase (EC 1.-.-.-)', 'Dihydropteridine reductase (EC 1.5.1.34)']}
# {'RAST': ['Uncharacterized protein YbdF']}
# {'RAST': ['Uncharacterized inner membrane protein YbdJ']}
# {'RAST': ['Glutamate--cysteine ligase-like protein YbdK']}
# {'RAST': ['Transposase InsL for insertion sequence element IS186']}
# {'RAST': ["4'-phosphopantetheinyl transferase (EC 2.7.8.-) [enterobactin] siderophore"]}
# {'RAST': ['TonB-dependent receptor', 'Outer membrane receptor for ferric enterobactin and colicins B, D']}
# {'RAST': ['Enterobactin esterase']}
# {'RAST': ['Enterobactin synthetase component F, serine activating enzyme (EC 2.7.7.-)']}
# {'RAST': ['Ferric enterobactin uptake protein FepE']}
# {'RAST': ['Ferric enterobactin transport ATP-binding protein FepC (TC 3.A.1.14.2)']}
# {'RAST': ['Ferric enterobactin transport system permease protein FepG (TC 3.A.1.14.2)']}
# {'RAST': ['Ferric enterobactin transport system permease protein FepD (TC 3.A.1.14.2)']}
# {'RAST': ['Enterobactin exporter EntS']}
# {'RAST': ['Ferric enterobactin-binding periplasmic protein FepB (TC 3.A.1.14.2)']}
# {'RAST': ['Isochorismate synthase (EC 5.4.4.2)', ' Isochorismate synthase (EC 5.4.4.2) [enterobactin] siderophore', ' Isochorismate synthase (EC 5.4.4.2) of siderophore biosynthesis']}
# {'RAST': ['2,3-dihydroxybenzoate-AMP ligase (EC 2.7.7.58) [enterobactin] siderophore', ' 2,3-dihydroxybenzoate-AMP ligase (EC 2.7.7.58) of siderophore biosynthesis']}
# {'RAST': ['Isochorismatase (EC 3.3.2.1) [enterobactin] siderophore', 'Apo-aryl carrier domain of EntB', ' Isochorismatase (EC 3.3.2.1) of siderophore biosynthesis']}
# {'RAST': ['2,3-dihydro-2,3-dihydroxybenzoate dehydrogenase (EC 1.3.1.28) [enterobactin] siderophore', ' 2,3-dihydro-2,3-dihydroxybenzoate dehydrogenase (EC 1.3.1.28) of siderophore biosynthesis']}
# {'RAST': ['Proofreading thioesterase in enterobactin biosynthesis EntH']}
# {'RAST': ['Carbon starvation protein A']}
# {'RAST': ['Hydroxycarboxylate dehydrogenase (NADP+) HcxA']}
# {'RAST': ['Glutamine-dependent 2-keto-4-methylthiobutyrate transaminase']}
# {'RAST': ['Co-activator of prophage gene expression IbrB']}
# {'RAST': ['Co-activator of prophage gene expression IbrA']}
# {'RAST': ['LysR-family transcriptional regulator YbdO']}
# {'RAST': ['Thiol:disulfide interchange protein DsbG precursor']}
# {'RAST': ['Alkyl hydroperoxide reductase protein C (EC 1.11.1.15)']}
# {'RAST': ['Alkyl hydroperoxide reductase protein F']}
# {'RAST': ['Universal stress protein G']}
# {'RAST': ['Uncharacterized zinc-type alcohol dehydrogenase-like protein YbdR']}
# {'RAST': ['Regulator of nucleoside diphosphate kinase']}
# {'RAST': ['Ribonuclease I precursor (EC 3.1.27.6)']}
# {'RAST': ['Citrate Succinate antiporter (TC 2.A.47.3.2)']}
# {'RAST': ['Triphosphoribosyl-dephospho-CoA synthase (EC 2.4.2.52)']}
# {'RAST': ['Citrate lyase holo-[acyl-carrier-protein] synthase (EC 2.7.7.61)']}
# {'RAST': ['Citrate lyase alpha chain (EC 4.1.3.6)']}
# {'RAST': ['Citrate lyase beta chain (EC 4.1.3.6)']}
# {'RAST': ['Citrate lyase gamma chain, acyl carrier protein']}
# {'RAST': ['[Citrate [pro-3S]-lyase] ligase (EC 6.2.1.22)']}
# {'RAST': ['Tricarboxylate transport sensor protein TctE => Citrate response regulator CitA']}
# {'RAST': ['Tricarboxylate transport transcriptional regulator TctD => Citrate response regulator CitB']}
# {'RAST': ['C4-dicarboxylate transporter DcuC (TC 2.A.61.1.1)']}
# {'RAST': ['Lipid A palmitoyltransferase PagP (EC 2.3.1.251)']}
# {'RAST': ['Cold shock protein of CSP family => CspE (naming convention as in E.coli)']}
# {'RAST': ['Fluoride ion transporter CrcB']}
# {'RAST': ['Twin-arginine translocation protein TatE']}
# {'RAST': ['Lipoyl synthase (EC 2.8.1.8)']}
# {'RAST': ['LysR-family transcriptional regulator YbeF']}
# {'RAST': ['Octanoate-[acyl-carrier-protein]-protein-N-octanoyltransferase (EC 2.3.1.181)']}
# {'RAST': ['Proposed lipoate regulatory protein YbeD']}
# {'RAST': ['D-alanyl-D-alanine carboxypeptidase (EC 3.4.16.4)']}
# {'RAST': ['Septum-associated rare lipoprotein A']}
# {'RAST': ['Rod shape-determining protein RodA']}
# {'RAST': ['Peptidoglycan D,D-transpeptidase MrdA (EC 3.4.16.4)']}
# {'RAST': ['23S rRNA (pseudouridine(1915)-N(3))-methyltransferase (EC 2.1.1.177)']}
# {'RAST': ['Ribosomal silencing factor RsfA']}
# {'RAST': ["Alpha-ribazole-5'-phosphate phosphatase (EC 3.1.3.73)"]}
# {'RAST': ['Nicotinate-nucleotide adenylyltransferase (EC 2.7.7.18)']}
# {'RAST': ['DNA polymerase III delta subunit (EC 2.7.7.7)']}
# {'RAST': ['LPS-assembly lipoprotein LptE']}
# {'RAST': ['Leucyl-tRNA synthetase (EC 6.1.1.4)']}
# {'RAST': ['Uncharacterized protein YbeL']}
# {'RAST': ['Uncharacterized protein YbeQ']}
# {'RAST': ['Uncharacterized protein YbeR']}
# {'RAST': ['Uncharacterized J domain-containing protein YbeS, predicted chaperone']}
# {'RAST': ['Uncharacterized protein YbeT']}
# {'RAST': ['Uncharacterized protein YbeU']}
# {'RAST': ['Uncharacterized J domain-containing protein YbeV']}
# {'RAST': ['Chaperone protein HscC']}
# {'RAST': ['Pyrimidine-specific ribonucleoside hydrolase RihA']}
# {'RAST': ['Glutamate/aspartate ABC transporter, ATP-binding protein GltL (TC 3.A.1.3.4)']}
# {'RAST': ['Glutamate/aspartate ABC transporter, permease protein GltK (TC 3.A.1.3.4)']}
# {'RAST': ['Glutamate/aspartate ABC transporter, permease protein GltJ (TC 3.A.1.3.4)']}
# {'RAST': ['Glutamate/aspartate ABC transporter, substrate-binding protein GltI (TC 3.A.1.3.4)']}
# {'RAST': ['Transposase InsH for insertion sequence element IS5']}
# {'RAST': ['Apolipoprotein N-acyltransferase', 'Copper homeostasis protein CutE']}
# {'RAST': ['Magnesium and cobalt efflux protein CorC']}
# {'RAST': ['Metal-dependent hydrolase YbeY, involved in rRNA and/or ribosome maturation and assembly']}
# {'RAST': ['Phosphate starvation-inducible protein PhoH, predicted ATPase']}
# {'RAST': ['tRNA-i(6)A37 methylthiotransferase (EC 2.8.4.3)']}
# {'RAST': ['2-polyprenyl-3-methyl-6-methoxy-1,4-benzoquinol hydroxylase']}
# {'RAST': ['Asparagine synthetase [glutamine-hydrolyzing] (EC 6.3.5.4)']}
# {'RAST': ['Phosphatase NagD predicted to act in N-acetylglucosamine utilization subsystem']}
# {'RAST': ['N-acetylglucosamine-6P-responsive transcriptional repressor NagC, ROK family']}
# {'RAST': ['N-acetylglucosamine-6-phosphate deacetylase (EC 3.5.1.25)']}
# {'RAST': ['Glucosamine-6-phosphate deaminase (EC 3.5.99.6)']}
# {'RAST': ['PTS system, N-acetylglucosamine-specific IIC component', 'PTS system, N-acetylglucosamine-specific IIB component (EC 2.7.1.193)', 'PTS system, N-acetylglucosamine-specific IIA component (EC 2.7.1.193)']}
# {'RAST': ['Glutaminyl-tRNA synthetase (EC 6.1.1.18)']}
# {'RAST': ['Outer membrane porin for chitooligosaccharides ChiP']}
# {'RAST': ['Uncharacterized lipoprotein ChiQ']}
# {'RAST': ['Ferric uptake regulation protein FUR']}
# {'RAST': ['Flavodoxin 1']}
# {'RAST': ['Uncharacterized protein YbfE']}
# {'RAST': ['Esterase ybfF (EC 3.1.-.-)']}
# {'RAST': ['SeqA protein, negative modulator of initiation of replication']}
# {'RAST': ['Phosphoglucomutase (EC 5.4.2.2)']}
# {'RAST': ['Hypothetical lipoprotein ybfP precursor']}
# {'RAST': ['Putrescine/proton symporter, putrescine/ornithine antiporter PotE']}
# {'RAST': ['Ornithine decarboxylase (EC 4.1.1.17)']}
# {'RAST': ['DNA-binding response regulator KdpE']}
# {'RAST': ['Osmosensitive K+ channel histidine kinase KdpD']}
# {'RAST': ['Potassium-transporting ATPase C chain (EC 3.6.3.12) (TC 3.A.3.7.1)']}
# {'RAST': ['Potassium-transporting ATPase B chain (EC 3.6.3.12) (TC 3.A.3.7.1)']}
# {'RAST': ['Potassium-transporting ATPase A chain (EC 3.6.3.12) (TC 3.A.3.7.1)']}
# {'RAST': ['Uncharacterized protein YbfA']}
# {'RAST': ['Protein RhsC']}
# {}
# {'RAST': ['Uncharacterized protein YbfC']}
# {'RAST': ['H repeat-associated protein, YhhI family']}
# {'RAST': ['FIG143828: Hypothetical protein YbgA']}
# {'RAST': ['Deoxyribodipyrimidine photolyase (EC 4.1.99.3)']}
# {'RAST': ['Dipeptide/H+ symporter DtpD']}
# {'RAST': ['GTP cyclohydrolase 1 type 2 homolog YbgI']}
# {'RAST': ['Allophanate hydrolase 2 subunit 1 (EC 3.5.1.54)']}
# {'RAST': ['Allophanate hydrolase 2 subunit 2 (EC 3.5.1.54)']}
# {'RAST': ['Lactam utilization protein LamB']}
# {'RAST': ['Endonuclease VIII']}
# {'RAST': ['AbrB protein']}
# {'RAST': ['Uncharacterized fimbrial-system-associated protein YbgO']}
# {'RAST': ['Uncharacterized fimbrial chaperone YbgP']}
# {'RAST': ['Uncharacterized outer membrane usher protein YbgQ']}
# {'RAST': ['Uncharacterized fimbrial-like protein YbgD']}
# {'RAST': ['Citrate synthase (si) (EC 2.3.3.1)']}
# {'RAST': ['Succinate dehydrogenase cytochrome b-556 subunit']}
# {'RAST': ['Succinate dehydrogenase hydrophobic membrane anchor protein']}
# {'RAST': ['Succinate dehydrogenase flavoprotein subunit (EC 1.3.5.1)']}
# {'RAST': ['Succinate dehydrogenase iron-sulfur protein (EC 1.3.5.1)']}
# {'RAST': ['2-oxoglutarate dehydrogenase E1 component (EC 1.2.4.2)']}
# {'RAST': ['Dihydrolipoamide succinyltransferase component (E2) of 2-oxoglutarate dehydrogenase complex (EC 2.3.1.61)']}
# {'RAST': ['Succinyl-CoA ligase [ADP-forming] beta chain (EC 6.2.1.5)']}
# {'RAST': ['Succinyl-CoA ligase [ADP-forming] alpha chain (EC 6.2.1.5)']}
# {'RAST': ['Transcriptional regulator of succinyl CoA synthetase operon']}
# {'RAST': ['PTS system, 2-O-alpha-mannosyl-D-glycerate-specific IIA component (EC 2.7.1.195)', 'PTS system, 2-O-alpha-mannosyl-D-glycerate-specific IIB component (EC 2.7.1.195)', 'PTS system, 2-O-alpha-mannosyl-D-glycerate-specific IIC component']}
# {'RAST': ['Mannosylglycerate hydrolase (EC 3.2.1.170)']}
# {'RAST': ['Cytochrome d ubiquinol oxidase subunit I (EC 1.10.3.-)']}
# {'RAST': ['Cytochrome d ubiquinol oxidase subunit II (EC 1.10.3.-)']}
# {'RAST': ['Cyd operon protein YbgE']}
# {'RAST': ['Tol-Pal system-associated acyl-CoA thioesterase']}
# {'RAST': ['Tol-Pal system protein TolQ']}
# {'RAST': ['Tol biopolymer transport system, TolR protein']}
# {'RAST': ['TolA protein']}
# {'RAST': ['Tol-Pal system beta propeller repeat protein TolB']}
# {'RAST': ['Tol-Pal system peptidoglycan-associated lipoprotein PAL']}
# {'RAST': ['Cell division coordinator CpoB']}
# {'RAST': ['Quinolinate synthetase (EC 2.5.1.72)']}
# {'RAST': ['Ribosyl nicotinamide transporter, PnuC-like']}
# {'RAST': ['Zinc transporter ZitB']}
# {'RAST': ['putative secreted protein']}
# {'RAST': ['2-keto-3-deoxy-D-arabino-heptulosonate-7-phosphate synthase I alpha (EC 2.5.1.54)']}
# {'RAST': ['Phosphoglycerate mutase (EC 5.4.2.11)']}
# {'RAST': ['Aldose 1-epimerase (EC 5.1.3.3)']}
# {'RAST': ['Galactokinase (EC 2.7.1.6)']}
# {'RAST': ['Galactose-1-phosphate uridylyltransferase (EC 2.7.7.10)']}
# {'RAST': ['UDP-glucose 4-epimerase (EC 5.1.3.2)']}
# {'RAST': ['Putative molybdenum transport ATP-binding protein modF']}
# {'RAST': ['DNA-binding domain of ModE', 'Molybdate-binding domain of ModE']}
# {'RAST': ['AcrZ membrane protein associated with AcrAB-TolC multidrug efflux pump']}
# {'RAST': ['Molybdenum ABC transporter, substrate-binding protein ModA']}
# {'RAST': ['Molybdenum ABC transporter permease protein ModB']}
# {'RAST': ['Molybdenum ABC transporter ATP-binding protein ModC']}
# {'RAST': ['Phosphatase YbhA (EC 3.1.3.-)']}
# {'RAST': ['6-phosphogluconolactonase (EC 3.1.1.31)']}
# {'RAST': ['Transcriptional regulator YbhD, LysR family']}
# {'RAST': ['Hypothetical protein YbhH, similar to PrpF protein involved in 2-methylcitrate cycle']}
# {'RAST': ['Inner membrane protein YbhI']}
# {'RAST': ['Aconitase family protein YbhJ']}
# {'RAST': ['Pectinesterase (EC 3.1.1.11)']}
# {'RAST': ['UPF0098 protein ybhB']}
# {'RAST': ['Adenosylmethionine-8-amino-7-oxononanoate aminotransferase (EC 2.6.1.62)']}
# {'RAST': ['Biotin synthase (EC 2.8.1.6)']}
# {'RAST': ['8-amino-7-oxononanoate synthase (EC 2.3.1.47)']}
# {'RAST': ['Malonyl-[acyl-carrier protein] O-methyltransferase (EC 2.1.1.197)']}
# {'RAST': ['Dethiobiotin synthase BioD (EC 6.3.3.3)']}
# {'RAST': ['Excinuclease ABC subunit B']}
# {}
# {'RAST': ["GTP 3',8-cyclase (EC 4.1.99.22)"]}
# {'RAST': ['Molybdenum cofactor biosynthesis protein MoaB']}
# {'RAST': ['Cyclic pyranopterin monophosphate synthase (EC 4.6.1.17)']}
# {'RAST': ['Molybdopterin synthase sulfur carrier subunit']}
# {'RAST': ['Molybdopterin synthase catalytic subunit MoaE (EC 2.8.1.12)']}
# {'RAST': ['Inner membrane protein YbhL']}
# {'RAST': ['Uncharacterized protein YbhM']}
# {'RAST': ['Inner membrane protein YbhQ']}
# {'RAST': ['Cardiolipin synthase (EC 2.7.8.-) bacterial type ClsB, has minor trans-phosphatidylation activity converting PE to PG']}
# {'RAST': ['Endonuclease/exonuclease/phosphatase family protein']}
# {'RAST': ['Inner membrane protein YbhQ']}
# {'RAST': ['ABC-type efflux pump permease component YbhR']}
# {'RAST': ['ABC-type efflux pump permease component YbhS']}
# {'RAST': ['ABC-type efflux pump, duplicated ATPase component YbhF']}
# {'RAST': ['ABC-type efflux pump membrane fusion component YbhG']}
# {'RAST': ['Transcriptional regulator YbiH, TetR family']}
# {'RAST': ['ATP-dependent RNA helicase RhlE (EC 3.6.4.13)']}
# {'RAST': ['Uncharacterized protein COG3236']}
# {'RAST': ['ATP-dependent helicase DinG/Rad3']}
# {'RAST': ['Anthranilate phosphoribosyltransferase-like protein']}
# {'RAST': ['Hydroxycarboxylate dehydrogenase (NADP+) HcxB']}
# {'RAST': ['Uncharacterized periplasmic protein YbiJ']}
# {'RAST': ['Uncharacterized zinc-finger containing protein YbiI']}
# {'RAST': ['PKHD-type hydroxylase YbiX']}
# {'RAST': ['Ferrichrome-iron receptor']}
# {'RAST': ['Uncharacterized periplasmic protein McbA']}
# {'RAST': ['23S rRNA (adenine(1618)-N(6))-methyltransferase (EC 2.1.1.181)']}
# {'RAST': ['Potassium efflux system KefA protein', 'Small-conductance mechanosensitive channel']}
# {'RAST': ['Glutamine ABC transporter, ATP-binding protein GlnQ']}
# {'RAST': ['Glutamine ABC transporter, permease protein GlnP']}
# {'RAST': ['Glutamine ABC transporter, substrate-binding protein GlnH']}
# {'RAST': ['DNA protection during starvation protein']}
# {'RAST': ['Threonine/homoserine exporter RhtA']}
# {'RAST': ['Outer membrane protein X precursor']}
# {'RAST': ['Phosphoethanolamine transferase OpgE']}
# {'RAST': ['Mn-dependent transcriptional regulator MntR']}
# {'RAST': ['Inner membrane protein YbiR, putative anion permease']}
# {'RAST': ['L,D-transpeptidase => YbiS']}
# {'RAST': ['Bis-ABC ATPase YbiT']}
# {'RAST': ['Uncharacterized protein YbiU']}
# {'RAST': ['Sugar phosphatase YbiV']}
# {'RAST': ['Pyruvate formate-lyase (EC 2.3.1.54)']}
# {'RAST': ['Pyruvate formate-lyase activating enzyme (EC 1.97.1.4)']}
# {'RAST': ['Fructose-6-phosphate aldolase']}
# {'RAST': ['Molybdopterin-synthase adenylyltransferase (EC 2.7.7.80)']}
# {'RAST': ['Molybdopterin molybdenumtransferase (EC 2.10.1.1)']}
# {'RAST': ['Isoaspartyl aminopeptidase (EC 3.4.19.5)', ' Asp-X dipeptidase']}
# {'RAST': ['Oligopeptide transport ATP-binding protein', ' Glutathione ABC transporter, ATP-binding protein GsiA']}
# {'RAST': ['Oligopeptide transport substrate-binding protein', ' Glutathione ABC transporter, substrate-binding protein GsiB']}
# {'RAST': ['Oligopeptide transport permease protein OppB-like', ' Glutathione ABC transporter, permease protein GsiC']}
# {'RAST': ['Oligopeptide transport permease protein OppC-like', ' Glutathione ABC transporter, permease protein GsiD']}
# {'RAST': ['c-di-GMP phosphodiesterase (EC 3.1.4.52) => PdeI']}
# {'RAST': ['Diguanylate cyclase (EC 2.7.7.65) => DgcI']}
# {'RAST': ['Ribosomal protein S12p Asp88 (E. coli) methylthiotransferase (EC 2.8.4.4)']}
# {'RAST': ['Biofilm regulator BssR']}
# {'RAST': ['Soluble aldose sugar dehydrogenase, PQQ-dependent (EC 1.1.5.-)']}
# {'RAST': ['Uncharacterized glutathione S-transferase-like protein']}
# {'RAST': ['D-alanyl-D-alanine carboxypeptidase (EC 3.4.16.4)']}
# {'RAST': ['Deoxyribose operon repressor DeoR']}
# {'RAST': ['Undecaprenyl-diphosphatase BcrC (EC 3.6.1.27), conveys bacitracin resistance']}
# {'RAST': ['Multidrug efflux pump MdfA/Cmr (of MFS type), broad spectrum']}
# {'RAST': ['Uncharacterized protein YbjH']}
# {'RAST': ['5-amino-6-(5-phospho-D-ribitylamino)uracil phosphatase YbjI']}
# {'RAST': ['Inner membrane protein YbjJ']}
# {'RAST': ['HTH-type transcriptional regulator RcdA']}
# {'RAST': ['Putative transport protein YbjL']}
# {'RAST': ['Inner membrane protein YbjM']}
# {'RAST': ['Glutaredoxin 1']}
# {'RAST': ['Uncharacterized protein YbjC']}
# {'RAST': ['Oxygen-insensitive NADPH nitroreductase (EC 1.-.-.-)']}
# {'RAST': ['Ribosomal protein S6--L-glutamate ligase']}
# {'RAST': ['Uncharacterized sensory transduction regulator YbjN']}
# {'RAST': ['Putrescine ABC transporter putrescine-binding protein PotF (TC 3.A.1.11.2)']}
# {'RAST': ['Putrescine transport ATP-binding protein PotG (TC 3.A.1.11.2)']}
# {'RAST': ['Putrescine transport system permease protein PotH (TC 3.A.1.11.2)']}
# {'RAST': ['Putrescine transport system permease protein PotI (TC 3.A.1.11.2)']}
# {'RAST': ['Inner membrane protein YbjO']}
# {'RAST': ['23S rRNA (uracil(747)-C(5))-methyltransferase (EC 2.1.1.189)']}
# {'RAST': ['Arginine ABC transporter, substrate-binding protein ArtJ']}
# {'RAST': ['Arginine ABC transporter, permease protein ArtM']}
# {'RAST': ['Arginine ABC transporter, permease protein ArtQ']}
# {'RAST': ['Arginine ABC transporter, substrate-binding protein ArtI']}
# {'RAST': ['Arginine ABC transporter, ATP-binding protein ArtP']}
# {'RAST': ['Uncharacterized lipoprotein YbjP']}
# {'RAST': ['UPF0145 protein YbjQ']}
# {'RAST': ['N-acetylmuramoyl-L-alanine amidase (EC 3.5.1.28)', ' 1,6-anhydro-N-acetylmuramyl-L-alanine amidase']}
# {'RAST': ['Uncharacterized NAD(P)-dependent epimerase/dehydratase family protein YbjS']}
# ...
# {'RAST': ['Lipoate-protein ligase A']}
# {'RAST': ['Protein Smp']}
# {'RAST': ['Phosphoserine phosphatase (EC 3.1.3.3)']}
# {'RAST': ['DNA repair protein RadA']}
# {'RAST': ['NadR transcriptional regulator', 'Nicotinamide-nucleotide adenylyltransferase, NadR family (EC 2.7.7.1)', 'Ribosylnicotinamide kinase (EC 2.7.1.22)']}
# {'RAST': ['Energy-dependent translational throttle protein EttA']}
# {'RAST': ['Soluble lytic murein transglycosylase (EC 4.2.2.n1)']}
# {'RAST': ['Transcriptional repressor protein TrpR']}
# {'RAST': ['Inosine/xanthosine triphosphatase']}
# {'RAST': ['Phosphoglycerate mutase (EC 5.4.2.11)']}
# {'RAST': ['DNA-binding transcriptional dual regulator Rob']}
# {'RAST': ['Conserved uncharacterized protein CreA']}
# {'RAST': ['Response regulator CreB of two-component signal transduction system CreBC']}
# {'RAST': ['Sensory histidine kinase CreC of two-component signal transduction system CreBC']}
# {'RAST': ['Inner membrane protein CreD']}
# {'RAST': ['Aerobic respiration control response regulator ArcA']}
# {'RAST': ['Uncharacterized protein YjjY']}
# {'RAST': ['Uncharacterized tRNA/rRNA methyltransferase LasT']}
# {}
# {}
# {'RAST': ['hypothetical protein']}
# {'RAST': ['Cytochrome d ubiquinol oxidase subunit X (EC 1.10.3.-)']}
# {}
# {}
# {'RAST': ['hypothetical protein']}
# {'RAST': ['UPF0509 protein YciZ']}
# {}
# {'RAST': ['hypothetical protein']}
# {}
# {'RAST': ['hypothetical protein']}
# {}
# {}
# {}
# {}
# {'RAST': ['hypothetical protein']}
# {'RAST': ['Uncharacterized protein YtcA']}
# {}
# {}
# {'RAST': ['Sugar-phosphate stress protein SgrT (embedded in SgrS)']}
# {'RAST': ['hypothetical protein']}
# {}
# {}
# {'RAST': ['hypothetical protein']}
# {'RAST': ['hypothetical protein']}
# {'RAST': ['hypothetical protein']}
# {}
# {}
# {}
# {'RAST': ['Small toxic protein IbsA']}
# {'RAST': ['Small toxic protein IbsB']}
# {}
# {'RAST': ['hypothetical protein']}
# {'RAST': ['Small toxic protein ShoB']}
# {'RAST': ['hypothetical protein']}
# {'RAST': ['hypothetical protein']}
# {'RAST': ['hypothetical protein']}
# {}
# {}
# {}
# {}
# {}
# {'RAST': ['Uncharacterized protein YshB']}
# {}
# {'RAST': ['MgtA leader peptide']}
# {'RAST': ['Putative membrane protein PmrR']}
# {'RAST': ['Hca operon (3-phenylpropionic acid catabolism) transcriptional activator HcaR']}
# {'RAST': ['Uncharacterized protein YlbE']}
# {'RAST': ['hypothetical protein']}
# {}
# {'RAST': ['Uncharacterized protein YabP']}
# {}
# {}
# {}
# {}
# {'RAST': ['IS1 protein InsB']}
# {'RAST': ['IS1 protein InsA']}
# {'RAST': ['Retron-type RNA-directed DNA polymerase (EC 2.7.7.49)']}
# {'RAST': ['Uncharacterized protein YagB']}
# {}
# {'RAST': ['Putative uncharacterized protein YagJ']}
# {'RAST': ['hypothetical protein']}
# {'RAST': ['LysR family transcriptional regulator YagP']}
# {}
# {'RAST': ['hypothetical protein']}
# {}
# {'RAST': ['hypothetical protein']}
# {'RAST': ['DNA polymerase III subunits gamma and tau (EC 2.7.7.7)']}
# {'RAST': ['Lead, cadmium, zinc and mercury transporting ATPase (EC 3.6.3.3) (EC 3.6.3.5)', 'Copper-translocating P-type ATPase (EC 3.6.3.4)']}
# {'RAST': ['ISSod13, transposase']}
# {'RAST': ['hypothetical protein']}
# {'RAST': ['Phage tail fiber, tail fiber assembly protein Tfa']}
# {}
# {'RAST': ['hypothetical protein']}
# {'RAST': ['H repeat-associated protein, YhhI family']}
# {}
# {}
# {'RAST': ['hypothetical domain', 'Cold shock protein of CSP family => CspB/CspG/CspI (naming convention as in E.coli)']}
# {}
# {'RAST': ['Putative uncharacterized protein b1142']}
# {'RAST': ['Phage terminase, large subunit']}
# {'RAST': ['Phage portal protein']}
# {}
# {}
# {}
# {'RAST': ['Putative uncharacterized protein YchS']}
# {'RAST': ['Transposase InsH for insertion sequence element IS5']}
# {}
# {}
# {'RAST': ['Putative uncharacterized protein YmjC']}
# {}
# {'RAST': ['hypothetical protein']}
# {'RAST': ['Putative uncharacterized phage-associated protein, YdaW family']}
# {'RAST': ['Putative uncharacterized protein YdaY']}
# {'RAST': ['Phage tail, tail length tape-measure protein H']}
# {}
# {}
# {'RAST': ['Putative glycoportein']}
# {'RAST': ['Outer membrane porin OmpD']}
# {}
# {}
# {'RAST': ['Putative uncharacterized membrane protein YdeT']}
# {'RAST': ['Uncharacterized MFS-type transporter YdfJ']}
# {}
# {'RAST': ['Phage head, terminase subunit Nu1']}
# {}
# {'RAST': ['hypothetical domain', 'Cold shock protein of CSP family => CspB/CspG/CspI (naming convention as in E.coli)']}
# {}
# {'RAST': ['Transposase']}
# {'RAST': ['Phage activator protein cII']}
# {'RAST': ['Uncharacterized MFS-type transporter YdfJ']}
# {'RAST': ['hypothetical protein']}
# {}
# {'RAST': ['Uncharacterized protein YeeW']}
# {'RAST': ['Propanediol utilization protein PduV, truncated fragment']}
# {'RAST': ['Molybdate metabolism regulator']}
# {'RAST': ['Uncharacterized protein YehQ']}
# {}
# {'RAST': ['Phage protein']}
# {'RAST': ['Phage DNA N-6-adenine methyltransferase']}
# {'RAST': ['Phage DNA replication protein O']}
# {'RAST': ['Excisionase']}
# {}
# {'RAST': ['Uncharacterized protein YfgD, not an arsenate reductase']}
# {'RAST': ['Uncharacterized protein YpjB']}
# {'RAST': ['Uncharacterized UPF0750 membrane protein YpjC']}
# {'RAST': ['hypothetical protein']}
# {'RAST': ['Uncharacterized protein YgeP']}
# {}
# {}
# {'RAST': ['Uncharacterized protein YqgD']}
# {'RAST': ['Hypothetical protein associated with Serine palmitoyltransferase']}
# {'RAST': ['Dienelactone hydrolase family protein']}
# {'RAST': ['Probable 4-amino-4-deoxy-L-arabinose-phosphoundecaprenol flippase subunit ArnE']}
# {'RAST': ['Putative uncharacterized protein YzgL']}
# {'RAST': ['Uncharacterized protein YrhD']}
# {}
# {'RAST': ['Ribonuclease PH (EC 2.7.7.56)']}
# {'RAST': ["Maltose-6'-phosphate glucosidase (EC 3.2.1.122)"]}
# {'RAST': ['PTS system, maltose and glucose-specific IIC component', 'PTS system, maltose and glucose-specific IIB component (EC 2.7.1.208)']}
# {'RAST': ['PTS system, maltose and glucose-specific IIC component', 'PTS system, maltose and glucose-specific IIB component (EC 2.7.1.208)']}
# {}
# {'RAST': ['Putative rho operon leader peptide']}
# {'RAST': ['hypothetical protein']}
# {}
# {'RAST': ['orf', 'Unknown function']}
# {}
# {'RAST': ['Hypothetical protein b4563']}
# {'RAST': ['Putative uncharacterized protein YjiT']}
# {'RAST': ['Multimodular transpeptidase-transglycosylase (EC 2.4.1.129) (EC 3.4.-.-)']}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'RAST': ['NAD-dependent protein deacetylase of SIR2 family']}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'RAST': ['Uncharacterized N-acetyltransferase YjaB']}
# {'RAST': ['Chaperone protein ClpB (ATP-dependent unfoldase)']}
# {}
# {}
# {'RAST': ['General secretion pathway protein L']}
# {}
# {'RAST': ['General secretion pathway protein C']}
# {}
# {}
# {}
# {'RAST': ['hypothetical protein']}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'RAST': ['5-methylcytosine-specific restriction enzyme McrB']}
# {}
# {'RAST': ['Sugar efflux transporter A']}
# {'RAST': ['Acetolactate synthase large subunit (EC 2.2.1.6)']}
# {}
# {'RAST': ['Small inner membrane protein, YmgF family']}
# {'RAST': ['Small inner membrane protein, YmgF family']}
# {'RAST': ['Small inner membrane protein, YmgF family']}
# {'RAST': ['Oligopeptide ABC transporter, ATP-binding protein OppD (TC 3.A.1.5.1)']}
# {'RAST': ['Hok/Gef-like protein']}
# {'RAST': ['Altronate oxidoreductase (EC 1.1.1.58)']}
# {'RAST': ['beta-lactam resistance protein']}
# {'RAST': ['Outer membrane lipoprotein pcp precursor']}
# {'RAST': ['Oxidoreductase YdhF']}
# {'RAST': ['Inner membrane transport protein YdhC']}
# {'RAST': ['Multidrug efflux transporter MdtK/NorM (MATE family)']}
# {'RAST': ['Catalase KatE-intracellular protease (EC 1.11.1.6)']}
# {'RAST': ['Cytoplasmic copper homeostasis protein CutC']}
# {'RAST': ['Putative SOS response-associated peptidase YedK']}
# {'RAST': ['UPF0253 protein YaeP']}
# {'RAST': ['RNA chaperone ProQ']}
# {'RAST': ['L-arabinose ABC transporter, permease protein AraH']}
# {'RAST': ['Transposase InsC for insertion element IS2']}
# {'RAST': ['Antigen 43']}
# {'RAST': ['Sulfate transport system permease protein CysW']}
# {'RAST': ['Cysteine desulfurase (EC 2.8.1.7) => IscS']}
# {'RAST': ['Phosphoribosylformylglycinamidine synthase, synthetase subunit (EC 6.3.5.3)', 'Phosphoribosylformylglycinamidine synthase, glutamine amidotransferase subunit (EC 6.3.5.3)']}
# {'RAST': ['Putative membrane protein YfjD']}
# {'RAST': ['DNA repair protein RecN']}
# {'RAST': ['Uncharacterized protein YfjP']}
# {'RAST': ['hypothetical protein']}
# {'RAST': ['PTS system, glucitol/sorbitol-specific IIC component']}
# {'RAST': ['PTS system, glucitol/sorbitol-specific IIB component (EC 2.7.1.198)', 'PTS system, glucitol/sorbitol-specific IIC component 2']}
# {'RAST': ['PTS system, arbutin-, cellobiose-, and salicin-specific IIB component', 'PTS system, arbutin-, cellobiose-, and salicin-specific IIC component']}
# {'RAST': ['Predicted FAD containing dehydrogenase']}
# {'RAST': ['Aspartate/ornithine carbamoyltransferase family protein protein YgeW']}
# {'RAST': ['Guanine/hypoxanthine permease GhxQ']}
# {'RAST': ['Uncharacterized protein YggP']}
# {'RAST': ['Transketolase (EC 2.2.1.1)']}
# {'RAST': ['Putative lipoprotein AcfD-like']}
# {'RAST': ['Glycolate dehydrogenase (EC 1.1.99.14), iron-sulfur subunit GlcF']}
# {'RAST': ['Glycolate dehydrogenase (EC 1.1.99.14), FAD-binding subunit GlcE']}
# {'RAST': ['Inner membrane protein YghQ, probably involved in polysaccharide biosynthesis']}
# {'RAST': ['Uncharacterized protein YqhG']}
# {'RAST': ['UPF0313 [4Fe-4S] protein YgiQ']}
# {'RAST': ['Transcriptional regulator YgiV, AraC family']}
# {'RAST': ['Evolved beta-D-galactosidase, alpha subunit']}
# {'RAST': ['Inner membrane permease YgjI, clustered with evolved beta-galactosidase']}
# {'RAST': ['Alkaline induced inner membrane protein Alx']}
# {'RAST': ['UPF0597 protein YhaM']}
# {'RAST': ['Inner membrane transport protein YhaO']}
# {'RAST': ['L-serine dehydratase, beta subunit (EC 4.3.1.17)', 'L-serine dehydratase, alpha subunit (EC 4.3.1.17)']}
# {'RAST': ['2-ketobutyrate formate-lyase (EC 2.3.1.-)', ' Pyruvate formate-lyase (EC 2.3.1.54)']}
# {'RAST': ['Aerobic respiration control sensor protein ArcB (EC 2.7.13.3)']}
# {'RAST': ['Uncharacterized protein YhdP']}
# {'RAST': ['Amino acid ABC transporter, permease protein 1, YhdX']}
# {'RAST': ['Uncharacterized protein YrdD']}
# {'RAST': ['Rossmann fold nucleotide-binding protein Smf possibly involved in DNA uptake']}
# {'RAST': ['Nitrite transporter NirC']}
# {'RAST': ['Fructoselysine 3-epimerase']}
# {'RAST': ['Hypothetical protein YhfZ']}
# {'RAST': ['Shikimate kinase I (EC 2.7.1.71)']}
# {'RAST': ['Transcription elongation factor GreB']}
# {'RAST': ['High-affinity gluconate transporter GntT']}
# {'RAST': ['Maltodextrin phosphorylase (EC 2.4.1.1)']}
# {'RAST': ["RNA 3'-terminal phosphate cyclase (EC 6.5.1.4)"]}
# {'RAST': ['Rhomboid protease GlpG (EC 3.4.21.105)']}
# {'RAST': ['Low-affinity gluconate/H+ symporter GntU']}
# {'RAST': ['Gluconate utilization system Gnt-I transcriptional repressor']}
# {'RAST': ['Branched-chain amino acid ABC transporter, substrate-binding protein LivJ (TC 3.A.1.4.1)']}
# {'RAST': ['Protein RhsB']}
# {'RAST': ['Ribosome-associated ATPase RbbA']}
# {'RAST': ['Cellulose synthase operon protein C']}
# {'RAST': ['Small inner membrane protein, YmgF family']}
# {'RAST': ['Outer membrane porin, OmpA family']}
# {'RAST': ['Toxic component of a type I toxin-antitoxin system, HokA']}
# {'RAST': ['BAX protein']}
# {'RAST': ['Valine--pyruvate aminotransferase (EC 2.6.1.66)']}
# {'RAST': ['2,3-diketo-L-gulonate TRAP transporter large permease protein yiaN']}
# {'RAST': ['Alcohol dehydrogenase (EC 1.1.1.1)']}
# {'RAST': ['Galactonate dehydratase (EC 4.2.1.6)']}
# {'RAST': ['2-dehydro-3-deoxyphosphogalactonate aldolase (EC 4.1.2.21)']}
# {'RAST': ['D-Galactonate repressor DgoR']}
# {'RAST': ['Uncharacterized protein YidX']}
# {'RAST': ['DNA gyrase subunit B (EC 5.99.1.3)']}
# {'RAST': ['Uncharacterized protein YieK']}
# {'RAST': ['Protein ViaA']}
# {'RAST': ['Kup system potassium uptake protein']}
# {'RAST': ['Uncharacterized transcriptional regulator YieP, GntR family']}
# {'RAST': ['LysR family transcriptional regulator HdfR']}
# {'RAST': ['Branched-chain amino acid aminotransferase (EC 2.6.1.42)']}
# {'RAST': ['Dihydroxy-acid dehydratase (EC 4.2.1.9)']}
# {'RAST': ['ATP-dependent DNA helicase Rep']}
# {'RAST': ["Guanosine-5'-triphosphate,3'-diphosphate pyrophosphatase (EC 3.6.1.40)", ' Exopolyphosphatase (EC 3.6.1.11)']}
# {'RAST': ['UDP-N-acetylglucosamine 2-epimerase (EC 5.1.3.14)']}
# {'RAST': ['UDP-N-acetyl-D-mannosamine dehydrogenase (EC 1.1.1.336)']}
# {'RAST': ['dTDP-glucose 4,6-dehydratase (EC 4.2.1.46)']}
# {'RAST': ['dTDP-fucosamine acetyltransferase (EC 2.3.1.210)']}
# {'RAST': ['TDP-N-acetylfucosamine:lipid II N-acetylfucosaminyltransferase (EC 2.4.1.325)']}
# {'RAST': ['Probable transport protein YifK']}
# {'RAST': ['Anaerobic sulfatase-maturating enzyme homolog AslB']}
# {'RAST': ['Porphobilinogen deaminase (EC 2.5.1.61)']}
# {'RAST': ['UPF0386 protein YjhX']}
# {'RAST': ['Uncharacterized inner membrane protein RarD']}
# {'RAST': ['ATP-dependent DNA helicase RecQ']}
# {'RAST': ['Threonine efflux protein RhtC']}
# {'RAST': ['Homoserine/homoserine lactone efflux protein']}
# {'RAST': ['Lysophospholipase L2 (EC 3.1.1.5)']}
# {'RAST': ['HAD phosphatase YigL']}
# {'RAST': ['Dienelactone hydrolase family protein']}
# {'RAST': ['2-methoxy-6-polyprenyl-1,4-benzoquinol methylase (EC 2.1.1.201)', ' Demethylmenaquinone methyltransferase (EC 2.1.1.163)']}
# {'RAST': ['Twin-arginine translocation protein TatB']}
# {'RAST': ['Deoxyribonuclease TatD']}
# {'RAST': ['3-ketoacyl-CoA thiolase (EC 2.3.1.16)']}
# {'RAST': ['Trk potassium uptake system protein TrkH']}
# {'RAST': ['GTP-binding protein TypA/BipA']}
# {'RAST': ['Sulphoquinovose/Na+ symporter']}
# {'RAST': ['L-rhamnose isomerase (EC 5.3.1.14)']}
# {'RAST': ['Periplasmic protein CpxP']}
# {'RAST': ['Phosphoenolpyruvate-protein phosphotransferase of PTS system (EC 2.7.3.9)']}
# {'RAST': ['Sulfur carrier protein ThiS']}
# {'RAST': ["NADH pyrophosphatase (EC 3.6.1.22), decaps 5'-NAD modified RNA"]}
# {'RAST': ['Uncharacterized protein YjdP']}
# {'RAST': ['Phosphonates utilization ATP-binding protein PhnK']}
# {'RAST': ['Entericidin A']}
# {'RAST': ['Entericidin B']}
# {'RAST': ['Uncharacterized protein YtfI']}
# {'RAST': ['Galactofuranose ABC transporter, ATP-binding protein']}
# {'RAST': ['Uncharacterized N-acetyltransferase YjgM']}
# {'RAST': ['Inner membrane protein YjgN']}
# {'RAST': ['Regulator of L-galactonate catabolism LgoR, GntR family']}
# {'RAST': ['Putative deoxyribonuclease YjjV']}
# {'RAST': ['Uncharacterized protein YkfH']}
# {'RAST': ['LSU ribosomal protein L36p', ' LSU ribosomal protein L36p, zinc-independent']}
# {'RAST': ['Uncharacterized protein YlcG']}
# {'RAST': ['Phage-encoded host cell membrane protein Rz1']}
# {'RAST': ['MbtH-like NRPS chaperone => YbdZ']}
# {'RAST': ['Uncharacterized proteins YbdD and YjiX']}
# {'RAST': ['Protein KdpF']}
# {'RAST': ['Cytochrome d ubiquinol oxidase subunit X (EC 1.10.3.-)']}
# {'RAST': ['IS1 protein InsA']}
# {'RAST': ['GnsA protein']}
# {'RAST': ['Inner membrane protein YmgF']}
# {'RAST': ['hypothetical protein']}
# {'RAST': ['hypothetical protein']}
# {'RAST': ['Uncharacterized phage-associated protein YdaE']}
# {'RAST': ['Phage-encoded host cell membrane protein Rz1']}
# {'RAST': ['Uncharacterized protein YdbJ']}
# {'RAST': ['hypothetical protein']}
# {'RAST': ['hypothetical protein']}
# {'RAST': ['Uncharacterized protein YobH']}
# {'RAST': ['YoeB toxin protein']}
# {'RAST': ['Uncharacterized protein YehK']}
# {'RAST': ['UPF0387 membrane protein YohO']}
# {'RAST': ['UPF0153 protein YeiW']}
# {'RAST': ['Undecaprenyl phosphate-aminoarabinose flippase subunit ArnE']}
# {'RAST': ['Gene 18 protein']}
# {'RAST': ['Uncharacterized protein YpeB']}
# {'RAST': ['UPF0370 protein YpfN']}
# {'RAST': ['hypothetical protein']}
# {'RAST': ['Alternative ribosome-rescue factor A']}
# {'RAST': ['Cytoplasmic protein, probably associated with glutathione-regulated potassium-efflux']}
# {'RAST': ['Uncharacterized lipoprotein YsaB precursor']}
# {'RAST': ['Uncharacterized protein YibT']}
# {'RAST': ['HAD phosphatase YigL']}
# {'RAST': ['Membrane protein insertion efficiency factor YidD']}
# {'RAST': ['Diaminopimelate decarboxylase and/or diaminopimelate epimerase leader peptide']}
# {'RAST': ['Toxin GhoT']}
# {'RAST': ['PTS system, IIB component']}
# {'RAST': ['UPF0386 protein YjhX']}
# {'RAST': ['hypothetical protein']}
# {'RAST': ['UPF0391 membrane protein YtjA']}

# %% [markdown]
# ### 1 - Build Base Model

# %%
builder = modelseedpy.MSBuilder(genome, template_gramneg, 'test')

# %%
model_base = builder.build_base_model('test', annotate_with_rast=False)

# %%
builder.add_atpm(model_base)
model_base
# Out:
# <Model test at 0x7fd10924b100>

# %% [markdown]
# ### 2 - ATP Gapfill / Analysis

# %%
from modelseedpy.core.msatpcorrection import load_default_medias

# %%
default_medias = load_default_medias()
print(f'loaded {len(default_medias)} medias')
# Out:
# loaded 54 medias

# %%
for media, min_obj in default_medias:
    print(media.id, media.get_media_constraints())
    break
# Out:
# Glc.O2 {'cpd00027_e0': (-1, 1000), 'cpd00007_e0': (-1000, 1000), 'cpd00001_e0': (-1000, 1000), 'cpd00067_e0': (-1000, 1000)}

# %%
from modelseedpy import MSATPCorrection
atp_correction = MSATPCorrection(model_base, template_core, default_medias,
                                 compartment='c0', atp_hydrolysis_id='ATPM_c0', 
                                 load_default_medias=False)

# %%
media_eval = atp_correction.evaluate_growth_media()
atp_correction.determine_growth_media()
atp_correction.apply_growth_media_gapfilling()
atp_correction.expand_model_to_genome_scale()
tests = atp_correction.build_tests()
# Out:
# No gapfilling solution found before filtering for Etho activating ATPM_c0
# No gapfilling solution found before filtering for mal-L activating ATPM_c0
# No gapfilling solution found before filtering for Pyr.SO4 activating ATPM_c0
# No gapfilling solution found before filtering for H2.SO4 activating ATPM_c0
# No gapfilling solution found before filtering for empty activating ATPM_c0
# No gapfilling solution found before filtering for Light activating ATPM_c0
# No gapfilling solution found before filtering for ANME activating ATPM_c0
# No gapfilling solution found before filtering for Methane activating ATPM_c0

# %%
for t in tests:
    print(t['media'].id, t['threshold'], atp_correction.media_gapfill_stats[t['media']])
# Out:
# empty 1e-05 None
# Glc.O2 31.800000000002317 {'reversed': {}, 'new': {}}
# Ac.O2 8.999999999999318 {'reversed': {}, 'new': {}}
# Etho.O2 14.7 {'reversed': {}, 'new': {}}
# Pyr.O2 12.45 {'reversed': {}, 'new': {}}
# Glyc.O2 18.15000000000082 {'reversed': {}, 'new': {}}
# Fum.O2 16.2 {'reversed': {}, 'new': {}}
# Akg.O2 21.900000000000272 {'reversed': {}, 'new': {}}
# LLac.O2 14.700000000000681 {'reversed': {}, 'new': {}}
# Dlac.O2 14.699999999999317 {'reversed': {}, 'new': {}}
# For.O2 2.2500000000002727 {'reversed': {}, 'new': {}}
# Glc 6.0 {'reversed': {}, 'new': {}}
# Pyr 1.2 {'reversed': {}, 'new': {}}
# Glyc 1.2 {'reversed': {}, 'new': {}}
# Fum 2.1 {'reversed': {}, 'new': {}}
# Llac 0.6 {'reversed': {}, 'new': {}}
# Dlac 0.6 {'reversed': {}, 'new': {}}
# For.NO2 0.09999999999990905 {'reversed': {}, 'new': {}}
# Pyr.NO3 4.95 {'reversed': {}, 'new': {}}
# Ac.NO2 0.39999999999990904 {'reversed': {}, 'new': {}}
# Ac.NO3 3.0 {'reversed': {}, 'new': {}}
# Glc.DMSO 4.800000000002319 {'reversed': {}, 'new': {}}
# Glc.TMAO 4.8 {'reversed': {}, 'new': {}}
# Pyr.DMSO 1.2 {'reversed': {}, 'new': {}}
# Pyr.TMAO 1.2 {'reversed': {}, 'new': {}}
# Pyr.SO3 1.2 {'reversed': {}, 'new': {}}
# LLac.SO4.H2 0.6749999999999999 {'reversed': {}, 'new': {}}
# LLac.SO4 0.6749999999999999 {'reversed': {}, 'new': {}}

# %% [markdown]
# ### 3 - Genome Scale Gapfilling

# %%
from modelseedpy import MSMedia
media_glucose = MSMedia.from_dict({
    'cpd00149': (-100, 100),
    'cpd00099': (-100, 100),
    'cpd00067': (-100, 100),
    'cpd00063': (-100, 100),
 'cpd00058': (-100, 100),
 'cpd00048': (-100, 100),
 'cpd00034': (-100, 100),
 'cpd00030': (-100, 100),
 'cpd00013': (-100, 100),
 'cpd00009': (-100, 100),
 'cpd00001': (-100, 100),
 'cpd00007': (-10, 100),
 'cpd00205': (-100, 100),
 'cpd00254': (-100, 100),
 'cpd00971': (-100, 100),
 'cpd10515': (-100, 100),
 'cpd10516': (-100, 100),
 'cpd11574': (-100, 100),
 'cpd00244': (-100, 100),
 'cpd00027': (-5, 100)})

# %%
from modelseedpy import MSGapfill
gapfill = MSGapfill(model_base, default_gapfill_templates=[template_gramneg], test_conditions=tests, default_target='bio1')

# %%
gapfill_res = gapfill.run_gapfilling(media_glucose)

# %%
gapfill_res
# Out:
# {'reversed': {},
#  'new': {'EX_cpd01981_e0': '>',
#   'rxn05459_c0': '>',
#   'rxn05481_c0': '<',
#   'rxn00599_c0': '>',
#   'rxn02185_c0': '<'},
#  'media': <modelseedpy.core.msmedia.MSMedia at 0x7fd091075630>,
#  'target': 'bio1',
#  'minobjective': 0.01,
#  'binary_check': False}

# %%
def _integrate_solution(template, model, gap_fill_solution):
    added_reactions = []
    for rxn_id, (lb, ub) in gap_fill_solution.items():
        template_reaction = template.reactions.get_by_id(rxn_id)
        model_reaction = template_reaction.to_reaction(model)
        model_reaction.lower_bound = lb
        model_reaction.upper_bound = ub
        _str = model_reaction.build_reaction_string(True)
        #print(f'{model.id} add {model_reaction.id}: {_str}')
        added_reactions.append(model_reaction)
    model.add_reactions(added_reactions)
    add_exchanges = MSBuilder.add_exchanges_to_model(model)

    return added_reactions, add_exchanges

model_gapfilled = model_base.copy()

from modelseedpy.core.msmodel import get_reaction_constraints_from_direction
from modelseedpy import MSBuilder
gap_sol = {}
for rxn_id, d in gapfill_res['new'].items():
    if rxn_id[:-1] in template_gramneg.reactions:
        gap_sol[rxn_id[:-1]] = get_reaction_constraints_from_direction(d)
print(gap_sol)
_integrate_solution(template_gramneg, model_gapfilled, gap_sol)
# Out:
# {'rxn05459_c': (0, 1000), 'rxn05481_c': (-1000, 0), 'rxn00599_c': (0, 1000), 'rxn02185_c': (-1000, 0)}
# ([<Reaction rxn05459_c0 at 0x7fcb9f6ed120>,
#   <Reaction rxn05481_c0 at 0x7fcb9f6ed390>,
#   <Reaction rxn00599_c0 at 0x7fcabde68100>,
#   <Reaction rxn02185_c0 at 0x7fcabde68790>],
#  [<Reaction EX_cpd01981_e0 at 0x7fcabde689d0>])

# %%
import math
def integrate_to_model_medium(media, model, prefix='EX_'):
    medium = {}
    for cpd, (lb, ub) in media.get_media_constraints().items():
        rxn_exchange = f'{prefix}{cpd}'
        if rxn_exchange in model.reactions:
            medium[rxn_exchange] = math.fabs(lb)
        else:
            print('not in model', cpd)
    return medium
model_gapfilled.medium = integrate_to_model_medium(media_glucose, model_gapfilled)
model_gapfilled.objective = 'bio1'
model_gapfilled.summary()
# Out:
# <h3>Objective</h3><p>1.0 bio1 = 0.5544145208492076</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>cpd00007_e0</td>
#       <td>EX_cpd00007_e0</td>
#       <td>8.362</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00009_e0</td>
#       <td>EX_cpd00009_e0</td>
#       <td>0.3665</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00013_e0</td>
#       <td>EX_cpd00013_e0</td>
#       <td>4.431</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00027_e0</td>
#       <td>EX_cpd00027_e0</td>
#       <td>5</td>
#       <td>6</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00030_e0</td>
#       <td>EX_cpd00030_e0</td>
#       <td>0.0008871</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00034_e0</td>
#       <td>EX_cpd00034_e0</td>
#       <td>0.0008871</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00048_e0</td>
#       <td>EX_cpd00048_e0</td>
#       <td>0.1153</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00058_e0</td>
#       <td>EX_cpd00058_e0</td>
#       <td>0.0008871</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00063_e0</td>
#       <td>EX_cpd00063_e0</td>
#       <td>0.0008871</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00099_e0</td>
#       <td>EX_cpd00099_e0</td>
#       <td>0.0008871</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00149_e0</td>
#       <td>EX_cpd00149_e0</td>
#       <td>0.0008871</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00205_e0</td>
#       <td>EX_cpd00205_e0</td>
#       <td>0.0008871</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00254_e0</td>
#       <td>EX_cpd00254_e0</td>
#       <td>0.0008871</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd10515_e0</td>
#       <td>EX_cpd10515_e0</td>
#       <td>0.003548</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>cpd00001_e0</td>
#       <td>EX_cpd00001_e0</td>
#       <td>-21.36</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00011_e0</td>
#       <td>EX_cpd00011_e0</td>
#       <td>-10.3</td>
#       <td>1</td>
#       <td>99.95%</td>
#     </tr>
#     <tr>
#       <td>cpd00067_e0</td>
#       <td>EX_cpd00067_e0</td>
#       <td>-3.659</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd01981_e0</td>
#       <td>EX_cpd01981_e0</td>
#       <td>-0.0008871</td>
#       <td>6</td>
#       <td>0.05%</td>
#     </tr>
#     <tr>
#       <td>cpd11416_c0</td>
#       <td>SK_cpd11416_c0</td>
#       <td>-0.5544</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>
