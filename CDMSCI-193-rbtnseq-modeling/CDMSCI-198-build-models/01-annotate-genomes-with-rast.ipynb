# %% [markdown]
# # Annotate Genomes with RAST
#
# **Parent**: CDMSCI-193 - RBTnSeq Modeling Analysis
#
# **Ticket**: CDMSCI-198 - Build Genome-Scale Metabolic Models
#
# ## Objective
#
# Annotate protein sequences for 57 organisms using RAST (Rapid Annotation using Subsystem Technology) to prepare for metabolic model building.
#
# ## What is RAST?
#
# RAST is an online service that annotates bacterial genomes with functional roles, which are then used to map genes to metabolic reactions in ModelSEED templates.
#
# **Key Features**:
# - Assigns functional roles to genes/proteins
# - Maps roles to biochemical reactions
# - Required for ModelSEEDpy model building
# - Takes 2-4 hours per genome
#
# ## Inputs
#
# - Protein FASTA files (57 organisms)
# - Location: `../data/raw/protein_sequences/`
#
# ## Outputs
#
# - Annotated genome objects saved as pickle files
# - Location: `results/genomes/`
# - Format: `{organism_id}_genome.pkl`
#
# **Last updated**: 2025-10-07

# %% [markdown]
# ## Setup

# %%
import modelseedpy
from modelseedpy import MSGenome, RastClient
from pathlib import Path
import pickle
import time
from datetime import datetime

print("Imports successful")
print(f"ModelSEEDpy version: {modelseedpy.__version__ if hasattr(modelseedpy, '____version__') else 'dev'}")
# Out:
# modelseedpy 0.4.2
# Imports successful
# ModelSEEDpy version: dev

# %% [markdown]
# ## Configuration

# %%
# Paths
FASTA_DIR = Path('../data/raw/protein_sequences')
OUTPUT_DIR = Path('results/genomes')
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# FASTA output directory
FASTA_OUTPUT_DIR = Path('results/fasta_annotated')
FASTA_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

LOG_FILE = Path('results/rast_annotation_log.txt')

print(f"Configuration set")
print(f"  Input directory: {FASTA_DIR}")
print(f"  Output directory: {OUTPUT_DIR}")
print(f"  FASTA output directory: {FASTA_OUTPUT_DIR}")
print(f"  Log file: {LOG_FILE}")
# Out:
# Configuration set
#   Input directory: ../data/raw/protein_sequences
#   Output directory: results/genomes
#   FASTA output directory: results/fasta_annotated
#   Log file: results/rast_annotation_log.txt

# %% [markdown]
# ## Find FASTA Files

# %%
print("Scanning for FASTA files...")
fasta_files = sorted(FASTA_DIR.glob('*_proteins.fasta'))

print(f"\nFound {len(fasta_files)} FASTA files:")
for i, fasta_file in enumerate(fasta_files, 1):
    print(f"  {i:2d}. {fasta_file.name}")
# Out:
# Scanning for FASTA files...
#
# Found 57 FASTA files:
#    1. ANA3_proteins.fasta
#    2. BFirm_proteins.fasta
#    3. Bifido_proteins.fasta
#    4. Brev2_proteins.fasta
#    5. Btheta_proteins.fasta
#    6. Burk376_proteins.fasta
#    7. Burkholderia_OAS925_proteins.fasta
#    8. Bvulgatus_CL09T03C04_proteins.fasta
#    9. CL21_proteins.fasta
#   10. Caulo_proteins.fasta
#   11. Cola_proteins.fasta
#   12. Cup4G11_proteins.fasta
#   13. Dda3937_proteins.fasta
#   14. Ddia6719_proteins.fasta
#   15. DdiaME23_proteins.fasta
#   16. Dino_proteins.fasta
#   17. DvH_proteins.fasta
#   18. Dyella79_proteins.fasta
#   19. HerbieS_proteins.fasta
#   20. Kang_proteins.fasta
#   21. Keio_proteins.fasta
#   22. Korea_proteins.fasta
#   23. Koxy_proteins.fasta
#   24. Lysobacter_OAE881_proteins.fasta
#   25. MR1_proteins.fasta
#   26. Magneto_proteins.fasta
#   27. Marino_proteins.fasta
#   28. Methanococcus_JJ_proteins.fasta
#   29. Methanococcus_S2_proteins.fasta
#   30. Miya_proteins.fasta
#   31. PS_proteins.fasta
#   32. PV4_proteins.fasta
#   33. Pedo557_proteins.fasta
#   34. Phaeo_proteins.fasta
#   35. Ponti_proteins.fasta
#   36. Putida_proteins.fasta
#   37. RalstoniaBSBF1503_proteins.fasta
#   38. RalstoniaGMI1000_proteins.fasta
#   39. RalstoniaPSI07_proteins.fasta
#   40. RalstoniaUW163_proteins.fasta
#   41. SB2B_proteins.fasta
#   42. Smeli_proteins.fasta
#   43. SynE_proteins.fasta
#   44. SyringaeB728a_mexBdelta_proteins.fasta
#   45. SyringaeB728a_proteins.fasta
#   46. Variovorax_OAS795_proteins.fasta
#   47. WCS417_proteins.fasta
#   48. Xantho_proteins.fasta
#   49. acidovorax_3H11_proteins.fasta
#   50. azobra_proteins.fasta
#   51. psRCH2_proteins.fasta
#   52. pseudo13_GW456_L13_proteins.fasta
#   53. pseudo1_N1B4_proteins.fasta
#   54. pseudo3_N2E3_proteins.fasta
#   55. pseudo5_N2C3_1_proteins.fasta
#   56. pseudo6_N2E2_proteins.fasta
#   57. rhodanobacter_10B01_proteins.fasta

# %% [markdown]
# ## Initialize RAST Client

# %%
print("Initializing RAST client...")
rast = RastClient()

print("\n⚠️  IMPORTANT NOTES:")
print("  - RAST annotation requires internet connection")
print("  - Each genome takes 2-4 hours to annotate")
print("  - 57 genomes = ~114-228 hours total if run serially")
print("  - You can stop and resume this notebook")
print("  - Already annotated genomes will be skipped")
print("\nRAST client ready")
# Out:
# Initializing RAST client...
#
# ⚠️  IMPORTANT NOTES:
#   - RAST annotation requires internet connection
#   - Each genome takes 2-4 hours to annotate
#   - 57 genomes = ~114-228 hours total if run serially
#   - You can stop and resume this notebook
#   - Already annotated genomes will be skipped
#
# RAST client ready

# %% [markdown]
# ## Helper Functions

# %%
def log_message(message):
    """Log message to file and print to console"""
    timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    log_msg = f"[{timestamp}] {message}"
    print(log_msg)
    
    with open(LOG_FILE, 'a') as f:
        f.write(log_msg + '\n')


def get_organism_id(fasta_filename):
    """Extract organism ID from FASTA filename"""
    # Remove _proteins.fasta suffix
    return fasta_filename.replace('_proteins.fasta', '')


def genome_already_annotated(organism_id):
    """Check if genome has already been annotated"""
    output_file = OUTPUT_DIR / f"{organism_id}_genome.pkl"
    return output_file.exists()


def save_genome(genome, organism_id):
    """Save annotated genome as pickle file"""
    output_file = OUTPUT_DIR / f"{organism_id}_genome.pkl"
    with open(output_file, 'wb') as f:
        pickle.dump(genome, f)
    return output_file


def load_genome(organism_id):
    """Load previously annotated genome"""
    input_file = OUTPUT_DIR / f"{organism_id}_genome.pkl"
    with open(input_file, 'rb') as f:
        return pickle.load(f)




def save_genome_as_fasta(genome, organism_id):
    """Save annotated genome as FASTA file with functional annotations"""
    output_file = FASTA_OUTPUT_DIR / f"{organism_id}_RAST.fasta"

    with open(output_file, 'w') as f:
        for feature in genome.features:
            # Create FASTA header with annotations
            header = f">{feature.id}"

            # Add functional roles if annotated
            if hasattr(feature, 'ontology_terms') and feature.ontology_terms:
                # Convert to list and take first 3 roles
                roles_list = list(feature.ontology_terms)
                roles = "; ".join(str(r) for r in roles_list[:3])
                header += f" | {roles}"
            else:
                header += " | Hypothetical protein"

            # Write header
            f.write(header + '\n')
            
            # Write sequence (convert to string if needed)
            seq_str = str(feature.seq) if hasattr(feature, 'seq') else ""
            f.write(seq_str + '\n')

    return output_file

def fasta_already_exists(organism_id):
    """Check if FASTA output already exists"""
    output_file = FASTA_OUTPUT_DIR / f"{organism_id}_RAST.fasta"
    return output_file.exists()


print("Helper functions defined")
# Out:
# Helper functions defined

# %% [markdown]
# ## Annotate Genomes
#
# This cell annotates all genomes sequentially. You can:
# - Run all at once (will take many hours)
# - Run one at a time by setting `batch_size = 1`
# - Stop and resume anytime (already annotated genomes are skipped)

# %%
# Configuration
BATCH_SIZE = None  # Set to None to process all, or set to N to process N genomes
START_INDEX = 0    # Set to skip first N genomes (useful for resuming)

log_message("="*80)
log_message("STARTING RAST ANNOTATION")
log_message("="*80)

# Select genomes to process
if BATCH_SIZE:
    genomes_to_process = fasta_files[START_INDEX:START_INDEX+BATCH_SIZE]
else:
    genomes_to_process = fasta_files[START_INDEX:]

log_message(f"Processing {len(genomes_to_process)} genomes (starting from index {START_INDEX})")

# Track progress
total_genomes = len(genomes_to_process)
completed = 0
skipped = 0
failed = 0

for i, fasta_file in enumerate(genomes_to_process, 1):
    organism_id = get_organism_id(fasta_file.name)
    
    log_message(f"\n[{i}/{total_genomes}] Processing: {organism_id}")
    log_message(f"  FASTA file: {fasta_file.name}")
    
    # Check if already annotated (both pickle and FASTA exist)
    if genome_already_annotated(organism_id) and fasta_already_exists(organism_id):
        log_message(f"  ✓ Already annotated - skipping")
        skipped += 1
        continue
    
    try:
        # Load genome from FASTA
        log_message(f"  Loading genome from FASTA...")
        genome = MSGenome.from_fasta(str(fasta_file))
        log_message(f"  Loaded {len(genome.features)} features")
        
        # Annotate with RAST
        log_message(f"  Submitting to RAST for annotation...")
        log_message(f"  ⏳ This will take 2-4 hours - please be patient")
        
        start_time = time.time()
        result = rast.annotate_genome(genome)
        elapsed_time = time.time() - start_time
        
        log_message(f"  ✓ Annotation complete ({elapsed_time/60:.1f} minutes)")
        
        # Count annotations
        annotated_features = sum(1 for f in genome.features if f.ontology_terms)
        log_message(f"  Annotated features: {annotated_features}/{len(genome.features)}")
        
        # Save genome as pickle
        output_file = save_genome(genome, organism_id)
        log_message(f"  ✓ Saved pickle: {output_file.name}")

        # Save genome as annotated FASTA
        fasta_file = save_genome_as_fasta(genome, organism_id)
        log_message(f"  ✓ Saved FASTA: {fasta_file.name}")
        
        completed += 1
        
    except Exception as e:
        log_message(f"  ✗ ERROR: {str(e)}")
        failed += 1
        continue

log_message(f"\n{'='*80}")
log_message("ANNOTATION SUMMARY")
log_message(f"{'='*80}")
log_message(f"Total processed: {total_genomes}")
log_message(f"  Completed: {completed}")
log_message(f"  Skipped (already done): {skipped}")
log_message(f"  Failed: {failed}")
log_message(f"\nOutput directory: {OUTPUT_DIR}")
log_message(f"{'='*80}")
# Out:
# [2025-10-14 20:01:36] ================================================================================
# [2025-10-14 20:01:36] STARTING RAST ANNOTATION
# [2025-10-14 20:01:36] ================================================================================
# [2025-10-14 20:01:36] Processing 57 genomes (starting from index 0)
# [2025-10-14 20:01:36]
# [1/57] Processing: ANA3
# [2025-10-14 20:01:36]   FASTA file: ANA3_proteins.fasta
# [2025-10-14 20:01:36]   Loading genome from FASTA...
# [2025-10-14 20:01:36]   Loaded 4360 features
# [2025-10-14 20:01:36]   Submitting to RAST for annotation...
# [2025-10-14 20:01:36]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:01:40]   ✓ Annotation complete (0.1 minutes)
# [2025-10-14 20:01:40]   Annotated features: 4071/4360
# [2025-10-14 20:01:40]   ✓ Saved pickle: ANA3_genome.pkl
# [2025-10-14 20:01:40]   ✓ Saved FASTA: ANA3_RAST.fasta
# [2025-10-14 20:01:40]
# [2/57] Processing: BFirm
# [2025-10-14 20:01:40]   FASTA file: BFirm_proteins.fasta
# [2025-10-14 20:01:40]   Loading genome from FASTA...
# [2025-10-14 20:01:40]   Loaded 7182 features
# [2025-10-14 20:01:40]   Submitting to RAST for annotation...
# [2025-10-14 20:01:40]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:01:44]   ✓ Annotation complete (0.1 minutes)
# [2025-10-14 20:01:44]   Annotated features: 6502/7182
# [2025-10-14 20:01:44]   ✓ Saved pickle: BFirm_genome.pkl
# [2025-10-14 20:01:44]   ✓ Saved FASTA: BFirm_RAST.fasta
# [2025-10-14 20:01:44]
# [3/57] Processing: Bifido
# [2025-10-14 20:01:44]   FASTA file: Bifido_proteins.fasta
# [2025-10-14 20:01:44]   Loading genome from FASTA...
# [2025-10-14 20:01:44]   Loaded 1960 features
# [2025-10-14 20:01:44]   Submitting to RAST for annotation...
# [2025-10-14 20:01:44]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:01:46]   ✓ Annotation complete (0.0 minutes)
# [2025-10-14 20:01:46]   Annotated features: 1818/1960
# [2025-10-14 20:01:46]   ✓ Saved pickle: Bifido_genome.pkl
# [2025-10-14 20:01:46]   ✓ Saved FASTA: Bifido_RAST.fasta
# [2025-10-14 20:01:46]
# [4/57] Processing: Brev2
# [2025-10-14 20:01:46]   FASTA file: Brev2_proteins.fasta
# [2025-10-14 20:01:46]   Loading genome from FASTA...
# [2025-10-14 20:01:46]   Loaded 3184 features
# [2025-10-14 20:01:46]   Submitting to RAST for annotation...
# [2025-10-14 20:01:46]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:01:49]   ✓ Annotation complete (0.0 minutes)
# [2025-10-14 20:01:49]   Annotated features: 2764/3184
# [2025-10-14 20:02:05]   Loading genome from FASTA...
# [2025-10-14 20:02:05]   Loaded 4638 features
# [2025-10-14 20:02:05]   Submitting to RAST for annotation...
# [2025-10-14 20:02:05]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:02:08]   ✓ Annotation complete (0.1 minutes)
# [2025-10-14 20:02:08]   Annotated features: 4364/4638
# [2025-10-14 20:02:08]   ✓ Saved pickle: CL21_genome.pkl
# [2025-10-14 20:02:08]   ✓ Saved FASTA: CL21_RAST.fasta
# [2025-10-14 20:02:08]
# [10/57] Processing: Caulo
# [2025-10-14 20:02:08]   FASTA file: Caulo_proteins.fasta
# [2025-10-14 20:02:08]   Loading genome from FASTA...
# [2025-10-14 20:02:08]   Loaded 3886 features
# [2025-10-14 20:02:08]   Submitting to RAST for annotation...
# [2025-10-14 20:02:08]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:02:11]   ✓ Annotation complete (0.0 minutes)
# [2025-10-14 20:02:11]   Annotated features: 3676/3886
# [2025-10-14 20:02:11]   ✓ Saved pickle: Caulo_genome.pkl
# [2025-10-14 20:02:11]   ✓ Saved FASTA: Caulo_RAST.fasta
# [2025-10-14 20:02:11]
# [11/57] Processing: Cola
# [2025-10-14 20:02:11]   FASTA file: Cola_proteins.fasta
# [2025-10-14 20:02:11]   Loading genome from FASTA...
# [2025-10-14 20:02:11]   Loaded 4625 features
# [2025-10-14 20:02:11]   Submitting to RAST for annotation...
# [2025-10-14 20:02:11]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:02:14]   ✓ Annotation complete (0.1 minutes)
# [2025-10-14 20:02:14]   Annotated features: 4408/4625
# [2025-10-14 20:02:14]   ✓ Saved pickle: Cola_genome.pkl
# [2025-10-14 20:02:14]   ✓ Saved FASTA: Cola_RAST.fasta
# [2025-10-14 20:02:14]
# [12/57] Processing: Cup4G11
# [2025-10-14 20:02:14]   FASTA file: Cup4G11_proteins.fasta
# [2025-10-14 20:02:14]   Loading genome from FASTA...
# [2025-10-14 20:02:14]   Loaded 7358 features
# [2025-10-14 20:02:14]   Submitting to RAST for annotation...
# [2025-10-14 20:02:14]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:02:19]   ✓ Annotation complete (0.1 minutes)
# [2025-10-14 20:02:19]   Annotated features: 6471/7358
# [2025-10-14 20:02:19]   ✓ Saved pickle: Cup4G11_genome.pkl
# [2025-10-14 20:02:19]   ✓ Saved FASTA: Cup4G11_RAST.fasta
# [2025-10-14 20:02:19]
# [13/57] Processing: Dda3937
# [2025-10-14 20:02:19]   FASTA file: Dda3937_proteins.fasta
# [2025-10-14 20:02:19]   Loading genome from FASTA...
# [2025-10-14 20:02:19]   Loaded 4213 features
# [2025-10-14 20:02:19]   Submitting to RAST for annotation...
# [2025-10-14 20:02:19]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:02:22]   ✓ Annotation complete (0.1 minutes)
# [2025-10-14 20:02:22]   Annotated features: 3945/4213
# [2025-10-14 20:02:22]   ✓ Saved pickle: Dda3937_genome.pkl
# [2025-10-14 20:02:22]   ✓ Saved FASTA: Dda3937_RAST.fasta
# [2025-10-14 20:02:22]
# [14/57] Processing: Ddia6719
# [2025-10-14 20:02:22]   FASTA file: Ddia6719_proteins.fasta
# [2025-10-14 20:02:22]   Loading genome from FASTA...
# [2025-10-14 20:02:22]   Loaded 4110 features
# [2025-10-14 20:02:22]   Submitting to RAST for annotation...
# [2025-10-14 20:02:22]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:02:25]   ✓ Annotation complete (0.1 minutes)
# [2025-10-14 20:02:25]   Annotated features: 3829/4110
# [2025-10-14 20:02:25]   ✓ Saved pickle: Ddia6719_genome.pkl
# [2025-10-14 20:02:25]   ✓ Saved FASTA: Ddia6719_RAST.fasta
# [2025-10-14 20:02:25]
# [15/57] Processing: DdiaME23
# [2025-10-14 20:02:25]   FASTA file: DdiaME23_proteins.fasta
# [2025-10-14 20:02:25]   Loading genome from FASTA...
# [2025-10-14 20:02:25]   Loaded 4182 features
# [2025-10-14 20:02:25]   Submitting to RAST for annotation...
# [2025-10-14 20:02:25]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:02:28]   ✓ Annotation complete (0.1 minutes)
# [2025-10-14 20:02:28]   Annotated features: 3874/4182
# [2025-10-14 20:02:28]   ✓ Saved pickle: DdiaME23_genome.pkl
# [2025-10-14 20:02:28]   ✓ Saved FASTA: DdiaME23_RAST.fasta
# [2025-10-14 20:02:28]
# [16/57] Processing: Dino
# [2025-10-14 20:02:28]   FASTA file: Dino_proteins.fasta
# [2025-10-14 20:02:28]   Loading genome from FASTA...
# [2025-10-14 20:02:28]   Loaded 4192 features
# [2025-10-14 20:02:28]   Submitting to RAST for annotation...
# [2025-10-14 20:02:28]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:02:31]   ✓ Annotation complete (0.1 minutes)
# [2025-10-14 20:02:31]   Annotated features: 4159/4192
# [2025-10-14 20:02:31]   ✓ Saved pickle: Dino_genome.pkl
# [2025-10-14 20:02:31]   ✓ Saved FASTA: Dino_RAST.fasta
# [2025-10-14 20:02:31]
# [17/57] Processing: DvH
# [2025-10-14 20:02:31]   FASTA file: DvH_proteins.fasta
# [2025-10-14 20:02:31]   Loading genome from FASTA...
# [2025-10-14 20:02:31]   Loaded 3403 features
# [2025-10-14 20:02:31]   Submitting to RAST for annotation...
# [2025-10-14 20:02:31]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:02:35]   ✓ Annotation complete (0.1 minutes)
# [2025-10-14 20:02:35]   Annotated features: 2990/3403
# [2025-10-14 20:02:35]   ✓ Saved pickle: DvH_genome.pkl
# [2025-10-14 20:02:35]   ✓ Saved FASTA: DvH_RAST.fasta
# [2025-10-14 20:02:35]
# [18/57] Processing: Dyella79
# [2025-10-14 20:02:35]   FASTA file: Dyella79_proteins.fasta
# [2025-10-14 20:02:35]   Loading genome from FASTA...
# [2025-10-14 20:02:35]   Loaded 4375 features
# [2025-10-14 20:02:35]   Submitting to RAST for annotation...
# [2025-10-14 20:02:49]   FASTA file: Koxy_proteins.fasta
# [2025-10-14 20:02:49]   Loading genome from FASTA...
# [2025-10-14 20:02:49]   Loaded 5309 features
# [2025-10-14 20:02:49]   Submitting to RAST for annotation...
# [2025-10-14 20:02:49]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:02:53]   ✓ Annotation complete (0.1 minutes)
# [2025-10-14 20:02:53]   Annotated features: 5045/5309
# [2025-10-14 20:02:53]   ✓ Saved pickle: Koxy_genome.pkl
# [2025-10-14 20:02:53]   ✓ Saved FASTA: Koxy_RAST.fasta
# [2025-10-14 20:02:53]
# [24/57] Processing: Lysobacter_OAE881
# [2025-10-14 20:02:53]   FASTA file: Lysobacter_OAE881_proteins.fasta
# [2025-10-14 20:02:53]   Loading genome from FASTA...
# [2025-10-14 20:02:53]   Loaded 3702 features
# [2025-10-14 20:02:53]   Submitting to RAST for annotation...
# [2025-10-14 20:02:53]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:02:56]   ✓ Annotation complete (0.0 minutes)
# [2025-10-14 20:02:56]   Annotated features: 2992/3702
# [2025-10-14 20:02:56]   ✓ Saved pickle: Lysobacter_OAE881_genome.pkl
# [2025-10-14 20:02:56]   ✓ Saved FASTA: Lysobacter_OAE881_RAST.fasta
# [2025-10-14 20:02:56]
# [25/57] Processing: MR1
# [2025-10-14 20:02:56]   FASTA file: MR1_proteins.fasta
# [2025-10-14 20:02:56]   Loading genome from FASTA...
# [2025-10-14 20:02:56]   Loaded 4467 features
# [2025-10-14 20:02:56]   Submitting to RAST for annotation...
# [2025-10-14 20:02:56]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:02:59]   ✓ Annotation complete (0.1 minutes)
# [2025-10-14 20:02:59]   Annotated features: 4303/4467
# [2025-10-14 20:02:59]   ✓ Saved pickle: MR1_genome.pkl
# [2025-10-14 20:02:59]   ✓ Saved FASTA: MR1_RAST.fasta
# [2025-10-14 20:02:59]
# [26/57] Processing: Magneto
# [2025-10-14 20:02:59]   FASTA file: Magneto_proteins.fasta
# [2025-10-14 20:02:59]   Loading genome from FASTA...
# [2025-10-14 20:02:59]   Loaded 4489 features
# [2025-10-14 20:02:59]   Submitting to RAST for annotation...
# [2025-10-14 20:02:59]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:03:03]   ✓ Annotation complete (0.1 minutes)
# [2025-10-14 20:03:03]   Annotated features: 4106/4489
# [2025-10-14 20:03:03]   ✓ Saved pickle: Magneto_genome.pkl
# [2025-10-14 20:03:03]   ✓ Saved FASTA: Magneto_RAST.fasta
# [2025-10-14 20:03:03]
# [27/57] Processing: Marino
# [2025-10-14 20:03:03]   FASTA file: Marino_proteins.fasta
# [2025-10-14 20:03:03]   Loading genome from FASTA...
# [2025-10-14 20:03:03]   Loaded 4410 features
# [2025-10-14 20:03:03]   Submitting to RAST for annotation...
# [2025-10-14 20:03:03]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:03:06]   ✓ Annotation complete (0.1 minutes)
# [2025-10-14 20:03:06]   Annotated features: 3646/4410
# [2025-10-14 20:03:06]   ✓ Saved pickle: Marino_genome.pkl
# [2025-10-14 20:03:06]   ✓ Saved FASTA: Marino_RAST.fasta
# [2025-10-14 20:03:06]
# [28/57] Processing: Methanococcus_JJ
# [2025-10-14 20:03:06]   FASTA file: Methanococcus_JJ_proteins.fasta
# [2025-10-14 20:03:06]   Loading genome from FASTA...
# [2025-10-14 20:03:06]   Loaded 1796 features
# [2025-10-14 20:03:06]   Submitting to RAST for annotation...
# [2025-10-14 20:03:06]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:03:08]   ✓ Annotation complete (0.0 minutes)
# [2025-10-14 20:03:08]   Annotated features: 1696/1796
# [2025-10-14 20:03:08]   ✓ Saved pickle: Methanococcus_JJ_genome.pkl
# [2025-10-14 20:03:08]   ✓ Saved FASTA: Methanococcus_JJ_RAST.fasta
# [2025-10-14 20:03:08]
# [29/57] Processing: Methanococcus_S2
# [2025-10-14 20:03:08]   FASTA file: Methanococcus_S2_proteins.fasta
# [2025-10-14 20:03:08]   Loading genome from FASTA...
# [2025-10-14 20:03:08]   Loaded 1741 features
# [2025-10-14 20:03:08]   Submitting to RAST for annotation...
# [2025-10-14 20:03:08]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:03:10]   ✓ Annotation complete (0.0 minutes)
# [2025-10-14 20:03:10]   Annotated features: 1720/1741
# [2025-10-14 20:03:10]   ✓ Saved pickle: Methanococcus_S2_genome.pkl
# [2025-10-14 20:03:10]   ✓ Saved FASTA: Methanococcus_S2_RAST.fasta
# [2025-10-14 20:03:10]
# [30/57] Processing: Miya
# [2025-10-14 20:03:10]   FASTA file: Miya_proteins.fasta
# [2025-10-14 20:03:10]   Loading genome from FASTA...
# [2025-10-14 20:03:10]   Loaded 3180 features
# [2025-10-14 20:03:10]   Submitting to RAST for annotation...
# [2025-10-14 20:03:10]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:03:13]   ✓ Annotation complete (0.1 minutes)
# [2025-10-14 20:03:13]   Annotated features: 3128/3180
# [2025-10-14 20:03:13]   ✓ Saved pickle: Miya_genome.pkl
# [2025-10-14 20:03:13]   ✓ Saved FASTA: Miya_RAST.fasta
# [2025-10-14 20:03:13]
# [31/57] Processing: PS
# [2025-10-14 20:03:13]   FASTA file: PS_proteins.fasta
# [2025-10-14 20:03:13]   Loading genome from FASTA...
# [2025-10-14 20:03:13]   Loaded 3443 features
# [2025-10-14 20:03:13]   Submitting to RAST for annotation...
# [2025-10-14 20:03:13]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:03:16]   ✓ Annotation complete (0.0 minutes)
# [2025-10-14 20:03:16]   Annotated features: 3276/3443
# [2025-10-14 20:03:16]   ✓ Saved pickle: PS_genome.pkl
# [2025-10-14 20:03:16]   ✓ Saved FASTA: PS_RAST.fasta
# [2025-10-14 20:03:16]
# [32/57] Processing: PV4
# [2025-10-14 20:03:16]   FASTA file: PV4_proteins.fasta
# [2025-10-14 20:03:16]   Loading genome from FASTA...
# [2025-10-14 20:03:46]   Loading genome from FASTA...
# [2025-10-14 20:03:46]   Loaded 3645 features
# [2025-10-14 20:03:46]   Submitting to RAST for annotation...
# [2025-10-14 20:03:46]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:03:50]   ✓ Annotation complete (0.1 minutes)
# [2025-10-14 20:03:50]   Annotated features: 3546/3645
# [2025-10-14 20:03:50]   ✓ Saved pickle: SB2B_genome.pkl
# [2025-10-14 20:03:50]   ✓ Saved FASTA: SB2B_RAST.fasta
# [2025-10-14 20:03:50]
# [42/57] Processing: Smeli
# [2025-10-14 20:03:50]   FASTA file: Smeli_proteins.fasta
# [2025-10-14 20:03:50]   Loading genome from FASTA...
# [2025-10-14 20:03:50]   Loaded 6218 features
# [2025-10-14 20:03:50]   Submitting to RAST for annotation...
# [2025-10-14 20:03:50]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:03:54]   ✓ Annotation complete (0.1 minutes)
# [2025-10-14 20:03:54]   Annotated features: 6118/6218
# [2025-10-14 20:03:54]   ✓ Saved pickle: Smeli_genome.pkl
# [2025-10-14 20:03:54]   ✓ Saved FASTA: Smeli_RAST.fasta
# [2025-10-14 20:03:54]
# [43/57] Processing: SynE
# [2025-10-14 20:03:54]   FASTA file: SynE_proteins.fasta
# [2025-10-14 20:03:54]   Loading genome from FASTA...
# [2025-10-14 20:03:54]   Loaded 2669 features
# [2025-10-14 20:03:54]   Submitting to RAST for annotation...
# [2025-10-14 20:03:54]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:03:56]   ✓ Annotation complete (0.0 minutes)
# [2025-10-14 20:03:56]   Annotated features: 2530/2669
# [2025-10-14 20:03:56]   ✓ Saved pickle: SynE_genome.pkl
# [2025-10-14 20:03:56]   ✓ Saved FASTA: SynE_RAST.fasta
# [2025-10-14 20:03:56]
# [44/57] Processing: SyringaeB728a_mexBdelta
# [2025-10-14 20:03:56]   FASTA file: SyringaeB728a_mexBdelta_proteins.fasta
# [2025-10-14 20:03:56]   Loading genome from FASTA...
# [2025-10-14 20:03:56]   Loaded 5089 features
# [2025-10-14 20:03:56]   Submitting to RAST for annotation...
# [2025-10-14 20:03:56]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:04:00]   ✓ Annotation complete (0.1 minutes)
# [2025-10-14 20:04:00]   Annotated features: 4752/5089
# [2025-10-14 20:04:00]   ✓ Saved pickle: SyringaeB728a_mexBdelta_genome.pkl
# [2025-10-14 20:04:00]   ✓ Saved FASTA: SyringaeB728a_mexBdelta_RAST.fasta
# [2025-10-14 20:04:00]
# [45/57] Processing: SyringaeB728a
# [2025-10-14 20:04:00]   FASTA file: SyringaeB728a_proteins.fasta
# [2025-10-14 20:04:00]   Loading genome from FASTA...
# [2025-10-14 20:04:00]   Loaded 5089 features
# [2025-10-14 20:04:00]   Submitting to RAST for annotation...
# [2025-10-14 20:04:00]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:04:03]   ✓ Annotation complete (0.1 minutes)
# [2025-10-14 20:04:03]   Annotated features: 4752/5089
# [2025-10-14 20:04:03]   ✓ Saved pickle: SyringaeB728a_genome.pkl
# [2025-10-14 20:04:03]   ✓ Saved FASTA: SyringaeB728a_RAST.fasta
# [2025-10-14 20:04:03]
# [46/57] Processing: Variovorax_OAS795
# [2025-10-14 20:04:03]   FASTA file: Variovorax_OAS795_proteins.fasta
# [2025-10-14 20:04:03]   Loading genome from FASTA...
# [2025-10-14 20:04:03]   Loaded 5732 features
# [2025-10-14 20:04:03]   Submitting to RAST for annotation...
# [2025-10-14 20:04:03]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:04:07]   ✓ Annotation complete (0.1 minutes)
# [2025-10-14 20:04:07]   Annotated features: 5217/5732
# [2025-10-14 20:04:07]   ✓ Saved pickle: Variovorax_OAS795_genome.pkl
# [2025-10-14 20:04:07]   ✓ Saved FASTA: Variovorax_OAS795_RAST.fasta
# [2025-10-14 20:04:07]
# [47/57] Processing: WCS417
# [2025-10-14 20:04:07]   FASTA file: WCS417_proteins.fasta
# [2025-10-14 20:04:07]   Loading genome from FASTA...
# [2025-10-14 20:04:07]   Loaded 5506 features
# [2025-10-14 20:04:07]   Submitting to RAST for annotation...
# [2025-10-14 20:04:07]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:04:10]   ✓ Annotation complete (0.1 minutes)
# [2025-10-14 20:04:10]   Annotated features: 4940/5506
# [2025-10-14 20:04:10]   ✓ Saved pickle: WCS417_genome.pkl
# [2025-10-14 20:04:10]   ✓ Saved FASTA: WCS417_RAST.fasta
# [2025-10-14 20:04:10]
# [48/57] Processing: Xantho
# [2025-10-14 20:04:10]   FASTA file: Xantho_proteins.fasta
# [2025-10-14 20:04:10]   Loading genome from FASTA...
# [2025-10-14 20:04:10]   Loaded 4617 features
# [2025-10-14 20:04:10]   Submitting to RAST for annotation...
# [2025-10-14 20:04:10]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:04:14]   ✓ Annotation complete (0.1 minutes)
# [2025-10-14 20:04:14]   Annotated features: 4350/4617
# [2025-10-14 20:04:14]   ✓ Saved pickle: Xantho_genome.pkl
# [2025-10-14 20:04:14]   ✓ Saved FASTA: Xantho_RAST.fasta
# [2025-10-14 20:04:14]
# [49/57] Processing: acidovorax_3H11
# [2025-10-14 20:04:14]   FASTA file: acidovorax_3H11_proteins.fasta
# [2025-10-14 20:04:14]   Loading genome from FASTA...
# [2025-10-14 20:04:14]   Loaded 4964 features
# [2025-10-14 20:04:14]   Submitting to RAST for annotation...
# [2025-10-14 20:04:14]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:04:17]   ✓ Annotation complete (0.1 minutes)
# [2025-10-14 20:04:17]   Annotated features: 4239/4964
# [2025-10-14 20:04:17]   ✓ Saved pickle: acidovorax_3H11_genome.pkl
# [2025-10-14 20:04:17]   ✓ Saved FASTA: acidovorax_3H11_RAST.fasta
# [2025-10-14 20:04:17]
# [50/57] Processing: azobra
# [2025-10-14 20:04:17]   FASTA file: azobra_proteins.fasta
# [2025-10-14 20:04:17]   Loading genome from FASTA...
# [2025-10-14 20:04:17]   Loaded 5488 features
# [2025-10-14 20:04:17]   Submitting to RAST for annotation...
# [2025-10-14 20:04:17]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:04:21]   ✓ Annotation complete (0.1 minutes)
# [2025-10-14 20:04:21]   Annotated features: 4506/5488
# [2025-10-14 20:04:21]   ✓ Saved pickle: azobra_genome.pkl
# [2025-10-14 20:04:21]   ✓ Saved FASTA: azobra_RAST.fasta
# [2025-10-14 20:04:21]
# [51/57] Processing: psRCH2
# [2025-10-14 20:04:21]   FASTA file: psRCH2_proteins.fasta
# [2025-10-14 20:04:21]   Loading genome from FASTA...
# [2025-10-14 20:04:21]   Loaded 4265 features
# [2025-10-14 20:04:21]   Submitting to RAST for annotation...
# [2025-10-14 20:04:21]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:04:24]   ✓ Annotation complete (0.0 minutes)
# [2025-10-14 20:04:24]   Annotated features: 3675/4265
# [2025-10-14 20:04:24]   ✓ Saved pickle: psRCH2_genome.pkl
# [2025-10-14 20:04:24]   ✓ Saved FASTA: psRCH2_RAST.fasta
# [2025-10-14 20:04:24]
# [52/57] Processing: pseudo13_GW456_L13
# [2025-10-14 20:04:24]   FASTA file: pseudo13_GW456_L13_proteins.fasta
# [2025-10-14 20:04:24]   Loading genome from FASTA...
# [2025-10-14 20:04:24]   Loaded 5152 features
# [2025-10-14 20:04:24]   Submitting to RAST for annotation...
# [2025-10-14 20:04:24]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:04:27]   ✓ Annotation complete (0.1 minutes)
# [2025-10-14 20:04:27]   Annotated features: 4679/5152
# [2025-10-14 20:04:27]   ✓ Saved pickle: pseudo13_GW456_L13_genome.pkl
# [2025-10-14 20:04:27]   ✓ Saved FASTA: pseudo13_GW456_L13_RAST.fasta
# [2025-10-14 20:04:27]
# [53/57] Processing: pseudo1_N1B4
# [2025-10-14 20:04:27]   FASTA file: pseudo1_N1B4_proteins.fasta
# [2025-10-14 20:04:27]   Loading genome from FASTA...
# [2025-10-14 20:04:27]   Loaded 5972 features
# [2025-10-14 20:04:27]   Submitting to RAST for annotation...
# [2025-10-14 20:04:27]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:04:31]   ✓ Annotation complete (0.1 minutes)
# [2025-10-14 20:04:31]   Annotated features: 5180/5972
# [2025-10-14 20:04:31]   ✓ Saved pickle: pseudo1_N1B4_genome.pkl
# [2025-10-14 20:04:31]   ✓ Saved FASTA: pseudo1_N1B4_RAST.fasta
# [2025-10-14 20:04:31]
# [54/57] Processing: pseudo3_N2E3
# [2025-10-14 20:04:31]   FASTA file: pseudo3_N2E3_proteins.fasta
# [2025-10-14 20:04:31]   Loading genome from FASTA...
# [2025-10-14 20:04:31]   Loaded 5766 features
# [2025-10-14 20:04:31]   Submitting to RAST for annotation...
# [2025-10-14 20:04:31]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:04:34]   ✓ Annotation complete (0.1 minutes)
# [2025-10-14 20:04:34]   Annotated features: 5064/5766
# [2025-10-14 20:04:34]   ✓ Saved pickle: pseudo3_N2E3_genome.pkl
# [2025-10-14 20:04:34]   ✓ Saved FASTA: pseudo3_N2E3_RAST.fasta
# [2025-10-14 20:04:34]
# [55/57] Processing: pseudo5_N2C3_1
# [2025-10-14 20:04:34]   FASTA file: pseudo5_N2C3_1_proteins.fasta
# [2025-10-14 20:04:34]   Loading genome from FASTA...
# [2025-10-14 20:04:34]   Loaded 6000 features
# [2025-10-14 20:04:34]   Submitting to RAST for annotation...
# [2025-10-14 20:04:34]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:04:38]   ✓ Annotation complete (0.1 minutes)
# [2025-10-14 20:04:38]   Annotated features: 5458/6000
# [2025-10-14 20:04:39]   ✓ Saved pickle: pseudo5_N2C3_1_genome.pkl
# [2025-10-14 20:04:39]   ✓ Saved FASTA: pseudo5_N2C3_1_RAST.fasta
# [2025-10-14 20:04:39]
# [56/57] Processing: pseudo6_N2E2
# [2025-10-14 20:04:39]   FASTA file: pseudo6_N2E2_proteins.fasta
# [2025-10-14 20:04:39]   Loading genome from FASTA...
# [2025-10-14 20:04:39]   Loaded 6094 features
# [2025-10-14 20:04:39]   Submitting to RAST for annotation...
# [2025-10-14 20:04:39]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:04:42]   ✓ Annotation complete (0.1 minutes)
# [2025-10-14 20:04:42]   Annotated features: 5374/6094
# [2025-10-14 20:04:42]   ✓ Saved pickle: pseudo6_N2E2_genome.pkl
# [2025-10-14 20:04:42]   ✓ Saved FASTA: pseudo6_N2E2_RAST.fasta
# [2025-10-14 20:04:42]
# [57/57] Processing: rhodanobacter_10B01
# [2025-10-14 20:04:42]   FASTA file: rhodanobacter_10B01_proteins.fasta
# [2025-10-14 20:04:42]   Loading genome from FASTA...
# [2025-10-14 20:04:42]   Loaded 3526 features
# [2025-10-14 20:04:42]   Submitting to RAST for annotation...
# [2025-10-14 20:04:42]   ⏳ This will take 2-4 hours - please be patient
# [2025-10-14 20:04:45]   ✓ Annotation complete (0.0 minutes)
# [2025-10-14 20:04:45]   Annotated features: 3337/3526
# [2025-10-14 20:04:45]   ✓ Saved pickle: rhodanobacter_10B01_genome.pkl
# [2025-10-14 20:04:45]   ✓ Saved FASTA: rhodanobacter_10B01_RAST.fasta
# [2025-10-14 20:04:45]
# ================================================================================
# [2025-10-14 20:04:45] ANNOTATION SUMMARY
# [2025-10-14 20:04:45] ================================================================================
# [2025-10-14 20:04:45] Total processed: 57
# [2025-10-14 20:04:45]   Completed: 57
# [2025-10-14 20:04:45]   Skipped (already done): 0
# [2025-10-14 20:04:45]   Failed: 0
# [2025-10-14 20:04:45]
# Output directory: results/genomes
# [2025-10-14 20:04:45] ================================================================================

# %% [markdown]
# ## Check Annotation Status

# %%
print("Checking annotation status for all organisms...")
print("="*80)

annotated_genomes = []
pending_genomes = []

for fasta_file in fasta_files:
    organism_id = get_organism_id(fasta_file.name)
    
    if genome_already_annotated(organism_id):
        annotated_genomes.append(organism_id)
    else:
        pending_genomes.append(organism_id)

print(f"\nAnnotated: {len(annotated_genomes)}/{len(fasta_files)} ({100*len(annotated_genomes)/len(fasta_files):.1f}%)")
print(f"Pending: {len(pending_genomes)} ({100*len(pending_genomes)/len(fasta_files):.1f}%)")

if pending_genomes:
    print(f"\n⚠️  Still need to annotate:")
    for org_id in pending_genomes[:10]:
        print(f"  - {org_id}")
    if len(pending_genomes) > 10:
        print(f"  ... and {len(pending_genomes) - 10} more")
else:
    print(f"\n✓ All genomes annotated!")

print("="*80)
# Out:
# Checking annotation status for all organisms...
# ================================================================================
#
# Annotated: 57/57 (100.0%)
# Pending: 0 (0.0%)
#
# ✓ All genomes annotated!
# ================================================================================

# %% [markdown]
# ## Load and Inspect Annotated Genome (Example)

# %%
if annotated_genomes:
    # Load first annotated genome as example
    example_org = annotated_genomes[0]
    print(f"Loading example genome: {example_org}")
    
    genome = load_genome(example_org)
    
    print(f"\nGenome information:")
    print(f"  Total features: {len(genome.features)}")
    
    # Count annotated features
    annotated = [f for f in genome.features if f.ontology_terms]
    print(f"  Annotated features: {len(annotated)}")
    print(f"  Annotation rate: {100*len(annotated)/len(genome.features):.1f}%")
    
    # Show first 5 annotated features
    print(f"\nFirst 5 annotated features:")
    for i, feature in enumerate(annotated[:5], 1):
        print(f"  {i}. {feature.id}")
        print(f"     Roles: {feature.ontology_terms[:2] if len(feature.ontology_terms) > 2 else feature.ontology_terms}")
else:
    print("No annotated genomes found. Please run annotation first.")
# Out:
# Loading example genome: ANA3
#
# Genome information:
#   Total features: 4360
#   Annotated features: 4071
#   Annotation rate: 93.4%
#
# First 5 annotated features:
#   1. ANA3:7022746
#      Roles: {'RAST': ['16S rRNA (guanine(527)-N(7))-methyltransferase (EC 2.1.1.170)']}
#   2. ANA3:7022747
#      Roles: {'RAST': ['tRNA-5-carboxymethylaminomethyl-2-thiouridine(34) synthesis protein MnmG']}
#   3. ANA3:7022748
#      Roles: {'RAST': ['Flavoprotein MioC']}
#   4. ANA3:7022749
#      Roles: {'RAST': ['amino acid/peptide transporter']}
#   5. ANA3:7022750
#      Roles: {'RAST': ['tRNA-5-carboxymethylaminomethyl-2-thiouridine(34) synthesis protein MnmE']}

# %% [markdown]
# ## Summary
#
# - `results/genomes/{organism_id}_genome.pkl` - Annotated genome objects (57 files)
# - `results/fasta_annotated/{organism_id}_RAST.fasta` - Annotated FASTA files (57 files)
# - `results/rast_annotation_log.txt` - Annotation log with timestamps
#
# **Next Steps**:
# 1. Wait for all RAST annotations to complete
# 2. Proceed to next notebook: `02-build-metabolic-models.ipynb`
# 3. Build genome-scale metabolic models using annotated genomes + templates
#
# **Important Notes**:
# - You can stop and resume this notebook anytime
# - Already annotated genomes will be skipped automatically
# - Check `rast_annotation_log.txt` for detailed progress
# - RAST requires internet connection
# - Total time: ~114-228 hours for 57 genomes (if run serially)
#
# **Troubleshooting**:
# - If RAST fails, check internet connection
# - If annotation hangs, restart the cell (progress is saved)
# - For issues, check RAST service status at http://rast.nmpdr.org
