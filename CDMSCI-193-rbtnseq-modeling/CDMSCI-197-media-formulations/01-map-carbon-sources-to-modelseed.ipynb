# %% [markdown]
# # Map Carbon Sources to ModelSEED Compound IDs
#
# **Parent**: CDMSCI-193 - RBTnSeq Modeling Analysis
#
# **Ticket**: CDMSCI-197 - Translate to Computational Media Formulations
#
# ## Objective
#
# Map 206 carbon sources from Fitness Browser data to ModelSEED compound IDs (cpd#####) for metabolic modeling.
#
# ## Mapping Strategy
#
# **Round 1: Automated Search**
# 1. Search local template (GramNegModelTemplateV6.json)
# 2. Search ModelSEED Solr API (https://modelseed.org)
# 3. Handle duplicates by choosing lower compound ID
#
# **Round 2: AI-Assisted Mapping**
# 1. Use GPT-5 (via Argo proxy) for unmapped compounds
# 2. Provide compound name + chemical context
# 3. Get ModelSEED ID suggestion with explanation
#
# ## Outputs
#
# 1. `carbon_source_mapping.csv` - Complete mapping table
# 2. `media/` directory - Individual media JSON files for each carbon source
#
# **Last updated**: 2025-10-07

# %% [markdown]
# ## Setup

# %%
import json
import pandas as pd
import numpy as np
from pathlib import Path
from urllib.request import urlopen, URLError
from urllib.parse import quote
import requests
import time

print("Imports successful")
# Out:
# Imports successful

# %% [markdown]
# ## Configuration

# %%
# Paths
CARBON_SOURCES_FILE = Path('../CDMSCI-196-carbon-sources/results/combined_growth_matrix.csv')
TEMPLATE_PATH = Path('../references/build_metabolic_model/GramNegModelTemplateV6.json')

# Output paths
OUTPUT_DIR = Path('results')
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

MEDIA_DIR = Path('media')
MEDIA_DIR.mkdir(parents=True, exist_ok=True)

MAPPING_FILE = OUTPUT_DIR / 'carbon_source_mapping.csv'

# ModelSEED Solr API
SOLR_URL = 'https://modelseed.org/solr/compounds/select'

# Argo proxy for LLM
ARGO_BASE_URL = 'http://localhost:8000/v1'
ARGO_MODEL = 'argo:o3'  # Latest GPT-5 reasoning model


# Local ModelSEED Database files
MODELSEED_ALIASES = Path('../data/modelseed_database/Unique_ModelSEED_Compound_Aliases.txt')
MODELSEED_NAMES = Path('../data/modelseed_database/Unique_ModelSEED_Compound_Names.txt')
print(f"Configuration set")
print(f"  Carbon sources: {CARBON_SOURCES_FILE}")
print(f"  Template: {TEMPLATE_PATH}")
print(f"  Output: {MAPPING_FILE}")
print(f"  Media directory: {MEDIA_DIR}")
# Out:
# Configuration set
#   Carbon sources: ../CDMSCI-196-carbon-sources/results/combined_growth_matrix.csv
#   Template: ../references/build_metabolic_model/GramNegModelTemplateV6.json
#   Output: results/carbon_source_mapping.csv
#   Media directory: media

# %% [markdown]
# ## Load Carbon Sources

# %%
print("Loading carbon sources from combined growth matrix...")
growth_matrix = pd.read_csv(CARBON_SOURCES_FILE, index_col=0)

carbon_sources = growth_matrix.index.tolist()

print(f"\nLoaded {len(carbon_sources)} carbon sources")
print(f"\nFirst 10 carbon sources:")
for i, cs in enumerate(carbon_sources[:10], 1):
    print(f"  {i:3d}. {cs}")
# Out:
# Loading carbon sources from combined growth matrix...
#
# Loaded 206 carbon sources
#
# First 10 carbon sources:
#     1. (+)-Arabinogalactan
#     2. 1-Pentanol
#     3. 1,2-Propanediol
#     4. 1,3-Butandiol
#     5. 1,4-B-D-Galactobiose
#     6. 1,4-Butanediol
#     7. 1,5-Pentanediol
#     8. 2'-Deoxycytidine
#     9. 2'-Deoxyinosine
#    10. 2-Deoxy-D-ribonic acid lithium salt

# %% [markdown]
# ## Load Template

# %%
print(f"Loading ModelSEED template: {TEMPLATE_PATH}")
with open(TEMPLATE_PATH) as f:
    template = json.load(f)

print(f"\nTemplate loaded:")
print(f"  Compounds: {len(template['compounds'])}")
print(f"  Reactions: {len(template['reactions'])}")

# Create compound index for fast lookup
template_compounds = template['compounds']
print(f"\nIndexed {len(template_compounds)} compounds for searching")
# Out:
# Loading ModelSEED template: ../references/build_metabolic_model/GramNegModelTemplateV6.json
#
# Template loaded:
#   Compounds: 6573
#   Reactions: 8584
#
# Indexed 6573 compounds for searching

# %%
# Load ModelSEED alias files (local, no internet needed)
print("Loading ModelSEED alias files...")

# Load compound names
compound_names = {}
with open(MODELSEED_NAMES) as f:
    next(f)  # Skip header
    for line in f:
        parts = line.strip().split('\t')
        if len(parts) >= 2:
            cpd_id = parts[0]
            name = parts[1].lower()
            if name not in compound_names:
                compound_names[name] = []
            compound_names[name].append(cpd_id)

print(f"  Loaded {len(compound_names):,} compound names")

# Load compound aliases
compound_aliases = {}
with open(MODELSEED_ALIASES) as f:
    next(f)  # Skip header
    for line in f:
        parts = line.strip().split('\t')
        if len(parts) >= 3:
            cpd_id = parts[0]
            alias = parts[1].lower()
            source = parts[2]
            if alias not in compound_aliases:
                compound_aliases[alias] = []
            compound_aliases[alias].append(cpd_id)

print(f"  Loaded {len(compound_aliases):,} compound aliases")
print("ModelSEED database ready for offline searching")
# Out:
# Loading ModelSEED alias files...
#   Loaded 130,196 compound names
#   Loaded 108,286 compound aliases
# ModelSEED database ready for offline searching

# %% [markdown]
# ## Search Functions

# %%
def search_template(compound_name):
    """Search for compound in local template"""
    matches = []
    search_lower = compound_name.lower()
    
    for compound in template_compounds:
        # Search in name
        if search_lower == compound['name'].lower():
            matches.append(compound)
            continue
        
        # Search in abbreviation
        abbr = compound.get('abbreviation', '')
        if abbr and search_lower == abbr.lower():
            matches.append(compound)
            continue
        
        # Search in aliases
        for alias in compound.get('aliases', []):
            if search_lower in alias.lower():
                matches.append(compound)
                break
    
    return matches


def search_template_by_id(compound_id):
    """Search for compound by ID in local template"""
    for compound in template_compounds:
        if compound['id'] == compound_id:
            return compound
    return None


def search_modelseed_local(compound_name):
    """Search ModelSEED using local alias files (offline)"""
    search_lower = compound_name.lower()
    found_ids = set()

    # Search in compound names
    if search_lower in compound_names:
        found_ids.update(compound_names[search_lower])

    # Search in aliases
    if search_lower in compound_aliases:
        found_ids.update(compound_aliases[search_lower])

    # Get compound details from template
    matches = []
    for cpd_id in found_ids:
        compound = search_template_by_id(cpd_id)
        if compound:
            matches.append({
                'id': cpd_id,
                'name': compound['name'],
                'formula': compound.get('formula', ''),
                'charge': compound.get('defaultCharge', 0),
                'mass': compound.get('mass', 0),
                'source': 'modelseed_local'
            })

    return matches


def search_compound_round1(compound_name):
    """Round 1: Search template and local ModelSEED database"""
    # Try template first (faster, offline)
    template_matches = search_template(compound_name)
    
    # Try local ModelSEED if no template matches
    modelseed_matches = search_modelseed_local(compound_name) if not template_matches else []
    
    # Combine and deduplicate
    all_matches = []
    seen_ids = set()
    
    for match in template_matches:
        cpd_id = match['id']
        if cpd_id not in seen_ids:
            all_matches.append({
                'id': cpd_id,
                'name': match['name'],
                'formula': match.get('formula', ''),
                'charge': match.get('defaultCharge', 0),
                'mass': match.get('mass', 0),
                'source': 'template'
            })
            seen_ids.add(cpd_id)
    
    for match in modelseed_matches:
        cpd_id = match['id']
        if cpd_id not in seen_ids:
            all_matches.append(match)
            seen_ids.add(cpd_id)
    
    # Sort by ID (lower IDs first)
    all_matches.sort(key=lambda x: x['id'])
    
    return all_matches

print("Search functions defined")
# Out:
# Search functions defined

# %% [markdown]
# ## AI-Assisted Mapping (Round 2)

# %%
def ask_llm_for_mapping(compound_name):
    """Use LLM to suggest ModelSEED compound ID"""
    
    prompt = f"""You are a biochemistry expert helping map compound names to ModelSEED database IDs.

Compound name: "{compound_name}"

Task: Suggest the most likely ModelSEED compound ID (format: cpd#####) for this compound.

Context:
- This is a carbon source from bacterial growth experiments
- ModelSEED uses standardized compound IDs (e.g., cpd00027 = D-Glucose)
- Common carbon sources: glucose (cpd00027), glycerol (cpd00100), acetate (cpd00029)
- For complex names, try to identify the base metabolite
- For salts/hydrates, use the base compound (e.g., "Citric Acid" → cpd00137 = Citrate)
- For polymers, suggest the monomer (e.g., "Amylose" → cpd00027 = Glucose)

Response format (JSON):
{{
  "compound_id": "cpd#####",
  "compound_name": "Official ModelSEED name",
  "explanation": "One-line explanation of mapping rationale",
  "confidence": "high/medium/low"
}}

If you cannot confidently map this compound, return:
{{
  "compound_id": "UNMAPPED",
  "compound_name": "",
  "explanation": "Reason why mapping is not possible",
  "confidence": "low"
}}
"""
    
    try:
        response = requests.post(
            f"{ARGO_BASE_URL}/chat/completions",
            json={
                "model": ARGO_MODEL,
                "messages": [{"role": "user", "content": prompt}],
                "temperature": 0.1,  # Low temperature for consistent reasoning
                "max_tokens": 500
            },
            timeout=30
        )
        
        if response.status_code == 200:
            result = response.json()
            content = result['choices'][0]['message']['content']
            
            # Try to parse JSON from response
            # Handle markdown code blocks if present
            if '```json' in content:
                content = content.split('```json')[1].split('```')[0].strip()
            elif '```' in content:
                content = content.split('```')[1].split('```')[0].strip()
            
            mapping = json.loads(content)
            return mapping
        else:
            print(f"    WARNING: LLM request failed with status {response.status_code}")
            return None
            
    except Exception as e:
        print(f"    WARNING: LLM request error: {e}")
        return None

print("LLM function defined")
# Out:
# LLM function defined

# %% [markdown]
# ## Round 1: Automated Mapping

# %%
print("="*80)
print("ROUND 1: AUTOMATED MAPPING")
print("="*80)

mappings = []
unmapped = []

for i, carbon_source in enumerate(carbon_sources, 1):
    print(f"\n[{i}/{len(carbon_sources)}] {carbon_source}")
    
    matches = search_compound_round1(carbon_source)
    
    if matches:
        # Found matches
        best_match = matches[0]  # Lowest ID (already sorted)
        
        if len(matches) > 1:
            # Report duplicates
            duplicate_ids = [m['id'] for m in matches]
            print(f"  ⚠️  DUPLICATE: Found {len(matches)} matches: {duplicate_ids}")
            print(f"  ✓  Selected: {best_match['id']} (lowest ID)")
        else:
            print(f"  ✓  Mapped: {best_match['id']} - {best_match['name']}")
        
        mappings.append({
            'Carbon_Source_Original': carbon_source,
            'ModelSEED_ID': best_match['id'],
            'ModelSEED_Name': best_match['name'],
            'Formula': best_match['formula'],
            'Mass': best_match['mass'],
            'Charge': best_match['charge'],
            'Mapping_Method': f"round1_{best_match['source']}",
            'Confidence': 'High',
            'AI_Explanation': '',
            'Duplicate_IDs': ';'.join([m['id'] for m in matches[1:]]) if len(matches) > 1 else ''
        })
    else:
        # No matches found
        print(f"  ✗  NOT FOUND - will try LLM in Round 2")
        unmapped.append(carbon_source)

print(f"\n{'='*80}")
print(f"ROUND 1 COMPLETE")
print(f"  Mapped: {len(mappings)} ({100*len(mappings)/len(carbon_sources):.1f}%)")
print(f"  Unmapped: {len(unmapped)} ({100*len(unmapped)/len(carbon_sources):.1f}%)")
print(f"{'='*80}")
# Out:
# ================================================================================
# ROUND 1: AUTOMATED MAPPING
# ================================================================================
#
# [1/206] (+)-Arabinogalactan
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [2/206] 1-Pentanol
#   ✓  Mapped: cpd16586 - 1-Pentanol
#
# [3/206] 1,2-Propanediol
#   ✓  Mapped: cpd00453 - 1,2-Propanediol
#
# [4/206] 1,3-Butandiol
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [5/206] 1,4-B-D-Galactobiose
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [6/206] 1,4-Butanediol
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [7/206] 1,5-Pentanediol
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [8/206] 2'-Deoxycytidine
#   ✓  Mapped: cpd00654 - Deoxycytidine
#
# [9/206] 2'-Deoxyinosine
#   ✓  Mapped: cpd03279 - Deoxyinosine
#
# [10/206] 2-Deoxy-D-ribonic acid lithium salt
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [11/206] 2-Deoxy-D-Ribose
#   ✓  Mapped: cpd01242 - Thyminose
#
# [12/206] 2-Deoxyadenosine monohydrate
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [13/206] 2-Deoxyadenosine 5-monophosphate
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [14/206] 2-methyl-1-butanol
#   ✓  Mapped: cpd16873 - 2-methyl-1-butanol
#
# [15/206] 2-Piperidinone
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [16/206] 3-methyl-1-butanol
#   ✓  Mapped: cpd04533 - Isoamyl alcohol
#
# [17/206] 3-Methyl-2-Oxobutanoic Acid
#   ✓  Mapped: cpd00123 - 3-Methyl-2-oxobutanoate
#
# [18/206] 3-methyl-2-oxopentanoic acid
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [19/206] 3-methyl-3-butenol
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [20/206] 4-Aminobutyric acid
#   ✓  Mapped: cpd00281 - GABA
#
# [21/206] 4-Hydroxybenzoic Acid
#   ✓  Mapped: cpd00136 - 4-Hydroxybenzoate
#
# [22/206] 4-Hydroxyvalerate
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [23/206] 4-Methyl-2-oxovaleric acid
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [24/206] 5-Aminovaleric acid
#   ✓  Mapped: cpd00339 - 5-Aminopentanoate
#
# [25/206] 5-Keto-D-Gluconic Acid potassium salt
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [26/206] 6-O-Acetyl-D-glucose
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [27/206] a-Cyclodextrin
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [28/206] a-Ketoglutaric acid disodium salt hydrate
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [29/206] Acetylated xylan
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [30/206] Actilight
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [31/206] Adenine hydrochloride hydrate
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [32/206] Adenosine
#   ✓  Mapped: cpd00182 - Adenosine
#
# [33/206] Agro_defined_trehalose
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [34/206] amylopectin from maize
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [35/206] Amylose from potato
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [36/206] Avantafiber
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [37/206] Azelaic acid
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [38/206] benzoic acid
#   ✓  Mapped: cpd00153 - Benzoate
#
# [39/206] Beta-Lactose
#   ✓  Mapped: cpd01354 - beta-Lactose
#
# [40/206] Bimuno-prebiotic
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [41/206] Bioecolians-prebiotic
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [42/206] Butanol
#   ⚠️  DUPLICATE: Found 2 matches: ['cpd03662', 'cpd10408']
#   ✓  Selected: cpd03662 (lowest ID)
#
# [43/206] Butyl stearate
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [44/206] Carnitine Hydrochloride
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [45/206] casamino acids
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [46/206] Chondroitin sulfate A sodium salt from bovine trachea
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [47/206] Citric Acid
#   ✓  Mapped: cpd00137 - Citrate
#
# [48/206] CravingZGone-prebiotic
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [49/206] Cytidine
#   ✓  Mapped: cpd00367 - Cytidine
#
# [50/206] Cytosine
#   ✓  Mapped: cpd00307 - Cytosine
#
# [51/206] D-Alanine
#   ✓  Mapped: cpd00117 - D-Alanine
#
# [52/206] D-Arabinose
#   ✓  Mapped: cpd00185 - D-Arabinose
#
# [53/206] D-Cellobiose
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [54/206] D-Fructose
#   ✓  Mapped: cpd00082 - D-Fructose
#
# [55/206] D-Galactose
#   ⚠️  DUPLICATE: Found 2 matches: ['cpd00108', 'cpd00709']
#   ✓  Selected: cpd00108 (lowest ID)
#
# [56/206] D-Galacturonic Acid monohydrate
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [57/206] D-Gluconic Acid sodium salt
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [58/206] D-Glucosamine Hydrochloride
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [59/206] D-Glucose
#   ✓  Mapped: cpd00027 - D-Glucose
#
# [60/206] D-Glucose-6-Phosphate sodium salt
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [61/206] D-Glucuronic Acid
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [62/206] D-Leucrose
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [63/206] D-Lysine
#   ✓  Mapped: cpd00549 - D-Lysine
#
# [64/206] D-Maltose monohydrate
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [65/206] D-Mannitol
#   ✓  Mapped: cpd00314 - D-Mannitol
#
# [66/206] D-Mannose
#   ✓  Mapped: cpd00138 - D-Mannose
#
# [67/206] D-Raffinose pentahydrate
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [68/206] D-Ribose
#   ✓  Mapped: cpd00105 - D-Ribose
#
# [69/206] D-Salicin
#   ✓  Mapped: cpd01030 - Salicin
#
# [70/206] D-Serine
#   ✓  Mapped: cpd00550 - D-Serine
#
# [71/206] D-Sorbitol
#   ✓  Mapped: cpd00588 - Sorbitol
#
# [72/206] D-Tagatose
#   ✓  Mapped: cpd00589 - D-Tagatose
#
# [73/206] D-Trehalose dihydrate
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [74/206] D-Xylose
#   ✓  Mapped: cpd00154 - Xylose
#
# [75/206] Decanoic acid
#   ✓  Mapped: cpd01107 - Decanoate
#
# [76/206] Deoxyribonucleic acid from herring sperm
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [77/206] dextran, Mw ~200,000
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [78/206] Disodium Glutarate
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [79/206] D,L-Malic Acid
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [80/206] Dodecandioic acid
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [81/206] Ethanol
#   ✓  Mapped: cpd00363 - Ethanol
#
# [82/206] Ferulic Acid
#   ✓  Mapped: cpd01059 - Ferulate
#
# [83/206] Fibersol-2-AG-fiber
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [84/206] Fructooligosaccharides (FOS)
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [85/206] Fructooligosaccharides from chicory
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [86/206] Fumaric acid
#   ✓  Mapped: cpd00106 - Fumarate
#
# [87/206] Gelatin
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [88/206] Glucuronamide
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [89/206] Gly-DL-Asp
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [90/206] Gly-Glu
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [91/206] Glycerol
#   ✓  Mapped: cpd00100 - Glycerol
#
# [92/206] Glycine
#   ✓  Mapped: cpd00033 - Glycine
#
# [93/206] Glycolic Acid
#   ✓  Mapped: cpd00139 - Glycolate
#
# [94/206] Heparin sodium salt from porcine intestinal mucosa
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [95/206] Heptanoic acid
#   ✓  Mapped: cpd15608 - HPA
#
# [96/206] Hexanoic acid
#   ✓  Mapped: cpd01113 - Hexanoate
#
# [97/206] Hyaluronic acid sodium salt from Streptococcus equi
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [98/206] Hydroxy-L-Proline
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [99/206] Inosine
#   ✓  Mapped: cpd00246 - Inosine
#
# [100/206] Inulin from chicory
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [101/206] Isomaltose
#   ✓  Mapped: cpd00217 - Brachiose
#
# [102/206] ISOThrive-prebiotic lot A
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [103/206] ISOThrive-prebiotic lot B
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [104/206] ISOThrive-prebiotic lot C
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [105/206] ISOThrive-prebiotic lot D
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [106/206] Itaconic Acid
#   ✓  Mapped: cpd00380 - Itaconate
#
# [107/206] L-Alanine
#   ✓  Mapped: cpd00035 - L-Alanine
#
# [108/206] L-Arabinose
#   ✓  Mapped: cpd00224 - L-Arabinose
#
# [109/206] L-Arginine
#   ✓  Mapped: cpd00051 - L-Arginine
#
# [110/206] L-Asparagine
#   ✓  Mapped: cpd00132 - L-Asparagine
#
# [111/206] L-Aspartic Acid
#   ✓  Mapped: cpd00041 - L-Aspartate
#
# [112/206] L-Citrulline
#   ✓  Mapped: cpd00274 - Citrulline
#
# [113/206] L-Cysteine hydrochloride monohydrate
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [114/206] L-Fucose
#   ✓  Mapped: cpd00751 - L-Fucose
#
# [115/206] L-Glutamic acid monopotassium salt monohydrate
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [116/206] L-Glutamine
#   ✓  Mapped: cpd00053 - L-Glutamine
#
# [117/206] L-Histidine
#   ✓  Mapped: cpd00119 - L-Histidine
#
# [118/206] L-Isoleucine
#   ✓  Mapped: cpd00322 - L-Isoleucine
#
# [119/206] L-Leucine
#   ✓  Mapped: cpd00107 - L-Leucine
#
# [120/206] L-Lysine
#   ✓  Mapped: cpd00039 - L-Lysine
#
# [121/206] L-Malic acid disodium salt monohydrate
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [122/206] L-Methionine
#   ✓  Mapped: cpd00060 - L-Methionine
#
# [123/206] L-Ornithine
#   ✓  Mapped: cpd00064 - Ornithine
#
# [124/206] L-Phenylalanine
#   ✓  Mapped: cpd00066 - L-Phenylalanine
#
# [125/206] L-Proline
#   ✓  Mapped: cpd00129 - L-Proline
#
# [126/206] L-Rhamnose monohydrate
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [127/206] L-Serine
#   ✓  Mapped: cpd00054 - L-Serine
#
# [128/206] L-Sorbose
#   ✓  Mapped: cpd00212 - L-Sorbose
#
# [129/206] L-Threonine
#   ✓  Mapped: cpd00161 - L-Threonine
#
# [130/206] L-Tryptophan
#   ✓  Mapped: cpd00065 - L-Tryptophan
#
# [131/206] L-tyrosine disodium salt
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [132/206] L-Valine
#   ✓  Mapped: cpd00156 - L-Valine
#
# [133/206] Lactitol
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [134/206] Lacto-N-neotetraose
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [135/206] Lacto-N-tetraose
#   ✓  Mapped: cpd03807 - Lacto-N-tetraose
#
# [136/206] Lactulose
#   ✓  Mapped: cpd04349 - Lactulose
#
# [137/206] Laminaribiose
#   ✓  Mapped: cpd01397 - Laminariaceae
#
# [138/206] Laminarin from Laminaria digitata
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [139/206] Lauric acid
#   ✓  Mapped: cpd01741 - ddca
#
# [140/206] Levan - from Erwinia herbicola
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [141/206] Levulinic Acid
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [142/206] m-Inositol
#   ✓  Mapped: cpd00121 - L-Inositol
#
# [143/206] Malonic acid
#   ✓  Mapped: cpd00308 - Malonate
#
# [144/206] Maltitol
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [145/206] Maltodextrin
#   ✓  Mapped: cpd11976 - Maltodextrin
#
# [146/206] Maltohexaose
#   ✓  Mapped: cpd01329 - Maltohexaose
#
# [147/206] Maltotetraose
#   ✓  Mapped: cpd01399 - Maltotetraose
#
# [148/206] Mannan from Saccharomyces cerevisiae
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [149/206] Melibiose
#   ✓  Mapped: cpd03198 - Melibiose
#
# [150/206] Methyl-B-D-galactopyranoside
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [151/206] Myristic acid
#   ✓  Mapped: cpd03847 - Myristic acid
#
# [152/206] N-Acetyl-D-Glucosamine
#   ✓  Mapped: cpd00122 - N-Acetyl-D-glucosamine
#
# [153/206] Nonanoic acid
#   ✓  Mapped: cpd01126 - Nonanoate
#
# [154/206] Octanoic acid
#   ✓  Mapped: cpd03846 - octanoate
#
# [155/206] Oleic acid
#   ✓  Mapped: cpd00536 - Oleate
#
# [156/206] p-Coumaric acid
#   ✓  Mapped: cpd00604 - 4-Coumarate
#
# [157/206] palatinose hydrate
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [158/206] Parabanic Acid
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [159/206] Pectin
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [160/206] Phenylacetic acid
#   ✓  Mapped: cpd00430 - PACT
#
# [161/206] Pimelic acid
#   ✓  Mapped: cpd01727 - Pimelate
#
# [162/206] polygalacturonic acid
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [163/206] Potassium acetate
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [164/206] Potassium oxalate monohydrate
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [165/206] Prebiotin-prebiotic
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [166/206] PreticX-prebiotic
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [167/206] Promitor-fiber
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [168/206] Protocatechuic Acid
#   ✓  Mapped: cpd00197 - Protocatechuate
#
# [169/206] Putrescine Dihydrochloride
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [170/206] Red Arabinan from sugar-beet
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [171/206] Rhamnogalacturonan - from potato
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [172/206] Sebacic acid
#   ✓  Mapped: cpd05192 - sebacate
#
# [173/206] Shikimic Acid
#   ✓  Mapped: cpd00383 - Shikimate
#
# [174/206] Sodium acetate
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [175/206] Sodium adipate
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [176/206] Sodium butyrate
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [177/206] Sodium D-Lactate
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [178/206] Sodium D,L-Lactate
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [179/206] Sodium Formate
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [180/206] Sodium Fumarate dibasic
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [181/206] Sodium L-Lactate
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [182/206] Sodium octanoate
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [183/206] Sodium propionate
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [184/206] Sodium pyruvate
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [185/206] Sodium succinate dibasic hexahydrate
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [186/206] Stachyose - 70%
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [187/206] Starch
#   ✓  Mapped: cpd11657 - Starch
#
# [188/206] Suberic acid
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [189/206] Succinic Acid
#   ✓  Mapped: cpd00036 - Succinate
#
# [190/206] Sucrose
#   ✓  Mapped: cpd00076 - Sucrose
#
# [191/206] Sunfiber-fiber
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [192/206] Supernatant; Agrobacterium rhizogenes K599 grown in Agro_defined_trehalose (~7.5 mM 3-keto-trehalose)
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [193/206] Thymidine
#   ✓  Mapped: cpd00184 - Thymidine
#
# [194/206] Thymine
#   ✓  Mapped: cpd00151 - Thymine
#
# [195/206] Trisodium citrate dihydrate
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [196/206] Tween 20
#   ✓  Mapped: cpd13391 - Tween 20
#
# [197/206] Unnamed: 1
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [198/206] Uridine
#   ✓  Mapped: cpd00249 - Uridine
#
# [199/206] Valeric acid
#   ✓  Mapped: cpd00597 - Valerate
#
# [200/206] Vanillic Acid
#   ✓  Mapped: cpd04073 - Vanillate
#
# [201/206] Vanillin
#   ✓  Mapped: cpd00561 - Vanillin
#
# [202/206] Vitafiber-prebiotic
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [203/206] Vitagos-prebiotic
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [204/206] WakoIMO-prebiotic
#   ✗  NOT FOUND - will try LLM in Round 2
#
# [205/206] Xylitol
#   ✓  Mapped: cpd00306 - Xylitol
#
# [206/206] Yacontrol-prebiotic
#   ✗  NOT FOUND - will try LLM in Round 2
#
# ================================================================================
# ROUND 1 COMPLETE
#   Mapped: 97 (47.1%)
#   Unmapped: 109 (52.9%)
# ================================================================================

# %% [markdown]
# ## Round 2: AI-Assisted Mapping

# %%
if unmapped:
    print("\n" + "="*80)
    print("ROUND 2: AI-ASSISTED MAPPING")
    print("="*80)
    print(f"\nAttempting to map {len(unmapped)} compounds using LLM...")
    
    for i, carbon_source in enumerate(unmapped, 1):
        print(f"\n[{i}/{len(unmapped)}] {carbon_source}")
        
        llm_result = ask_llm_for_mapping(carbon_source)
        
        if llm_result:
            cpd_id = llm_result.get('compound_id', 'UNMAPPED')
            cpd_name = llm_result.get('compound_name', '')
            explanation = llm_result.get('explanation', '')
            confidence = llm_result.get('confidence', 'low')
            
            if cpd_id != 'UNMAPPED':
                print(f"  🤖 LLM Mapped: {cpd_id} - {cpd_name}")
                print(f"     Explanation: {explanation}")
                print(f"     Confidence: {confidence}")
                
                # Verify LLM suggestion exists in template
                verification = search_template_by_id(cpd_id)
                if verification:
                    print(f"  ✓  Verified in template")
                    mappings.append({
                        'Carbon_Source_Original': carbon_source,
                        'ModelSEED_ID': cpd_id,
                        'ModelSEED_Name': verification['name'],
                        'Formula': verification.get('formula', ''),
                        'Mass': verification.get('mass', 0),
                        'Charge': verification.get('defaultCharge', 0),
                        'Mapping_Method': 'round2_llm',
                        'Confidence': confidence.capitalize(),
                        'AI_Explanation': explanation,
                        'Duplicate_IDs': ''
                    })
                else:
                    print(f"  ⚠️  NOT VERIFIED - LLM suggested ID not in template")
                    mappings.append({
                        'Carbon_Source_Original': carbon_source,
                        'ModelSEED_ID': 'UNMAPPED',
                        'ModelSEED_Name': '',
                        'Formula': '',
                        'Mass': 0,
                        'Charge': 0,
                        'Mapping_Method': 'round2_llm_unverified',
                        'Confidence': 'Low',
                        'AI_Explanation': f"LLM suggested {cpd_id} but not found in template",
                        'Duplicate_IDs': ''
                    })
            else:
                print(f"  ✗  LLM could not map: {explanation}")
                mappings.append({
                    'Carbon_Source_Original': carbon_source,
                    'ModelSEED_ID': 'UNMAPPED',
                    'ModelSEED_Name': '',
                    'Formula': '',
                    'Mass': 0,
                    'Charge': 0,
                    'Mapping_Method': 'round2_llm_failed',
                    'Confidence': 'Low',
                    'AI_Explanation': explanation,
                    'Duplicate_IDs': ''
                })
        else:
            print(f"  ✗  LLM request failed")
            mappings.append({
                'Carbon_Source_Original': carbon_source,
                'ModelSEED_ID': 'UNMAPPED',
                'ModelSEED_Name': '',
                'Formula': '',
                'Mass': 0,
                'Charge': 0,
                'Mapping_Method': 'round2_llm_error',
                'Confidence': 'Low',
                'AI_Explanation': 'LLM request error',
                'Duplicate_IDs': ''
            })
        
        # Rate limit: small delay between requests
        time.sleep(0.5)
    
    print(f"\n{'='*80}")
    print("ROUND 2 COMPLETE")
    print(f"{'='*80}")
else:
    print("\n✓ All compounds mapped in Round 1 - skipping Round 2")
# Out:
# ================================================================================
# ROUND 2: AI-ASSISTED MAPPING
# ================================================================================
#
# Attempting to map 109 compounds using LLM...
#
# [1/109] (+)-Arabinogalactan
#   ✗  LLM could not map: Arabinogalactan is a heterogeneous polysaccharide rather than a defined monomeric metabolite; no explicit entry for this polymer is present in ModelSEED, so a confident mapping is not possible.
#
# [2/109] 1,3-Butandiol
#   ✗  LLM could not map: I could not locate a clear ModelSEED entry for 1,3-butanediol (distinct from the more common 2,3-butanediol), so a confident mapping is not possible with the information at hand.
#
# [3/109] 1,4-B-D-Galactobiose
#   🤖 LLM Mapped: cpd15501 - beta-D-Galactobiose
#      Explanation: ModelSEED contains a specific entry for the disaccharide Gal-β(1→4)-Gal (beta-D-galactobiose), which matches the name “1,4-B-D-Galactobiose”.
#      Confidence: medium
#   ✓  Verified in template
#
# [4/109] 1,4-Butanediol
#   ✗  LLM could not map: ModelSEED appears to contain entries for 2,3-butanediol and related metabolites, but no distinct entry for the terminal-diol isomer 1,4-butanediol could be located with confidence.
#
# [5/109] 1,5-Pentanediol
#   ✗  LLM could not map: The specific diol “1,5-Pentanediol” does not appear in the standard ModelSEED compound list I have access to, and no obviously equivalent compound (e.g., a generic pentanediol entry) is recognizable, so a confident mapping is not possible.
#
# [6/109] 2-Deoxy-D-ribonic acid lithium salt
#   🤖 LLM Mapped: cpd03020 - 2-deoxy-D-ribonate
#      Explanation: Lithium salt ignored; base compound 2-deoxy-D-ribonic acid corresponds to ModelSEED’s 2-deoxy-D-ribonate (cpd03020)
#      Confidence: medium
#   ⚠️  NOT VERIFIED - LLM suggested ID not in template
#
# [7/109] 2-Deoxyadenosine monohydrate
#   🤖 LLM Mapped: cpd03347 - 2'-Deoxyadenosine
#      Explanation: The monohydrate form corresponds to the base nucleoside 2'-Deoxyadenosine, which in ModelSEED is cpd03347
#      Confidence: medium
#   ✓  Verified in template
#
# [8/109] 2-Deoxyadenosine 5-monophosphate
#   🤖 LLM Mapped: cpd00242 - 2'-Deoxyadenosine 5'-monophosphate
#      Explanation: ModelSEED compound cpd00242 is listed as 2′-deoxyadenosine-5′-phosphate (dAMP), the deoxy-analog of AMP
#      Confidence: medium
#   ✓  Verified in template
#
# [9/109] 2-Piperidinone
#   ✗  LLM could not map: ModelSEED does not appear to contain an entry for 2-Piperidinone (δ-valerolactam); no clear synonymous compound could be located, so a confident mapping cannot be made
#
# [10/109] 3-methyl-2-oxopentanoic acid
#   🤖 LLM Mapped: cpd00558 - 3-methyl-2-oxopentanoate
#      Explanation: ModelSEED compound cpd00558 is listed as 3-methyl-2-oxopentanoate (α-keto-β-methylvalerate), the conjugate base of 3-methyl-2-oxopentanoic acid
#      Confidence: medium
#   ✓  Verified in template
#
# [11/109] 3-methyl-3-butenol
#   ✗  LLM could not map: No exact match for 3-methyl-3-butenol (isoprenol) could be located in the current ModelSEED compound list; the metabolite appears to be absent from the database.
#
# [12/109] 4-Hydroxyvalerate
#   🤖 LLM Mapped: cpd07914 - 4-Hydroxyvalerate
#      Explanation: ModelSEED contains a compound explicitly named 4-Hydroxyvalerate (synonym 4-hydroxypentanoate), matching the query compound
#      Confidence: medium
#   ⚠️  NOT VERIFIED - LLM suggested ID not in template
#
# [13/109] 4-Methyl-2-oxovaleric acid
#   🤖 LLM Mapped: cpd00611 - 4-Methyl-2-oxopentanoate
#      Explanation: 4-Methyl-2-oxovaleric acid is the same molecule as 4-methyl-2-oxopentanoate (α-ketoisocaproate), which is listed in ModelSEED as cpd00611.
#      Confidence: medium
#   ✓  Verified in template
#
# [14/109] 5-Keto-D-Gluconic Acid potassium salt
#   🤖 LLM Mapped: cpd03280 - 5-dehydro-D-gluconate
#      Explanation: Potassium salt corresponds to the anion of 5-keto-D-gluconic acid, which ModelSEED lists as 5-dehydro-D-gluconate (cpd03280)
#      Confidence: medium
#   ✓  Verified in template
#
# [15/109] 6-O-Acetyl-D-glucose
#   🤖 LLM Mapped: cpd00027 - D-Glucose
#      Explanation: ModelSEED does not appear to contain a dedicated entry for 6-O-acetyl-D-glucose; the compound is most reasonably represented by its core metabolite D-glucose, which would result after de-acetylation during metabolism.
#      Confidence: low
#   ✓  Verified in template
#
# [16/109] a-Cyclodextrin
#   🤖 LLM Mapped: cpd00027 - D-Glucose
#      Explanation: α-Cyclodextrin is a cyclic oligosaccharide composed solely of six α-1,4-linked glucose units, so following the guideline for polymers it is represented by its glucose monomer in ModelSEED.
#      Confidence: medium
#   ✓  Verified in template
#
# [17/109] a-Ketoglutaric acid disodium salt hydrate
#   🤖 LLM Mapped: cpd00024 - 2-Oxoglutarate
#      Explanation: Alpha-ketoglutaric acid (disodium salt, hydrate) corresponds to the base metabolite 2-oxoglutarate in ModelSEED (cpd00024).
#      Confidence: high
#   ✓  Verified in template
#
# [18/109] Acetylated xylan
#   🤖 LLM Mapped: cpd00279 - D-Xylose
#      Explanation: Acetylated xylan is a hemicellulose whose basic monomeric unit is D-xylose; ModelSEED represents polymers by their monomer, so the best match is D-xylose
#      Confidence: medium
#   ✓  Verified in template
#
# [19/109] Actilight
#   🤖 LLM Mapped: cpd00076 - D-Fructose
#      Explanation: Actilight is a commercial fructo-oligosaccharide (FOS) preparation; following the guideline to map polymers to their monomer, the base monomer is D-fructose (ModelSEED cpd00076).
#      Confidence: medium
#   ✓  Verified in template
#
# [20/109] Adenine hydrochloride hydrate
#   🤖 LLM Mapped: cpd00226 - Adenine
#      Explanation: The name specifies adenine in a hydrochloride hydrate form; stripping salt/hydrate yields the core metabolite adenine, which is ModelSEED cpd00226.
#      Confidence: high
#   ✓  Verified in template
#
# [21/109] Agro_defined_trehalose
#   🤖 LLM Mapped: cpd00166 - Trehalose
#      Explanation: Name indicates the disaccharide trehalose; ModelSEED compound cpd00166 corresponds to trehalose.
#      Confidence: medium
#   ✓  Verified in template
#
# [22/109] amylopectin from maize
#   🤖 LLM Mapped: cpd00027 - D-Glucose
#      Explanation: Amylopectin is a glucose polymer; ModelSEED convention maps polysaccharides to their glucose monomer
#      Confidence: medium
#   ✓  Verified in template
#
# [23/109] Amylose from potato
#   🤖 LLM Mapped: cpd00027 - D-Glucose
#      Explanation: Amylose is a linear polymer of α-1,4-linked glucose units, so ModelSEED experiments typically represent it by its monomer glucose
#      Confidence: medium
#   ✓  Verified in template
#
# [24/109] Avantafiber
#   🤖 LLM Mapped: cpd00027 - D-Glucose
#      Explanation: AvantaFiber is a commercial microcrystalline cellulose preparation, and cellulose is represented in ModelSEED by its glucose monomer units; therefore it is mapped to D-glucose.
#      Confidence: medium
#   ✓  Verified in template
#
# [25/109] Azelaic acid
#   🤖 LLM Mapped: cpd15414 - Azelate
#      Explanation: ModelSEED includes azelaic acid under the synonym “azelate,” the de-protonated (–ate) form of azelaic acid (nonanedioic acid)
#      Confidence: medium
#   ✓  Verified in template
#
# [26/109] Bimuno-prebiotic
#   🤖 LLM Mapped: cpd00043 - D-Galactose
#      Explanation: Bimuno-prebiotic is a commercial mixture of galacto-oligosaccharides (GOS), whose repeating (and ultimately metabolized) monomeric unit is D-galactose, so it is mapped to the base sugar.
#      Confidence: medium
#   ✓  Verified in template
#
# [27/109] Bioecolians-prebiotic
#   🤖 LLM Mapped: cpd00027 - D-Glucose
#      Explanation: Bioecolians is a commercial α-glucan oligosaccharide prebiotic; following the polymer rule the base monomer is glucose
#      Confidence: low
#   ✓  Verified in template
#
# [28/109] Butyl stearate
#   ✗  LLM could not map: ModelSEED appears to lack a specific entry for the fatty-acid ester “butyl stearate,” and mapping it to the parent acid (stearate) would be speculative without clear database evidence.
#
# [29/109] Carnitine Hydrochloride
#   🤖 LLM Mapped: cpd00318 - L-Carnitine
#      Explanation: ModelSEED IDs follow KEGG numbering; KEGG C00318 is L-carnitine—the HCl salt is just the protonated form of this base compound.
#      Confidence: medium
#   ✓  Verified in template
#
# [30/109] casamino acids
#   ✗  LLM could not map: Casamino acids is an undefined mixture of many amino acids and small peptides rather than a single, well-defined metabolite, and no single generic ‘casamino acids’ entry exists in the standard ModelSEED compound catalog.
#
# [31/109] Chondroitin sulfate A sodium salt from bovine trachea
#   🤖 LLM Mapped: cpd00355 - Chondroitin 4-sulfate
#      Explanation: KEGG compound C00355 (chondroitin sulfate) is carried into ModelSEED as cpd00355, matching the polymer ‘chondroitin sulfate A’
#      Confidence: low
#   ✓  Verified in template
#
# [32/109] CravingZGone-prebiotic
#   ✗  LLM could not map: “CravingZGone-prebiotic” appears to be a commercial/brand formulation rather than a defined single metabolite; its chemical composition cannot be inferred from the name alone, so a reliable ModelSEED ID cannot be assigned.
#
# [33/109] D-Cellobiose
#   🤖 LLM Mapped: cpd00289 - Cellobiose
#      Explanation: ModelSEED compound cpd00289 is listed as Cellobiose, the disaccharide composed of two D-glucose units, matching the supplied name D-Cellobiose.
#      Confidence: medium
#   ✓  Verified in template
#
# [34/109] D-Galacturonic Acid monohydrate
#   🤖 LLM Mapped: cpd00256 - D-Galacturonate
#      Explanation: The monohydrate form corresponds to the base acid D-Galacturonic acid, which is represented in ModelSEED as D-Galacturonate (cpd00256)
#      Confidence: medium
#   ✓  Verified in template
#
# [35/109] D-Gluconic Acid sodium salt
#   🤖 LLM Mapped: cpd00264 - D-Gluconate
#      Explanation: ‘D-Gluconic Acid sodium salt’ is the sodium salt of D-gluconic acid, which corresponds to the base anion D-gluconate used in ModelSEED
#      Confidence: medium
#   ✓  Verified in template
#
# [36/109] D-Glucosamine Hydrochloride
#   🤖 LLM Mapped: cpd00246 - D-Glucosamine
#      Explanation: The hydrochloride salt is ignored; the underlying metabolite is D-Glucosamine, which in ModelSEED is recorded under cpd00246
#      Confidence: medium
#   ✓  Verified in template
#
# [37/109] D-Glucose-6-Phosphate sodium salt
#   🤖 LLM Mapped: cpd00079 - D-Glucose 6-phosphate
#      Explanation: Sodium salt is ignored; underlying metabolite is D-Glucose-6-phosphate which corresponds to ModelSEED cpd00079.
#      Confidence: medium
#   ✓  Verified in template
#
# [38/109] D-Glucuronic Acid
#   🤖 LLM Mapped: cpd00220 - D-Glucuronate
#      Explanation: ModelSEED represents acids in their de-protonated form; the entry for D-Glucuronate (cpd00220) corresponds to D-Glucuronic Acid.
#      Confidence: medium
#   ✓  Verified in template
#
# [39/109] D-Leucrose
#   ✗  LLM could not map: The disaccharide D-Leucrose (α-D-glucopyranosyl-(1→5)-D-fructopyranose) does not appear among the compounds currently catalogued in ModelSEED; no direct ID or obvious surrogate compound could be found.
#
# [40/109] D-Maltose monohydrate
#   🤖 LLM Mapped: cpd00108 - Maltose
#      Explanation: Monohydrate just adds water; the core metabolite is maltose, which corresponds to ModelSEED ID cpd00108.
#      Confidence: medium
#   ✓  Verified in template
#
# [41/109] D-Raffinose pentahydrate
#   🤖 LLM Mapped: cpd03161 - Raffinose
#      Explanation: Dropped the pentahydrate descriptor and matched the base trisaccharide D-Raffinose to the ModelSEED compound for raffinose.
#      Confidence: low
#   ✓  Verified in template
#
# [42/109] D-Trehalose dihydrate
#   🤖 LLM Mapped: cpd00794 - alpha,alpha-D-Trehalose
#      Explanation: Trehalose dihydrate is simply the disaccharide trehalose; ModelSEED lists trehalose as cpd00794.
#      Confidence: medium
#   ✓  Verified in template
#
# [43/109] Deoxyribonucleic acid from herring sperm
#   🤖 LLM Mapped: cpd11468 - DNA
#      Explanation: The material is genomic DNA (a polymer of deoxyribonucleotides); ModelSEED has a generic polymer compound entry named “DNA,” best matching this substrate.
#      Confidence: medium
#   ✓  Verified in template
#
# [44/109] dextran, Mw ~200,000
#   🤖 LLM Mapped: cpd00027 - D-Glucose
#      Explanation: Dextran is a polysaccharide composed exclusively of glucose units, so the base monomer in ModelSEED is D-glucose
#      Confidence: medium
#   ✓  Verified in template
#
# [45/109] Disodium Glutarate
#   🤖 LLM Mapped: cpd01010 - Glutarate
#      Explanation: Disodium glutarate is the disodium salt of glutaric acid; the base metabolite in ModelSEED is glutarate (cpd01010)
#      Confidence: high
#   ✓  Verified in template
#
# [46/109] D,L-Malic Acid
#   🤖 LLM Mapped: cpd00130 - Malate
#      Explanation: Malic acid corresponds to malate in its deprotonated form; ModelSEED represents malate as cpd00130 (typically L-malate), and the racemic D,L mixture is mapped to this base compound.
#      Confidence: medium
#   ✓  Verified in template
#
# [47/109] Dodecandioic acid
#   ✗  LLM could not map: Could not locate a clear ModelSEED entry for dodecanedioic (dodecandioic) acid; no confidently matching ID found
#
# [48/109] Fibersol-2-AG-fiber
#   🤖 LLM Mapped: cpd00027 - D-Glucose
#      Explanation: Fibersol-2 is a digestion-resistant maltodextrin composed solely of glucose units; following the polymer-to-monomer guideline, map it to its glucose monomer.
#      Confidence: medium
#   ✓  Verified in template
#
# [49/109] Fructooligosaccharides (FOS)
#   🤖 LLM Mapped: cpd00082 - D-Fructose
#      Explanation: Fructooligosaccharides are short fructose polymers that are ultimately degraded to and assimilated as the monomer D-fructose, so the base metabolite is used.
#      Confidence: medium
#   ✓  Verified in template
#
# [50/109] Fructooligosaccharides from chicory
#   🤖 LLM Mapped: cpd00082 - D-Fructose
#      Explanation: Fructooligosaccharides are short β-2,1–linked fructose chains, so per polymer-to-monomer rule they map to the fructose monomer
#      Confidence: medium
#   ✓  Verified in template
#
# [51/109] Gelatin
#   ✗  LLM could not map: Gelatin is a heterogeneous mixture of polypeptides rather than a defined small-molecule metabolite; no single ModelSEED compound cleanly represents it.
#
# [52/109] Glucuronamide
#   🤖 LLM Mapped: cpd08306 - D-Glucuronamide
#      Explanation: ModelSEED contains a dedicated entry for the amide of D-glucuronic acid listed as D-Glucuronamide (cpd08306), matching the supplied name exactly.
#      Confidence: medium
#   ✓  Verified in template
#
# [53/109] Gly-DL-Asp
#   🤖 LLM Mapped: cpd00041 - L-Aspartate
#      Explanation: The di-peptide Gly-DL-Asp will be hydrolyzed to yield glycine and (predominantly) L-aspartate; ModelSEED represents amino-acid carbon sources, so the base metabolite L-aspartate (cpd00041) is the closest match.
#      Confidence: medium
#   ✓  Verified in template
#
# [54/109] Gly-Glu
#   🤖 LLM Mapped: cpd11578 - L-glycyl-L-glutamate
#      Explanation: Gly-Glu is the dipeptide composed of glycine and L-glutamate; ModelSEED lists this dipeptide under cpd11578.
#      Confidence: medium
#   ✓  Verified in template
#
# [55/109] Heparin sodium salt from porcine intestinal mucosa
#   ✗  LLM could not map: Heparin is a large sulfated glycosaminoglycan polymer; no corresponding base metabolite or obvious polymer entry could be located in the standard ModelSEED compound list, so a confident mapping is not possible
#
# [56/109] Hyaluronic acid sodium salt from Streptococcus equi
#   ✗  LLM could not map: ModelSEED does not appear to contain a specific entry for the polymer hyaluronic acid / hyaluronan, and mapping it to one of its two monomers (N-acetyl-D-glucosamine or D-glucuronate) would be arbitrary, so a confident one-to-one mapping is not possible
#
# [57/109] Hydroxy-L-Proline
#   🤖 LLM Mapped: cpd00408 - trans-4-hydroxy-L-proline
#      Explanation: Hydroxy-L-Proline is generally understood to be 4-hydroxy-L-proline; in ModelSEED this metabolite is listed as trans-4-hydroxy-L-proline (cpd00408).
#      Confidence: medium
#   ✓  Verified in template
#
# [58/109] Inulin from chicory
#   🤖 LLM Mapped: cpd00079 - D-Fructose
#      Explanation: Inulin is a fructan polymer whose monomeric unit released upon hydrolysis is D-fructose, so the polymer is represented by its monomer in ModelSEED.
#      Confidence: medium
#   ✓  Verified in template
#
# [59/109] ISOThrive-prebiotic lot A
#   🤖 LLM Mapped: cpd00027 - D-Glucose
#      Explanation: ISOThrive is a commercial prebiotic syrup composed mainly of isomalto-oligosaccharides (short glucose chains); using the monomer glucose as the representative metabolite follows ModelSEED’s polymer-to-monomer mapping rule.
#      Confidence: low
#   ✓  Verified in template
#
# [60/109] ISOThrive-prebiotic lot B
#   ✗  LLM could not map: ISOThrive is a commercial prebiotic syrup composed of mixed isomalto-oligosaccharides; there is no single, well-defined ModelSEED compound that represents this heterogeneous mixture.
#
# [61/109] ISOThrive-prebiotic lot C
#   ✗  LLM could not map: ISOThrive is a proprietary mixture of short α-1,6/α-1,4-linked glucose oligosaccharides (maltosyl-iso-malto-oligosaccharides); no single ModelSEED compound represents this heterogeneous prebiotic syrup, so a clear one-to-one mapping is not possible.
#
# [62/109] ISOThrive-prebiotic lot D
#   🤖 LLM Mapped: cpd00027 - D-Glucose
#      Explanation: ISOThrive is a commercial prebiotic consisting of glucose-based oligosaccharides; following the polymer→monomer rule, these map to the glucose monomer used by ModelSEED.
#      Confidence: medium
#   ✓  Verified in template
#
# [63/109] L-Cysteine hydrochloride monohydrate
#   🤖 LLM Mapped: cpd00084 - L-Cysteine
#      Explanation: Hydrochloride monohydrate is just a salt/hydrate form; the underlying metabolite is L-cysteine, which is ModelSEED cpd00084.
#      Confidence: high
#   ✓  Verified in template
#
# [64/109] L-Glutamic acid monopotassium salt monohydrate
#   🤖 LLM Mapped: cpd00023 - L-Glutamate
#      Explanation: The potassium salt and hydrate forms are ignored, leaving the base metabolite L-glutamate, which is ModelSEED compound cpd00023.
#      Confidence: high
#   ✓  Verified in template
#
# [65/109] L-Malic acid disodium salt monohydrate
#   🤖 LLM Mapped: cpd00179 - L-Malate
#      Explanation: The disodium‐salt monohydrate form corresponds to the base acid L-malic acid (L-malate) which is listed in ModelSEED as cpd00179.
#      Confidence: medium
#   ✓  Verified in template
#
# [66/109] L-Rhamnose monohydrate
#   🤖 LLM Mapped: cpd00122 - L-Rhamnose
#      Explanation: Monohydrate form corresponds to the base sugar L-Rhamnose represented in ModelSEED as cpd00122
#      Confidence: high
#   ✓  Verified in template
#
# [67/109] L-tyrosine disodium salt
#   🤖 LLM Mapped: cpd00051 - L-Tyrosine
#      Explanation: The 'disodium salt' refers only to the ionic form; the core metabolite is L-tyrosine, which is ModelSEED cpd00051.
#      Confidence: high
#   ✓  Verified in template
#
# [68/109] Lactitol
#   ✗  LLM could not map: ModelSEED does not appear to contain an entry specifically named “Lactitol”; without clear evidence of an existing ID, a confident mapping cannot be made.
#
# [69/109] Lacto-N-neotetraose
#   ✗  LLM could not map: No clear ModelSEED entry for the human-milk oligosaccharide Lacto-N-neotetraose could be located; mapping would be highly speculative
#
# [70/109] Laminarin from Laminaria digitata
#   🤖 LLM Mapped: cpd00027 - D-Glucose
#      Explanation: Laminarin is a β-1,3/1,6-glucan; per guidance polymers are mapped to their glucose monomer in ModelSEED.
#      Confidence: medium
#   ✓  Verified in template
#
# [71/109] Levan - from Erwinia herbicola
#   🤖 LLM Mapped: cpd00082 - D-Fructose
#      Explanation: Levan is a fructan polysaccharide composed solely of β-D-fructose units, so the base metabolite in ModelSEED is D-Fructose
#      Confidence: medium
#   ✓  Verified in template
#
# [72/109] Levulinic Acid
#   🤖 LLM Mapped: cpd01402 - 4-Oxopentanoate (levulinate)
#      Explanation: Levulinic acid is the protonated form of 4-oxopentanoate; ModelSEED follows KEGG numbering, so KEGG C01402 → ModelSEED cpd01402
#      Confidence: medium
#   ✓  Verified in template
#
# [73/109] Maltitol
#   ✗  LLM could not map: No exact entry for the sugar-alcohol maltitol could be located in the current ModelSEED compound list; closest relatives would be maltose (cpd00208) or sorbitol (cpd00247), but neither is an exact match.
#
# [74/109] Mannan from Saccharomyces cerevisiae
#   🤖 LLM Mapped: cpd00132 - D-Mannose
#      Explanation: Mannan is a polysaccharide composed of mannose residues; per guidance for polymers the monomer (D-mannose) is used.
#      Confidence: medium
#   ✓  Verified in template
#
# [75/109] Methyl-B-D-galactopyranoside
#   🤖 LLM Mapped: cpd00102 - D-Galactose
#      Explanation: The methyl glycoside would be cleaved to yield D-galactose; since the methylated form is not present in ModelSEED, the parent sugar is the closest match.
#      Confidence: medium
#   ✓  Verified in template
#
# [76/109] palatinose hydrate
#   ✗  LLM could not map: Palatinose (isomaltulose) does not appear as a distinct entry in the current ModelSEED compound list, and no close synonym with a reliable ID could be located; uncertain mapping.
#
# [77/109] Parabanic Acid
#   🤖 LLM Mapped: cpd01367 - Parabanate
#      Explanation: ModelSEED lists the de-protonated form ‘Parabanate’; parabanic acid corresponds to this compound’s acid form
#      Confidence: medium
#   ✓  Verified in template
#
# [78/109] Pectin
#   🤖 LLM Mapped: cpd00089 - D-Galacturonate
#      Explanation: Pectin is a poly-galacturonic-acid polymer; ModelSEED represents polymers by their monomer, here D-galacturonate.
#      Confidence: medium
#   ✓  Verified in template
#
# [79/109] polygalacturonic acid
#   🤖 LLM Mapped: cpd00945 - D-Galacturonate
#      Explanation: Polygalacturonic acid is a polymer whose repeating unit is D-galacturonic acid, so it is mapped to the monomer D-Galacturonate in ModelSEED
#      Confidence: medium
#   ✓  Verified in template
#
# [80/109] Potassium acetate
#   🤖 LLM Mapped: cpd00029 - Acetate
#      Explanation: Potassium acetate is simply the potassium salt of acetate; ModelSEED represents salts by the base anion Acetate (cpd00029).
#      Confidence: high
#   ✓  Verified in template
#
# [81/109] Potassium oxalate monohydrate
#   ✗  LLM could not map: I am unable to locate a reliable ModelSEED ID for oxalate/oxalic acid from memory; providing an ID would be guess-work.
#
# [82/109] Prebiotin-prebiotic
#   🤖 LLM Mapped: cpd00082 - D-Fructose
#      Explanation: Prebiotin consists mainly of inulin-type fructooligosaccharides; treating the polymer as its monomeric unit gives D-fructose, mapped here to the ModelSEED ID for that sugar
#      Confidence: low
#   ✓  Verified in template
#
# [83/109] PreticX-prebiotic
#   🤖 LLM Mapped: cpd00109 - D-Xylose
#      Explanation: PreticX is a commercial xylo-oligosaccharide prebiotic; mapping to its monomer D-xylose follows ModelSEED guidance for polymers.
#      Confidence: medium
#   ✓  Verified in template
#
# [84/109] Promitor-fiber
#   🤖 LLM Mapped: cpd00027 - D-Glucose
#      Explanation: Promitor is a branded soluble corn fiber composed of glucose polymers; mapping to the monomer glucose follows the guideline for polymers
#      Confidence: low
#   ✓  Verified in template
#
# [85/109] Putrescine Dihydrochloride
#   🤖 LLM Mapped: cpd00305 - Putrescine
#      Explanation: Removed the di-HCl salt designation and mapped to the base metabolite putrescine (1,4-diaminobutane) present in ModelSEED
#      Confidence: medium
#   ✓  Verified in template
#
# [86/109] Red Arabinan from sugar-beet
#   🤖 LLM Mapped: cpd00152 - L-Arabinose
#      Explanation: Arabinan is a polysaccharide whose repeating unit is L-arabinose; polymers are mapped to their monomer in ModelSEED.
#      Confidence: medium
#   ✓  Verified in template
#
# [87/109] Rhamnogalacturonan - from potato
#   ✗  LLM could not map: Rhamnogalacturonan is a complex pectic polysaccharide; no clearly corresponding monomeric or polymer entry could be located in the current ModelSEED compound list with confidence.
#
# [88/109] Sodium acetate
#   🤖 LLM Mapped: cpd00029 - Acetate
#      Explanation: Sodium acetate is simply the sodium salt of acetate, so it maps to the acetate anion used in ModelSEED.
#      Confidence: high
#   ✓  Verified in template
#
# [89/109] Sodium adipate
#   🤖 LLM Mapped: cpd02983 - Adipate
#      Explanation: Sodium adipate is simply the sodium salt of adipic acid; ModelSEED lists the deprotonated dianion as “Adipate.”
#      Confidence: medium
#   ✓  Verified in template
#
# [90/109] Sodium butyrate
#   🤖 LLM Mapped: cpd00971 - Butyrate
#      Explanation: Sodium butyrate is simply the sodium salt of butyrate (butanoate), so it maps to the base metabolite “Butyrate” in ModelSEED.
#      Confidence: medium
#   ✓  Verified in template
#
# [91/109] Sodium D-Lactate
#   🤖 LLM Mapped: cpd00020 - D-Lactate
#      Explanation: Sodium salt form corresponds to the conjugate base of D-lactic acid, which is listed in ModelSEED as D-Lactate (cpd00020).
#      Confidence: medium
#   ✓  Verified in template
#
# [92/109] Sodium D,L-Lactate
#   🤖 LLM Mapped: cpd00159 - L-Lactate
#      Explanation: Sodium D,L-lactate is the salt form of lactic acid; ModelSEED represents lactate via the base metabolite L-lactate (cpd00159)
#      Confidence: medium
#   ✓  Verified in template
#
# [93/109] Sodium Formate
#   🤖 LLM Mapped: cpd00047 - Formate
#      Explanation: Sodium formate is the sodium salt of formic acid; ModelSEED represents the base anion ‘Formate’ as cpd00047.
#      Confidence: high
#   ✓  Verified in template
#
# [94/109] Sodium Fumarate dibasic
#   🤖 LLM Mapped: cpd00106 - Fumarate
#      Explanation: Sodium fumarate dibasic is simply the disodium salt of fumarate; ModelSEED represents the base anion fumarate as cpd00106.
#      Confidence: high
#   ✓  Verified in template
#
# [95/109] Sodium L-Lactate
#   🤖 LLM Mapped: cpd00159 - L-Lactate
#      Explanation: Sodium L-lactate is the sodium salt of L-lactic acid; the underlying metabolite in ModelSEED is L-lactate (cpd00159).
#      Confidence: high
#   ✓  Verified in template
#
# [96/109] Sodium octanoate
#   🤖 LLM Mapped: cpd15572 - Octanoate
#      Explanation: Sodium salt converted to its conjugate base octanoate (caprylate) which is listed in ModelSEED
#      Confidence: low
#   ✓  Verified in template
#
# [97/109] Sodium propionate
#   🤖 LLM Mapped: cpd00141 - Propionate
#      Explanation: Sodium propionate is the salt form of propionic acid; the corresponding base metabolite in ModelSEED is propionate (propanoate), mapped to cpd00141.
#      Confidence: medium
#   ✓  Verified in template
#
# [98/109] Sodium pyruvate
#   🤖 LLM Mapped: cpd00020 - Pyruvate
#      Explanation: Sodium pyruvate is simply the sodium salt of pyruvic acid, which in ModelSEED is represented by the base anion ‘Pyruvate’.
#      Confidence: high
#   ✓  Verified in template
#
# [99/109] Sodium succinate dibasic hexahydrate
#   🤖 LLM Mapped: cpd00036 - Succinate
#      Explanation: The sodium salt and hydration state are ignored, leaving the core metabolite succinate, which is ModelSEED cpd00036.
#      Confidence: high
#   ✓  Verified in template
#
# [100/109] Stachyose - 70%
#   🤖 LLM Mapped: cpd15718 - Stachyose
#      Explanation: The name matches the tetrasaccharide stachyose; purity information (-70%) is ignored.
#      Confidence: medium
#   ✓  Verified in template
#
# [101/109] Suberic acid
#   ✗  LLM could not map: I am not sufficiently certain which ModelSEED entry (if any) corresponds to suberic acid / octanedioic acid, so prefer to leave it unmapped rather than risk an incorrect ID.
#
# [102/109] Sunfiber-fiber
#   ✗  LLM could not map: “Sunfiber” is a branded, partially-hydrolyzed guar gum (galactomannan) polymer; ModelSEED does not contain entries for guar gum or galactomannan polymers, and mapping it to a single monomeric sugar (galactose or mannose) would be speculative.
#
# [103/109] Supernatant; Agrobacterium rhizogenes K599 grown in Agro_defined_trehalose (~7.5 mM 3-keto-trehalose)
#   🤖 LLM Mapped: cpd00426 - Trehalose
#      Explanation: The supernatant is described as containing ~7.5 mM 3-keto-trehalose; ModelSEED does not list this modified sugar, so we map to the parent compound trehalose, the closest available metabolite entry.
#      Confidence: low
#   ✓  Verified in template
#
# [104/109] Trisodium citrate dihydrate
#   🤖 LLM Mapped: cpd00137 - Citrate
#      Explanation: Trisodium citrate dihydrate is simply the sodium salt/hydrate form of citrate; the base metabolite “Citrate” is ModelSEED cpd00137.
#      Confidence: high
#   ✓  Verified in template
#
# [105/109] Unnamed: 1
#   ✗  LLM could not map: The term "Unnamed: 1" is not a chemical name but appears to be a placeholder or spreadsheet column header, so no corresponding ModelSEED compound can be determined.
#
# [106/109] Vitafiber-prebiotic
#   🤖 LLM Mapped: cpd00027 - D-Glucose
#      Explanation: Vitafiber is a commercial isomalto-oligosaccharide (chains of α-1,6-linked glucose); per guidance, polymers/oligosaccharides are represented by their glucose monomer in ModelSEED.
#      Confidence: medium
#   ✓  Verified in template
#
# [107/109] Vitagos-prebiotic
#   🤖 LLM Mapped: cpd00043 - D-Galactose
#      Explanation: ‘Vitagos’ is a commercial galacto-oligosaccharide (GOS) prebiotic; following the guideline for polymers/mixtures, it is mapped to its principal monomer, D-galactose (cpd00043).
#      Confidence: low
#   ✓  Verified in template
#
# [108/109] WakoIMO-prebiotic
#   🤖 LLM Mapped: cpd00027 - D-Glucose
#      Explanation: Wako IMO-prebiotic is a mixture of isomalto-oligosaccharides (glucose polymers); mapped to the glucose monomer per polymer-to-monomer rule.
#      Confidence: medium
#   ✓  Verified in template
#
# [109/109] Yacontrol-prebiotic
#   ✗  LLM could not map: “Yacontrol-prebiotic” is a commercial/trade designation rather than a specific chemical entity, and its exact composition (e.g. MOS, FOS, inulin, etc.) cannot be deduced from the name alone, so no single ModelSEED compound can be confidently assigned.
#
# ================================================================================
# ROUND 2 COMPLETE
# ================================================================================

# %% [markdown]
# ## Summary Statistics

# %%
# Create DataFrame
mapping_df = pd.DataFrame(mappings)

# Statistics
total = len(mapping_df)
mapped = (mapping_df['ModelSEED_ID'] != 'UNMAPPED').sum()
unmapped_final = (mapping_df['ModelSEED_ID'] == 'UNMAPPED').sum()

round1_mapped = mapping_df['Mapping_Method'].str.startswith('round1').sum()
round2_mapped = (mapping_df['Mapping_Method'].str.startswith('round2') & 
                 (mapping_df['ModelSEED_ID'] != 'UNMAPPED')).sum()

duplicates = (mapping_df['Duplicate_IDs'] != '').sum()
ai_assisted = (mapping_df['AI_Explanation'] != '').sum()

print("\n" + "="*80)
print("MAPPING SUMMARY")
print("="*80)
print(f"\nTotal carbon sources: {total}")
print(f"\nSuccessfully mapped: {mapped} ({100*mapped/total:.1f}%)")
print(f"  Round 1 (automated): {round1_mapped}")
print(f"  Round 2 (AI-assisted): {round2_mapped}")
print(f"\nUnmapped: {unmapped_final} ({100*unmapped_final/total:.1f}%)")
print(f"\nDuplicates resolved: {duplicates}")
print(f"AI-assisted mappings: {ai_assisted}")

print(f"\n{'='*80}")

# %% [markdown]
# ## Save Mapping Table

# %%
print(f"\nSaving mapping table to: {MAPPING_FILE}")
mapping_df.to_csv(MAPPING_FILE, index=False)
print(f"Saved {len(mapping_df)} mappings")

# Display first 20 rows
print(f"\nFirst 20 mappings:")
display(mapping_df.head(20))

# %% [markdown]
# ## Review Unmapped Compounds

# %%
unmapped_df = mapping_df[mapping_df['ModelSEED_ID'] == 'UNMAPPED']

if len(unmapped_df) > 0:
    print(f"\n⚠️  MANUAL CURATION REQUIRED for {len(unmapped_df)} compounds:")
    print("="*80)
    
    for idx, row in unmapped_df.iterrows():
        print(f"\n{row['Carbon_Source_Original']}")
        print(f"  Method: {row['Mapping_Method']}")
        if row['AI_Explanation']:
            print(f"  AI says: {row['AI_Explanation']}")
    
    print("\n" + "="*80)
    print("\nSuggestions for manual curation:")
    print("1. Check ModelSEED web interface: https://modelseed.org")
    print("2. Search KEGG database for compound IDs")
    print("3. For complex mixtures, consider using representative compound")
    print("4. For proprietary prebiotics, research composition")
    print("5. Update mapping CSV manually and re-run media generation")
else:
    print("\n✓ All compounds successfully mapped!")

# %% [markdown]
# ## Generate Media JSON Files
#
# Create individual media formulation files for each mapped carbon source.

# %%
# Base media formulation (same for all)
BASE_MEDIA = {
    'cpd00007': (-10, 100),    # O2
    'cpd00001': (-100, 100),   # H2O
    'cpd00009': (-100, 100),   # Phosphate
    'cpd00013': (-100, 100),   # NH3
    'cpd00048': (-100, 100),   # Sulfate
    'cpd00099': (-100, 100),   # Cl-
    'cpd00067': (-100, 100),   # H+
    'cpd00205': (-100, 100),   # K+
    'cpd00254': (-100, 100),   # Mg2+
    'cpd00971': (-100, 100),   # Na+
    'cpd00149': (-100, 100),   # Co2+
    'cpd00063': (-100, 100),   # Ca2+
    'cpd00058': (-100, 100),   # Cu2+
    'cpd00034': (-100, 100),   # Zn2+
    'cpd00030': (-100, 100),   # Mn2+
    'cpd10515': (-100, 100),   # Fe2+
    'cpd10516': (-100, 100),   # Fe3+
    'cpd11574': (-100, 100),   # Molybdate
    'cpd00244': (-100, 100),   # Ni2+
}

# Carbon source uptake rate (negative = uptake)
CARBON_UPTAKE_RATE = -5

print("Base media formulation loaded")
print(f"  Base nutrients: {len(BASE_MEDIA)}")
print(f"  Carbon uptake rate: {CARBON_UPTAKE_RATE} mmol/gDW/hr")

# %%
print(f"\nGenerating media JSON files...")
print("="*80)

media_generated = 0
media_skipped = 0

for idx, row in mapping_df.iterrows():
    carbon_source = row['Carbon_Source_Original']
    cpd_id = row['ModelSEED_ID']
    
    if cpd_id == 'UNMAPPED':
        print(f"  ✗ Skipping {carbon_source} (unmapped)")
        media_skipped += 1
        continue
    
    # Create media formulation
    media_dict = BASE_MEDIA.copy()
    media_dict[cpd_id] = (CARBON_UPTAKE_RATE, 100)
    
    # Create safe filename
    safe_filename = carbon_source.replace('/', '_').replace(' ', '_').replace(',', '')
    safe_filename = safe_filename.replace('(', '').replace(')', '')
    media_file = MEDIA_DIR / f"{safe_filename}.json"
    
    # Save media file
    with open(media_file, 'w') as f:
        json.dump(media_dict, f, indent=2)
    
    media_generated += 1
    
    if media_generated <= 5:
        print(f"  ✓ Generated: {media_file.name}")

if media_generated > 5:
    print(f"  ... and {media_generated - 5} more files")

print(f"\n{'='*80}")
print(f"Media generation complete")
print(f"  Generated: {media_generated}")
print(f"  Skipped: {media_skipped}")
print(f"  Output directory: {MEDIA_DIR}")
print(f"{'='*80}")

# %% [markdown]
# ## Usage Example
#
# How to load media files for ModelSEEDpy:

# %%
# Example: Load glucose media
print("Example: Loading media for D-Glucose")
print("="*80)

# Find glucose media file
glucose_file = MEDIA_DIR / "2-Deoxy-D-Ribose.json"  # First carbon source as example

if glucose_file.exists():
    with open(glucose_file) as f:
        media_dict = json.load(f)
    
    print(f"\nLoaded media from: {glucose_file.name}")
    print(f"Total compounds: {len(media_dict)}")
    print(f"\nCarbon source:")
    for cpd_id, bounds in media_dict.items():
        if bounds[0] == CARBON_UPTAKE_RATE:  # Find carbon source
            print(f"  {cpd_id}: {bounds}")
    
    print(f"\nUsage with ModelSEEDpy:")
    print("  from modelseedpy import MSMedia")
    print(f"  media = MSMedia.from_dict(media_dict)")
    print("  model.medium = media.get_media_constraints()")
else:
    print("Example media file not found")

# %% [markdown]
# ## Summary
#
# **Files Created**:
# 1. `results/carbon_source_mapping.csv` - Complete mapping table
# 2. `media/*.json` - Individual media formulations
#
# **Next Steps**:
# 1. Review unmapped compounds and perform manual curation if needed
# 2. Update mapping CSV with manual corrections
# 3. Re-run media generation section if needed
# 4. Proceed to CDMSCI-198: Build metabolic models
# 5. Proceed to CDMSCI-199: Run FBA simulations with these media
